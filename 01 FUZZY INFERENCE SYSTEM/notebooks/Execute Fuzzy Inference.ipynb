# %%
import os
import sys
import pickle as pk
import numpy as np

project_root = os.path.dirname(os.getcwd())
sys.path.append(project_root)
sys.path.append(os.path.join(project_root, "src", "model"))
sys.path.append(os.path.join(project_root, "src", "rules"))
sys.path.append(os.path.join(project_root, "src", "fuzzy"))

from src.model import evaluate_model as em
from src.model import train_model as mod
from src.rules import extract_crisp_rules as cr
from src.fuzzy import fuzzy_inference as fi
from src.fuzzy import export_fuzzy_objects as ef

from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.metrics import (
    accuracy_score, recall_score, precision_score, 
    f1_score, confusion_matrix
)
import pandas as pd

# %%
from config import LOAN_FILE,MODEL_DIR, PKL_DIR
    
pklList=mod.read_all_pkl_files(PKL_DIR)
pklList
# Out:
# {'X_test.pkl':          last_fico_range_high  recoveries  term_num  fico_range_low  \
#  1593248                 649.0         0.0        36           735.0
#  1548776                 649.0         0.0        60           670.0
#  2278832                 719.0         0.0        60           730.0
#  2327643                 719.0         0.0        36           695.0
#  2676968                 769.0         0.0        36           695.0
#  ...                       ...         ...       ...             ...
#  2173988                 779.0         0.0        60           780.0
#  1951656                 599.0         0.0        36           670.0
#  860745                  679.0         0.0        60           680.0
#  2527918                 704.0         0.0        36           695.0
#  1563390                 599.0         0.0        36           675.0
#
#           total_rec_late_fee  acc_open_past_24mths    dti  mort_acc  loan_amnt  \
#  1593248                 0.0                   0.0  26.01       2.0    35000.0
#  1548776                 0.0                   3.0  21.83       2.0    21000.0
#  2278832                 0.0                   6.0  17.85       1.0    16800.0
#  2327643                 0.0                   0.0  30.31       0.0    23950.0
#  2676968                 0.0                   1.0  72.64       2.0    35000.0
#  ...                     ...                   ...    ...       ...        ...
#  2173988                 0.0                   1.0  15.58       4.0    30000.0
#  1951656                 0.0                   5.0  33.11       0.0     9525.0
#  860745                  0.0                   5.0  14.61       4.0    15000.0
#  2527918                 0.0                   6.0  17.70       1.0     3000.0
#  1563390                 0.0                   5.0  18.47       1.0    20000.0
#
#          debt_settlement_flag grade verification_status
#  1593248                    N     B            Verified
#  1548776                    N     D            Verified
#  2278832                    N     C        Not Verified
#  2327643                    N     B            Verified
#  2676968                    N     C            Verified
#  ...                      ...   ...                 ...
#  2173988                    N     C            Verified
#  1951656                    N     C            Verified
#  860745                     N     D        Not Verified
#  2527918                    N     C     Source Verified
#  1563390                    N     C     Source Verified
#
#  [559054 rows x 12 columns],
#  'X_train.pkl':          last_fico_range_high  recoveries  term_num  fico_range_low  \
#  2326545                 689.0        0.00        36           690.0
#  164929                  809.0        0.00        36           685.0
#  1038900                 669.0        0.00        36           680.0
#  165940                  669.0        0.00        60           670.0
#  1014685                 564.0     1384.86        60           685.0
#  ...                       ...         ...       ...             ...
#  277003                  794.0        0.00        36           715.0
#  2421628                 704.0        0.00        36           690.0
#  131933                  719.0        0.00        36           670.0
#  1508372                 539.0        0.00        60           670.0
#  121959                  694.0      822.40        36           665.0
#
#           total_rec_late_fee  acc_open_past_24mths    dti  mort_acc  loan_amnt  \
#  2326545                 0.0                   3.0  10.78       3.0    14875.0
#  164929                  0.0                   1.0  14.02       0.0     7000.0
#  1038900                 0.0                   4.0   8.06       2.0    30000.0
#  165940                  0.0                   5.0  33.93       0.0    25450.0
#  1014685                 0.0                   9.0  19.71       0.0    10000.0
#  ...                     ...                   ...    ...       ...        ...
#  277003                  0.0                   5.0  14.82       1.0    10500.0
#  2421628                 0.0                   5.0  21.83       5.0    35000.0
#  131933                  0.0                   2.0  27.83       0.0     8875.0
#  1508372                 0.0                   2.0  12.51       3.0    20000.0
#  121959                  0.0                   9.0  13.44       4.0     8875.0
#
#          debt_settlement_flag grade verification_status
#  2326545                    N     A        Not Verified
#  164929                     N     B        Not Verified
#  1038900                    N     B     Source Verified
#  165940                     N     E            Verified
#  1014685                    N     D        Not Verified
#  ...                      ...   ...                 ...
#  277003                     N     B        Not Verified
#  2421628                    N     D     Source Verified
#  131933                     N     B        Not Verified
#  1508372                    N     C     Source Verified
#  121959                     N     B            Verified
#
#  [1304459 rows x 12 columns],
#  'y_test.pkl': 1593248    0
#  1548776    0
#  2278832    0
#  2327643    0
#  2676968    0
#            ..
#  2173988    0
#  1951656    0
#  860745     0
#  2527918    0
#  1563390    0
#  Name: bad_good, Length: 559054, dtype: int64,
#  'y_train.pkl': 2326545    0
#  164929     0
#  1038900    0
#  165940     0
#  1014685    1
#            ..
#  277003     0
#  2421628    0
#  131933     0
#  1508372    0
#  121959     1
#  Name: bad_good, Length: 1304459, dtype: int64}

# %%
import glob

# 1. Configuración de rutas y prefijo
prefix = 'catboost_NEW_encoded_'

try:
    # 2. Buscar todos los archivos que coincidan con el patrón en el directorio
    search_pattern = os.path.join(MODEL_DIR, f"{prefix}*.cbm")
    model_files = glob.glob(search_pattern)

    if not model_files:
        raise FileNotFoundError(f"No se encontraron modelos con el prefijo '{prefix}' en: {MODEL_DIR}")

    # 3. Ordenar alfabéticamente y seleccionar el último (más reciente)

    latest_model_path = sorted(model_files)[-1]

    # 4. Carga del modelo y métricas
    print(f"[INFO] Modelo más reciente detectado: {os.path.basename(latest_model_path)}")
    
    catboost_model, catboost_metrics, X_train_encoded, cat_mappings = mod.load_model(latest_model_path)

    # 5. Visualización de metadatos cargados
    print(f"[SUCCESS] Modelo cargado correctamente:")
    print(f"  - Model type: {catboost_metrics.get('model_type')}")
    print(f"  - Saved date: {catboost_metrics.get('saved_date')}")
    print(f"  - Optimal threshold: {catboost_metrics.get('optimal_threshold')}")

except Exception as e:
    print(f"[ERROR] No se pudo cargar el modelo: {e}")
# Out:
# [INFO] Modelo más reciente detectado: catboost_NEW_encoded_20260316_214456_model.cbm
# [INFO] CatBoost model loaded from: c:\Users\danli\OneDrive\Casa Serrano Hidalgo\Danilo\Maestria USFQ Danilo\Tesis\Rule reduction\Tesis Byron\FuzzyInferenceSystemFromGBT\01 FUZZY INFERENCE SYSTEM\object\model\catboost_NEW_encoded_20260316_214456_model.cbm
# [INFO] Metrics loaded from: c:\Users\danli\OneDrive\Casa Serrano Hidalgo\Danilo\Maestria USFQ Danilo\Tesis\Rule reduction\Tesis Byron\FuzzyInferenceSystemFromGBT\01 FUZZY INFERENCE SYSTEM\object\model\catboost_NEW_encoded_20260316_214456_metrics.json
# [INFO] Category mappings loaded from: c:\Users\danli\OneDrive\Casa Serrano Hidalgo\Danilo\Maestria USFQ Danilo\Tesis\Rule reduction\Tesis Byron\FuzzyInferenceSystemFromGBT\01 FUZZY INFERENCE SYSTEM\object\model\catboost_NEW_encoded_20260316_214456_category_mappings.pkl
#   Encoded features: ['debt_settlement_flag', 'grade', 'verification_status']
# [INFO] X_train_encoded loaded from: c:\Users\danli\OneDrive\Casa Serrano Hidalgo\Danilo\Maestria USFQ Danilo\Tesis\Rule reduction\Tesis Byron\FuzzyInferenceSystemFromGBT\01 FUZZY INFERENCE SYSTEM\object\model\catboost_NEW_encoded_20260316_214456_X_train_encoded.parquet
#   Shape: (1304459, 12)
# [SUCCESS] Modelo cargado correctamente:
#   - Model type: CatBoost
#   - Saved date: 2026-03-16 21:44:56
#   - Optimal threshold: 0.43000000000000005

# %%
"""
# Este es el código original, pero lo cambié para que automáticamente busque el último modelo entrenado - Danilo
---

print("[INFO] Model loaded:")
catboost_model, catboost_metrics, X_train_encoded, cat_mappings = mod.load_model(os.path.join(MODEL_DIR, 'catboost_NEW_encoded_20260209_192057_model.cbm'))

print(f"  Model type: {catboost_metrics.get('model_type')}")
print(f"  Saved date: {catboost_metrics.get('saved_date')}")
print(f"  Optimal threshold: {catboost_metrics.get('optimal_threshold')}")
"""
# Out:
# '\nEste es el código original, pero lo cambié para que automáticamente busque el último modelo entrenado - Danilo\n---\n\nprint("[INFO] Model loaded:")\ncatboost_model, catboost_metrics, X_train_encoded, cat_mappings = mod.load_model(os.path.join(MODEL_DIR, \'catboost_NEW_encoded_20260209_192057_model.cbm\'))\n\nprint(f"  Model type: {catboost_metrics.get(\'model_type\')}")\nprint(f"  Saved date: {catboost_metrics.get(\'saved_date\')}")\nprint(f"  Optimal threshold: {catboost_metrics.get(\'optimal_threshold\')}")\n'

# %%
X_train = pklList['X_train.pkl']
y_train = pklList['y_train.pkl']
X_test=pklList['X_test.pkl']
y_test=pklList['y_test.pkl']

# %%
print("Catboost feature names:")
print(catboost_model.feature_names_)
# Out:
# Catboost feature names:
# ['last_fico_range_high', 'recoveries', 'term_num', 'fico_range_low', 'total_rec_late_fee', 'acc_open_past_24mths', 'dti', 'mort_acc', 'loan_amnt', 'debt_settlement_flag', 'grade', 'verification_status']

# %%
y_test.unique
y_test.value_counts()/len(y_test)
# Out:
# bad_good
# 0    0.805328
# 1    0.194672
# Name: count, dtype: float64

# %%
y_train.unique
y_train.value_counts()/len(y_train)
# Out:
# bad_good
# 0    0.804586
# 1    0.195414
# Name: count, dtype: float64

# %%
all_features = X_train.columns.tolist()
(all_features)
# Out:
# ['last_fico_range_high',
#  'recoveries',
#  'term_num',
#  'fico_range_low',
#  'total_rec_late_fee',
#  'acc_open_past_24mths',
#  'dti',
#  'mort_acc',
#  'loan_amnt',
#  'debt_settlement_flag',
#  'grade',
#  'verification_status']

# %%
# Compute CatBoost feature importances and list top features by importance
feature_importances = catboost_model.get_feature_importance() * 100
print(f"Feature importances length: {len(feature_importances)}")

top_features_idx = np.argsort(feature_importances)[-60:]
print(f"Top feature indices identified: {top_features_idx}")

top_features = [all_features[i] for i in top_features_idx if i < len(all_features)]
print(f"Top features identified: {top_features}")
# Out:
# Feature importances length: 12
# Top feature indices identified: [11  4  7 10  5  6  3  8  9  2  0  1]
# Top features identified: ['verification_status', 'total_rec_late_fee', 'mort_acc', 'grade', 'acc_open_past_24mths', 'dti', 'fico_range_low', 'loan_amnt', 'debt_settlement_flag', 'term_num', 'last_fico_range_high', 'recoveries']

# %%
# select balanced trees from the CatBoost model using the training data
balanced_trees = cr.get_catboost_trees(
    catboost_model,
    X_train_encoded,
    y_train,
    n_trees=None,
    max_samples=3000000,  # Extract all samples, without limitation.
    parallel_jobs=-1 #run in parallel using all available CPU cores
)
print(f"[INFO] Balanced trees selected: {len(balanced_trees)}")
# Out:
# [INFO] -------------------- Tree Selection Process --------------------
# [INFO] Using ALL 68 trees (no selection needed)
#
# [INFO] -------------------- Selection Complete --------------------
# [INFO] Balanced trees selected: 68

# %%
# Extract crisp rules from the selected balanced trees using the training data
cb_rules = cr.extract_rules_from_trees(
    catboost_model, X_train_encoded, y_train,
    min_confidence=0,
    min_support=0,
    tree_index_list=balanced_trees,
    parallel_jobs=-1
)
# Out:
# [INFO] -------------------- CatBoost Rule Extraction --------------------
#
# [INFO] Dataset statistics:
#   Total samples: 1,304,459
#   Class 0: 1,049,549 (80.5%)
#   Class 1: 254,910 (19.5%)
#
# [INFO] Creating CatBoost Pool...
#    All features treated as numeric (pre-encoded)
#
# [INFO] Processing 68 trees...
#
#    [INFO] Extracted 1,681 rules
#    [INFO] All conditions are numeric (categorical features encoded)
#
#    [INFO] Metrics validation:
#      Class 0: 571 rules
#        - Avg Precision: 0.732
#        - High quality (>0.7): 344 (60.2%)
#      Class 1: 1,110 rules
#        - Avg Precision: 0.682
#        - High quality (>0.7): 656 (59.1%)
#
#    [INFO] Quality distribution:
#      Min precision:    0.006
#      25th percentile:  0.417
#      Median:           0.915
#      75th percentile:  1.000
#      Max precision:    1.000
#
# [INFO] -------------------- Extraction Complete --------------------

# %%
unique_rules = cr.remove_duplicate_rules(cb_rules)
unique_rules
# Out:
# [INFO] Processing rule with conditions: ('last_fico_range_high <= 581.500000', 'last_fico_range_high <= 631.500000', 'recoveries <= 0.005000', 'recoveries <= 1730.060059', 'term_num <= 48.000000')
#
# [INFO] Processing rule with conditions: ('last_fico_range_high <= 581.500000', 'last_fico_range_high > 631.500000', 'recoveries <= 0.005000', 'recoveries <= 1730.060059', 'term_num <= 48.000000')
#
# [INFO] Processing rule with conditions: ('last_fico_range_high <= 581.500000', 'last_fico_range_high <= 631.500000', 'recoveries <= 0.005000', 'recoveries > 1730.060059', 'term_num <= 48.000000')
#
# [INFO] Processing rule with conditions: ('last_fico_range_high <= 581.500000', 'last_fico_range_high > 631.500000', 'recoveries <= 0.005000', 'recoveries > 1730.060059', 'term_num <= 48.000000')
#
# [INFO] Processing rule with conditions: ('last_fico_range_high <= 581.500000', 'last_fico_range_high <= 631.500000', 'recoveries <= 0.005000', 'recoveries <= 1730.060059', 'term_num > 48.000000')
#
# [INFO] Processing rule with conditions: ('last_fico_range_high <= 581.500000', 'last_fico_range_high > 631.500000', 'recoveries <= 0.005000', 'recoveries <= 1730.060059', 'term_num > 48.000000')
#
# [INFO] Processing rule with conditions: ('last_fico_range_high <= 581.500000', 'last_fico_range_high <= 631.500000', 'recoveries <= 0.005000', 'recoveries > 1730.060059', 'term_num > 48.000000')
#
# [INFO] Processing rule with conditions: ('last_fico_range_high <= 581.500000', 'last_fico_range_high > 631.500000', 'recoveries <= 0.005000', 'recoveries > 1730.060059', 'term_num > 48.000000')
#
# [INFO] Processing rule with conditions: ('last_fico_range_high > 581.500000', 'last_fico_range_high > 631.500000', 'recoveries <= 0.005000', 'recoveries <= 1730.060059', 'term_num <= 48.000000')
#
# [INFO] Processing rule with conditions: ('last_fico_range_high > 581.500000', 'last_fico_range_high > 631.500000', 'recoveries <= 0.005000', 'recoveries > 1730.060059', 'term_num <= 48.000000')
#
# [INFO] Processing rule with conditions: ('last_fico_range_high > 581.500000', 'last_fico_range_high > 631.500000', 'recoveries <= 0.005000', 'recoveries <= 1730.060059', 'term_num > 48.000000')
#
# [INFO] Processing rule with conditions: ('last_fico_range_high > 581.500000', 'last_fico_range_high > 631.500000', 'recoveries <= 0.005000', 'recoveries > 1730.060059', 'term_num > 48.000000')
#
# [INFO] Processing rule with conditions: ('last_fico_range_high <= 581.500000', 'last_fico_range_high <= 631.500000', 'recoveries > 0.005000', 'recoveries > 1730.060059', 'term_num <= 48.000000')
#
# [INFO] Processing rule with conditions: ('last_fico_range_high <= 581.500000', 'last_fico_range_high > 631.500000', 'recoveries > 0.005000', 'recoveries > 1730.060059', 'term_num <= 48.000000')
#
# [INFO] Processing rule with conditions: ('last_fico_range_high <= 581.500000', 'last_fico_range_high <= 631.500000', 'recoveries > 0.005000', 'recoveries > 1730.060059', 'term_num > 48.000000')
#
# [INFO] Processing rule with conditions: ('last_fico_range_high <= 581.500000', 'last_fico_range_high > 631.500000', 'recoveries > 0.005000', 'recoveries > 1730.060059', 'term_num > 48.000000')
#
# [INFO] Processing rule with conditions: ('last_fico_range_high > 581.500000', 'last_fico_range_high > 631.500000', 'recoveries > 0.005000', 'recoveries > 1730.060059', 'term_num <= 48.000000')
#
# [INFO] Processing rule with conditions: ('last_fico_range_high > 581.500000', 'last_fico_range_high > 631.500000', 'recoveries > 0.005000', 'recoveries > 1730.060059', 'term_num > 48.000000')
#
# [INFO] Processing rule with conditions: ('debt_settlement_flag <= 0.500000', 'dti <= 25.035000', 'last_fico_range_high <= 506.500000', 'last_fico_range_high <= 581.500000', 'recoveries <= 1.280000')
#
# [INFO] Processing rule with conditions: ('debt_settlement_flag <= 0.500000', 'dti > 25.035000', 'last_fico_range_high <= 506.500000', 'last_fico_range_high <= 581.500000', 'recoveries <= 1.280000')
#
# [INFO] Processing rule with conditions: ('debt_settlement_flag <= 0.500000', 'dti <= 25.035000', 'last_fico_range_high <= 506.500000', 'last_fico_range_high > 581.500000', 'recoveries <= 1.280000')
#
# [INFO] Processing rule with conditions: ('debt_settlement_flag <= 0.500000', 'dti > 25.035000', 'last_fico_range_high <= 506.500000', 'last_fico_range_high > 581.500000', 'recoveries <= 1.280000')
#
# [INFO] Processing rule with conditions: ('debt_settlement_flag > 0.500000', 'dti <= 25.035000', 'last_fico_range_high <= 506.500000', 'last_fico_range_high <= 581.500000', 'recoveries <= 1.280000')
#
# [INFO] Processing rule with conditions: ('debt_settlement_flag > 0.500000', 'dti > 25.035000', 'last_fico_range_high <= 506.500000', 'last_fico_range_high <= 581.500000', 'recoveries <= 1.280000')
#
# [INFO] Processing rule with conditions: ('debt_settlement_flag > 0.500000', 'dti <= 25.035000', 'last_fico_range_high <= 506.500000', 'last_fico_range_high > 581.500000', 'recoveries <= 1.280000')
#
# [INFO] Processing rule with conditions: ('debt_settlement_flag > 0.500000', 'dti > 25.035000', 'last_fico_range_high <= 506.500000', 'last_fico_range_high > 581.500000', 'recoveries <= 1.280000')
#
# [INFO] Processing rule with conditions: ('debt_settlement_flag <= 0.500000', 'dti > 25.035000', 'last_fico_range_high <= 506.500000', 'last_fico_range_high <= 581.500000', 'recoveries > 1.280000')
#
# [INFO] Processing rule with conditions: ('debt_settlement_flag <= 0.500000', 'dti > 25.035000', 'last_fico_range_high <= 506.500000', 'last_fico_range_high > 581.500000', 'recoveries > 1.280000')
#
# [INFO] Processing rule with conditions: ('debt_settlement_flag > 0.500000', 'dti > 25.035000', 'last_fico_range_high <= 506.500000', 'last_fico_range_high <= 581.500000', 'recoveries > 1.280000')
#
# [INFO] Processing rule with conditions: ('debt_settlement_flag > 0.500000', 'dti > 25.035000', 'last_fico_range_high <= 506.500000', 'last_fico_range_high > 581.500000', 'recoveries > 1.280000')
#
# [INFO] Processing rule with conditions: ('debt_settlement_flag <= 0.500000', 'dti <= 25.035000', 'last_fico_range_high <= 581.500000', 'last_fico_range_high > 506.500000', 'recoveries <= 1.280000')
#
# [INFO] Processing rule with conditions: ('debt_settlement_flag <= 0.500000', 'dti > 25.035000', 'last_fico_range_high <= 581.500000', 'last_fico_range_high > 506.500000', 'recoveries <= 1.280000')
#
# [INFO] Processing rule with conditions: ('debt_settlement_flag <= 0.500000', 'dti <= 25.035000', 'last_fico_range_high > 506.500000', 'last_fico_range_high > 581.500000', 'recoveries <= 1.280000')
#
# [INFO] Processing rule with conditions: ('debt_settlement_flag <= 0.500000', 'dti > 25.035000', 'last_fico_range_high > 506.500000', 'last_fico_range_high > 581.500000', 'recoveries <= 1.280000')
#
# [INFO] Processing rule with conditions: ('debt_settlement_flag > 0.500000', 'dti <= 25.035000', 'last_fico_range_high <= 581.500000', 'last_fico_range_high > 506.500000', 'recoveries <= 1.280000')
#
# [INFO] Processing rule with conditions: ('debt_settlement_flag > 0.500000', 'dti > 25.035000', 'last_fico_range_high <= 581.500000', 'last_fico_range_high > 506.500000', 'recoveries <= 1.280000')
#
# [INFO] Processing rule with conditions: ('debt_settlement_flag > 0.500000', 'dti <= 25.035000', 'last_fico_range_high > 506.500000', 'last_fico_range_high > 581.500000', 'recoveries <= 1.280000')
#
# [INFO] Processing rule with conditions: ('debt_settlement_flag > 0.500000', 'dti > 25.035000', 'last_fico_range_high > 506.500000', 'last_fico_range_high > 581.500000', 'recoveries <= 1.280000')
#
# [INFO] Processing rule with conditions: ('debt_settlement_flag <= 0.500000', 'dti > 25.035000', 'last_fico_range_high <= 581.500000', 'last_fico_range_high > 506.500000', 'recoveries > 1.280000')
#
# [INFO] Processing rule with conditions: ('debt_settlement_flag <= 0.500000', 'dti > 25.035000', 'last_fico_range_high > 506.500000', 'last_fico_range_high > 581.500000', 'recoveries > 1.280000')
#
# [INFO] Processing rule with conditions: ('debt_settlement_flag > 0.500000', 'dti > 25.035000', 'last_fico_range_high <= 581.500000', 'last_fico_range_high > 506.500000', 'recoveries > 1.280000')
#
# [INFO] Processing rule with conditions: ('debt_settlement_flag > 0.500000', 'dti > 25.035000', 'last_fico_range_high > 506.500000', 'last_fico_range_high > 581.500000', 'recoveries > 1.280000')
#
# [INFO] Processing rule with conditions: ('fico_range_low <= 702.500000', 'last_fico_range_high <= 631.500000', 'last_fico_range_high <= 676.500000', 'loan_amnt <= 9812.500000', 'recoveries <= 7.880000')
#
# [INFO] Processing rule with conditions: ('fico_range_low <= 702.500000', 'last_fico_range_high <= 631.500000', 'last_fico_range_high <= 676.500000', 'loan_amnt <= 9812.500000', 'recoveries > 7.880000')
#
# [INFO] Processing rule with conditions: ('fico_range_low > 702.500000', 'last_fico_range_high <= 631.500000', 'last_fico_range_high <= 676.500000', 'loan_amnt <= 9812.500000', 'recoveries <= 7.880000')
#
# [INFO] Processing rule with conditions: ('fico_range_low > 702.500000', 'last_fico_range_high <= 631.500000', 'last_fico_range_high <= 676.500000', 'loan_amnt <= 9812.500000', 'recoveries > 7.880000')
#
# [INFO] Processing rule with conditions: ('fico_range_low <= 702.500000', 'last_fico_range_high <= 631.500000', 'last_fico_range_high <= 676.500000', 'loan_amnt > 9812.500000', 'recoveries <= 7.880000')
#
# [INFO] Processing rule with conditions: ('fico_range_low <= 702.500000', 'last_fico_range_high <= 631.500000', 'last_fico_range_high <= 676.500000', 'loan_amnt > 9812.500000', 'recoveries > 7.880000')
#
# [INFO] Processing rule with conditions: ('fico_range_low > 702.500000', 'last_fico_range_high <= 631.500000', 'last_fico_range_high <= 676.500000', 'loan_amnt > 9812.500000', 'recoveries <= 7.880000')
#
# [INFO] Processing rule with conditions: ('fico_range_low > 702.500000', 'last_fico_range_high <= 631.500000', 'last_fico_range_high <= 676.500000', 'loan_amnt > 9812.500000', 'recoveries > 7.880000')
#
# [INFO] Processing rule with conditions: ('fico_range_low <= 702.500000', 'last_fico_range_high <= 631.500000', 'last_fico_range_high > 676.500000', 'loan_amnt <= 9812.500000', 'recoveries <= 7.880000')
#
# [INFO] Processing rule with conditions: ('fico_range_low <= 702.500000', 'last_fico_range_high > 631.500000', 'last_fico_range_high > 676.500000', 'loan_amnt <= 9812.500000', 'recoveries <= 7.880000')
#
# [INFO] Processing rule with conditions: ('fico_range_low <= 702.500000', 'last_fico_range_high <= 631.500000', 'last_fico_range_high > 676.500000', 'loan_amnt <= 9812.500000', 'recoveries > 7.880000')
#
# [INFO] Processing rule with conditions: ('fico_range_low <= 702.500000', 'last_fico_range_high > 631.500000', 'last_fico_range_high > 676.500000', 'loan_amnt <= 9812.500000', 'recoveries > 7.880000')
#
# [INFO] Processing rule with conditions: ('fico_range_low > 702.500000', 'last_fico_range_high <= 631.500000', 'last_fico_range_high > 676.500000', 'loan_amnt <= 9812.500000', 'recoveries <= 7.880000')
#
# [INFO] Processing rule with conditions: ('fico_range_low > 702.500000', 'last_fico_range_high > 631.500000', 'last_fico_range_high > 676.500000', 'loan_amnt <= 9812.500000', 'recoveries <= 7.880000')
#
# [INFO] Processing rule with conditions: ('fico_range_low > 702.500000', 'last_fico_range_high <= 631.500000', 'last_fico_range_high > 676.500000', 'loan_amnt <= 9812.500000', 'recoveries > 7.880000')
#
# [INFO] Processing rule with conditions: ('fico_range_low > 702.500000', 'last_fico_range_high > 631.500000', 'last_fico_range_high > 676.500000', 'loan_amnt <= 9812.500000', 'recoveries > 7.880000')
#
# [INFO] Processing rule with conditions: ('fico_range_low <= 702.500000', 'last_fico_range_high <= 631.500000', 'last_fico_range_high > 676.500000', 'loan_amnt > 9812.500000', 'recoveries <= 7.880000')
#
# [INFO] Processing rule with conditions: ('fico_range_low <= 702.500000', 'last_fico_range_high > 631.500000', 'last_fico_range_high > 676.500000', 'loan_amnt > 9812.500000', 'recoveries <= 7.880000')
#
# [INFO] Processing rule with conditions: ('fico_range_low <= 702.500000', 'last_fico_range_high <= 631.500000', 'last_fico_range_high > 676.500000', 'loan_amnt > 9812.500000', 'recoveries > 7.880000')
#
# [INFO] Processing rule with conditions: ('fico_range_low <= 702.500000', 'last_fico_range_high > 631.500000', 'last_fico_range_high > 676.500000', 'loan_amnt > 9812.500000', 'recoveries > 7.880000')
#
# [INFO] Processing rule with conditions: ('fico_range_low > 702.500000', 'last_fico_range_high <= 631.500000', 'last_fico_range_high > 676.500000', 'loan_amnt > 9812.500000', 'recoveries <= 7.880000')
#
# [INFO] Processing rule with conditions: ('fico_range_low > 702.500000', 'last_fico_range_high > 631.500000', 'last_fico_range_high > 676.500000', 'loan_amnt > 9812.500000', 'recoveries <= 7.880000')
#
# [INFO] Processing rule with conditions: ('fico_range_low > 702.500000', 'last_fico_range_high <= 631.500000', 'last_fico_range_high > 676.500000', 'loan_amnt > 9812.500000', 'recoveries > 7.880000')
#
# [INFO] Processing rule with conditions: ('fico_range_low > 702.500000', 'last_fico_range_high > 631.500000', 'last_fico_range_high > 676.500000', 'loan_amnt > 9812.500000', 'recoveries > 7.880000')
#
# [INFO] Processing rule with conditions: ('last_fico_range_high <= 536.500000', 'last_fico_range_high <= 581.500000', 'loan_amnt <= 36012.500000', 'mort_acc <= 0.500000', 'recoveries <= 23.610001')
#
# [INFO] Processing rule with conditions: ('last_fico_range_high <= 536.500000', 'last_fico_range_high <= 581.500000', 'loan_amnt > 36012.500000', 'mort_acc <= 0.500000', 'recoveries <= 23.610001')
#
# [INFO] Processing rule with conditions: ('last_fico_range_high <= 536.500000', 'last_fico_range_high <= 581.500000', 'loan_amnt <= 36012.500000', 'mort_acc > 0.500000', 'recoveries <= 23.610001')
#
# [INFO] Processing rule with conditions: ('last_fico_range_high <= 536.500000', 'last_fico_range_high <= 581.500000', 'loan_amnt > 36012.500000', 'mort_acc > 0.500000', 'recoveries <= 23.610001')
#
# [INFO] Processing rule with conditions: ('last_fico_range_high <= 536.500000', 'last_fico_range_high > 581.500000', 'loan_amnt > 36012.500000', 'mort_acc <= 0.500000', 'recoveries <= 23.610001')
#
# [INFO] Processing rule with conditions: ('last_fico_range_high <= 536.500000', 'last_fico_range_high > 581.500000', 'loan_amnt > 36012.500000', 'mort_acc > 0.500000', 'recoveries <= 23.610001')
#
# [INFO] Processing rule with conditions: ('last_fico_range_high <= 536.500000', 'last_fico_range_high <= 581.500000', 'loan_amnt <= 36012.500000', 'mort_acc <= 0.500000', 'recoveries > 23.610001')
#
# [INFO] Processing rule with conditions: ('last_fico_range_high <= 536.500000', 'last_fico_range_high <= 581.500000', 'loan_amnt > 36012.500000', 'mort_acc <= 0.500000', 'recoveries > 23.610001')
#
# [INFO] Processing rule with conditions: ('last_fico_range_high <= 536.500000', 'last_fico_range_high <= 581.500000', 'loan_amnt <= 36012.500000', 'mort_acc > 0.500000', 'recoveries > 23.610001')
#
# [INFO] Processing rule with conditions: ('last_fico_range_high <= 536.500000', 'last_fico_range_high <= 581.500000', 'loan_amnt > 36012.500000', 'mort_acc > 0.500000', 'recoveries > 23.610001')
#
# [INFO] Processing rule with conditions: ('last_fico_range_high <= 536.500000', 'last_fico_range_high > 581.500000', 'loan_amnt > 36012.500000', 'mort_acc <= 0.500000', 'recoveries > 23.610001')
#
# [INFO] Processing rule with conditions: ('last_fico_range_high <= 536.500000', 'last_fico_range_high > 581.500000', 'loan_amnt > 36012.500000', 'mort_acc > 0.500000', 'recoveries > 23.610001')
#
# [INFO] Processing rule with conditions: ('last_fico_range_high <= 581.500000', 'last_fico_range_high > 536.500000', 'loan_amnt <= 36012.500000', 'mort_acc <= 0.500000', 'recoveries <= 23.610001')
#
# [INFO] Processing rule with conditions: ('last_fico_range_high <= 581.500000', 'last_fico_range_high > 536.500000', 'loan_amnt > 36012.500000', 'mort_acc <= 0.500000', 'recoveries <= 23.610001')
#
# [INFO] Processing rule with conditions: ('last_fico_range_high <= 581.500000', 'last_fico_range_high > 536.500000', 'loan_amnt <= 36012.500000', 'mort_acc > 0.500000', 'recoveries <= 23.610001')
#
# [INFO] Processing rule with conditions: ('last_fico_range_high <= 581.500000', 'last_fico_range_high > 536.500000', 'loan_amnt > 36012.500000', 'mort_acc > 0.500000', 'recoveries <= 23.610001')
#
# [INFO] Processing rule with conditions: ('last_fico_range_high > 536.500000', 'last_fico_range_high > 581.500000', 'loan_amnt > 36012.500000', 'mort_acc <= 0.500000', 'recoveries <= 23.610001')
#
# [INFO] Processing rule with conditions: ('last_fico_range_high > 536.500000', 'last_fico_range_high > 581.500000', 'loan_amnt > 36012.500000', 'mort_acc > 0.500000', 'recoveries <= 23.610001')
#
# [INFO] Processing rule with conditions: ('last_fico_range_high <= 581.500000', 'last_fico_range_high > 536.500000', 'loan_amnt <= 36012.500000', 'mort_acc <= 0.500000', 'recoveries > 23.610001')
#
# [INFO] Processing rule with conditions: ('last_fico_range_high <= 581.500000', 'last_fico_range_high > 536.500000', 'loan_amnt > 36012.500000', 'mort_acc <= 0.500000', 'recoveries > 23.610001')
#
# [INFO] Processing rule with conditions: ('last_fico_range_high <= 581.500000', 'last_fico_range_high > 536.500000', 'loan_amnt <= 36012.500000', 'mort_acc > 0.500000', 'recoveries > 23.610001')
#
# [INFO] Processing rule with conditions: ('last_fico_range_high <= 581.500000', 'last_fico_range_high > 536.500000', 'loan_amnt > 36012.500000', 'mort_acc > 0.500000', 'recoveries > 23.610001')
#
# [INFO] Processing rule with conditions: ('last_fico_range_high > 536.500000', 'last_fico_range_high > 581.500000', 'loan_amnt > 36012.500000', 'mort_acc <= 0.500000', 'recoveries > 23.610001')
#
# [INFO] Processing rule with conditions: ('last_fico_range_high > 536.500000', 'last_fico_range_high > 581.500000', 'loan_amnt > 36012.500000', 'mort_acc > 0.500000', 'recoveries > 23.610001')
#
# [INFO] Processing rule with conditions: ('dti <= 35.665001', 'last_fico_range_high <= 249.500000', 'last_fico_range_high <= 601.500000', 'recoveries <= 396.714996', 'total_rec_late_fee <= 15.395000')
#
# [INFO] Processing rule with conditions: ('dti > 35.665001', 'last_fico_range_high <= 249.500000', 'last_fico_range_high <= 601.500000', 'recoveries <= 396.714996', 'total_rec_late_fee <= 15.395000')
#
# [INFO] Processing rule with conditions: ('dti <= 35.665001', 'last_fico_range_high <= 249.500000', 'last_fico_range_high > 601.500000', 'recoveries <= 396.714996', 'total_rec_late_fee <= 15.395000')
#
# [INFO] Processing rule with conditions: ('dti > 35.665001', 'last_fico_range_high <= 249.500000', 'last_fico_range_high > 601.500000', 'recoveries <= 396.714996', 'total_rec_late_fee <= 15.395000')
#
# [INFO] Processing rule with conditions: ('dti <= 35.665001', 'last_fico_range_high <= 249.500000', 'last_fico_range_high <= 601.500000', 'recoveries > 396.714996', 'total_rec_late_fee <= 15.395000')
#
# [INFO] Processing rule with conditions: ('dti > 35.665001', 'last_fico_range_high <= 249.500000', 'last_fico_range_high <= 601.500000', 'recoveries > 396.714996', 'total_rec_late_fee <= 15.395000')
#
# [INFO] Processing rule with conditions: ('dti <= 35.665001', 'last_fico_range_high <= 249.500000', 'last_fico_range_high > 601.500000', 'recoveries > 396.714996', 'total_rec_late_fee <= 15.395000')
#
# [INFO] Processing rule with conditions: ('dti > 35.665001', 'last_fico_range_high <= 249.500000', 'last_fico_range_high > 601.500000', 'recoveries > 396.714996', 'total_rec_late_fee <= 15.395000')
#
# [INFO] Processing rule with conditions: ('dti > 35.665001', 'last_fico_range_high <= 249.500000', 'last_fico_range_high <= 601.500000', 'recoveries <= 396.714996', 'total_rec_late_fee > 15.395000')
#
# [INFO] Processing rule with conditions: ('dti > 35.665001', 'last_fico_range_high <= 249.500000', 'last_fico_range_high > 601.500000', 'recoveries <= 396.714996', 'total_rec_late_fee > 15.395000')
#
# [INFO] Processing rule with conditions: ('dti > 35.665001', 'last_fico_range_high <= 249.500000', 'last_fico_range_high <= 601.500000', 'recoveries > 396.714996', 'total_rec_late_fee > 15.395000')
#
# [INFO] Processing rule with conditions: ('dti > 35.665001', 'last_fico_range_high <= 249.500000', 'last_fico_range_high > 601.500000', 'recoveries > 396.714996', 'total_rec_late_fee > 15.395000')
#
# [INFO] Processing rule with conditions: ('dti > 35.665001', 'last_fico_range_high <= 601.500000', 'last_fico_range_high > 249.500000', 'recoveries <= 396.714996', 'total_rec_late_fee <= 15.395000')
#
# [INFO] Processing rule with conditions: ('dti > 35.665001', 'last_fico_range_high > 249.500000', 'last_fico_range_high > 601.500000', 'recoveries <= 396.714996', 'total_rec_late_fee <= 15.395000')
#
# [INFO] Processing rule with conditions: ('dti > 35.665001', 'last_fico_range_high <= 601.500000', 'last_fico_range_high > 249.500000', 'recoveries > 396.714996', 'total_rec_late_fee <= 15.395000')
#
# [INFO] Processing rule with conditions: ('dti > 35.665001', 'last_fico_range_high > 249.500000', 'last_fico_range_high > 601.500000', 'recoveries > 396.714996', 'total_rec_late_fee <= 15.395000')
#
# [INFO] Processing rule with conditions: ('dti > 35.665001', 'last_fico_range_high <= 601.500000', 'last_fico_range_high > 249.500000', 'recoveries <= 396.714996', 'total_rec_late_fee > 15.395000')
#
# [INFO] Processing rule with conditions: ('dti > 35.665001', 'last_fico_range_high > 249.500000', 'last_fico_range_high > 601.500000', 'recoveries <= 396.714996', 'total_rec_late_fee > 15.395000')
#
# [INFO] Processing rule with conditions: ('dti > 35.665001', 'last_fico_range_high <= 601.500000', 'last_fico_range_high > 249.500000', 'recoveries > 396.714996', 'total_rec_late_fee > 15.395000')
#
# [INFO] Processing rule with conditions: ('dti > 35.665001', 'last_fico_range_high > 249.500000', 'last_fico_range_high > 601.500000', 'recoveries > 396.714996', 'total_rec_late_fee > 15.395000')
#
# [INFO] Processing rule with conditions: ('last_fico_range_high <= 506.500000', 'last_fico_range_high <= 516.500000', 'last_fico_range_high <= 656.500000', 'loan_amnt <= 18987.500000', 'recoveries <= 1.280000')
#
# [INFO] Processing rule with conditions: ('last_fico_range_high <= 506.500000', 'last_fico_range_high <= 516.500000', 'last_fico_range_high > 656.500000', 'loan_amnt <= 18987.500000', 'recoveries <= 1.280000')
#
# [INFO] Processing rule with conditions: ('last_fico_range_high <= 506.500000', 'last_fico_range_high <= 516.500000', 'last_fico_range_high <= 656.500000', 'loan_amnt > 18987.500000', 'recoveries <= 1.280000')
#
# [INFO] Processing rule with conditions: ('last_fico_range_high <= 506.500000', 'last_fico_range_high <= 516.500000', 'last_fico_range_high > 656.500000', 'loan_amnt > 18987.500000', 'recoveries <= 1.280000')
#
# [INFO] Processing rule with conditions: ('last_fico_range_high <= 506.500000', 'last_fico_range_high > 516.500000', 'last_fico_range_high > 656.500000', 'loan_amnt <= 18987.500000', 'recoveries <= 1.280000')
#
# [INFO] Processing rule with conditions: ('last_fico_range_high <= 506.500000', 'last_fico_range_high > 516.500000', 'last_fico_range_high > 656.500000', 'loan_amnt > 18987.500000', 'recoveries <= 1.280000')
#
# [INFO] Processing rule with conditions: ('last_fico_range_high <= 506.500000', 'last_fico_range_high <= 516.500000', 'last_fico_range_high <= 656.500000', 'loan_amnt <= 18987.500000', 'recoveries > 1.280000')
#
# [INFO] Processing rule with conditions: ('last_fico_range_high <= 506.500000', 'last_fico_range_high <= 516.500000', 'last_fico_range_high > 656.500000', 'loan_amnt <= 18987.500000', 'recoveries > 1.280000')
#
# [INFO] Processing rule with conditions: ('last_fico_range_high <= 506.500000', 'last_fico_range_high <= 516.500000', 'last_fico_range_high <= 656.500000', 'loan_amnt > 18987.500000', 'recoveries > 1.280000')
#
# [INFO] Processing rule with conditions: ('last_fico_range_high <= 506.500000', 'last_fico_range_high <= 516.500000', 'last_fico_range_high > 656.500000', 'loan_amnt > 18987.500000', 'recoveries > 1.280000')
#
# [INFO] Processing rule with conditions: ('last_fico_range_high <= 506.500000', 'last_fico_range_high > 516.500000', 'last_fico_range_high > 656.500000', 'loan_amnt <= 18987.500000', 'recoveries > 1.280000')
#
# [INFO] Processing rule with conditions: ('last_fico_range_high <= 506.500000', 'last_fico_range_high > 516.500000', 'last_fico_range_high > 656.500000', 'loan_amnt > 18987.500000', 'recoveries > 1.280000')
#
# [INFO] Processing rule with conditions: ('last_fico_range_high > 506.500000', 'last_fico_range_high > 516.500000', 'last_fico_range_high > 656.500000', 'loan_amnt <= 18987.500000', 'recoveries <= 1.280000')
#
# [INFO] Processing rule with conditions: ('last_fico_range_high > 506.500000', 'last_fico_range_high > 516.500000', 'last_fico_range_high > 656.500000', 'loan_amnt > 18987.500000', 'recoveries <= 1.280000')
#
# [INFO] Processing rule with conditions: ('last_fico_range_high > 506.500000', 'last_fico_range_high > 516.500000', 'last_fico_range_high > 656.500000', 'loan_amnt <= 18987.500000', 'recoveries > 1.280000')
#
# [INFO] Processing rule with conditions: ('last_fico_range_high > 506.500000', 'last_fico_range_high > 516.500000', 'last_fico_range_high > 656.500000', 'loan_amnt > 18987.500000', 'recoveries > 1.280000')
#
# [INFO] Processing rule with conditions: ('last_fico_range_high <= 616.500000', 'last_fico_range_high <= 631.500000', 'recoveries <= 0.005000', 'term_num <= 48.000000', 'verification_status <= 1.500000')
#
# [INFO] Processing rule with conditions: ('last_fico_range_high <= 616.500000', 'last_fico_range_high <= 631.500000', 'recoveries <= 0.005000', 'term_num > 48.000000', 'verification_status <= 1.500000')
#
# [INFO] Processing rule with conditions: ('last_fico_range_high <= 631.500000', 'last_fico_range_high > 616.500000', 'recoveries <= 0.005000', 'term_num <= 48.000000', 'verification_status <= 1.500000')
#
# [INFO] Processing rule with conditions: ('last_fico_range_high <= 631.500000', 'last_fico_range_high > 616.500000', 'recoveries <= 0.005000', 'term_num > 48.000000', 'verification_status <= 1.500000')
#
# [INFO] Processing rule with conditions: ('last_fico_range_high <= 631.500000', 'last_fico_range_high > 616.500000', 'recoveries > 0.005000', 'term_num <= 48.000000', 'verification_status <= 1.500000')
#
# [INFO] Processing rule with conditions: ('last_fico_range_high <= 631.500000', 'last_fico_range_high > 616.500000', 'recoveries > 0.005000', 'term_num > 48.000000', 'verification_status <= 1.500000')
#
# [INFO] Processing rule with conditions: ('last_fico_range_high <= 616.500000', 'last_fico_range_high > 631.500000', 'recoveries <= 0.005000', 'term_num <= 48.000000', 'verification_status <= 1.500000')
#
# [INFO] Processing rule with conditions: ('last_fico_range_high <= 616.500000', 'last_fico_range_high > 631.500000', 'recoveries <= 0.005000', 'term_num > 48.000000', 'verification_status <= 1.500000')
#
# [INFO] Processing rule with conditions: ('last_fico_range_high > 616.500000', 'last_fico_range_high > 631.500000', 'recoveries <= 0.005000', 'term_num <= 48.000000', 'verification_status <= 1.500000')
#
# [INFO] Processing rule with conditions: ('last_fico_range_high > 616.500000', 'last_fico_range_high > 631.500000', 'recoveries <= 0.005000', 'term_num > 48.000000', 'verification_status <= 1.500000')
#
# [INFO] Processing rule with conditions: ('last_fico_range_high > 616.500000', 'last_fico_range_high > 631.500000', 'recoveries > 0.005000', 'term_num <= 48.000000', 'verification_status <= 1.500000')
#
# [INFO] Processing rule with conditions: ('last_fico_range_high > 616.500000', 'last_fico_range_high > 631.500000', 'recoveries > 0.005000', 'term_num > 48.000000', 'verification_status <= 1.500000')
#
# [INFO] Processing rule with conditions: ('last_fico_range_high <= 616.500000', 'last_fico_range_high <= 631.500000', 'recoveries <= 0.005000', 'term_num <= 48.000000', 'verification_status > 1.500000')
#
# [INFO] Processing rule with conditions: ('last_fico_range_high <= 616.500000', 'last_fico_range_high <= 631.500000', 'recoveries <= 0.005000', 'term_num > 48.000000', 'verification_status > 1.500000')
#
# [INFO] Processing rule with conditions: ('last_fico_range_high <= 631.500000', 'last_fico_range_high > 616.500000', 'recoveries <= 0.005000', 'term_num <= 48.000000', 'verification_status > 1.500000')
#
# [INFO] Processing rule with conditions: ('last_fico_range_high <= 631.500000', 'last_fico_range_high > 616.500000', 'recoveries <= 0.005000', 'term_num > 48.000000', 'verification_status > 1.500000')
#
# [INFO] Processing rule with conditions: ('last_fico_range_high <= 631.500000', 'last_fico_range_high > 616.500000', 'recoveries > 0.005000', 'term_num <= 48.000000', 'verification_status > 1.500000')
#
# [INFO] Processing rule with conditions: ('last_fico_range_high <= 631.500000', 'last_fico_range_high > 616.500000', 'recoveries > 0.005000', 'term_num > 48.000000', 'verification_status > 1.500000')
#
# [INFO] Processing rule with conditions: ('last_fico_range_high <= 616.500000', 'last_fico_range_high > 631.500000', 'recoveries <= 0.005000', 'term_num <= 48.000000', 'verification_status > 1.500000')
#
# [INFO] Processing rule with conditions: ('last_fico_range_high <= 616.500000', 'last_fico_range_high > 631.500000', 'recoveries <= 0.005000', 'term_num > 48.000000', 'verification_status > 1.500000')
#
# [INFO] Processing rule with conditions: ('last_fico_range_high > 616.500000', 'last_fico_range_high > 631.500000', 'recoveries <= 0.005000', 'term_num <= 48.000000', 'verification_status > 1.500000')
#
# [INFO] Processing rule with conditions: ('last_fico_range_high > 616.500000', 'last_fico_range_high > 631.500000', 'recoveries <= 0.005000', 'term_num > 48.000000', 'verification_status > 1.500000')
#
# [INFO] Processing rule with conditions: ('last_fico_range_high > 616.500000', 'last_fico_range_high > 631.500000', 'recoveries > 0.005000', 'term_num <= 48.000000', 'verification_status > 1.500000')
#
# [INFO] Processing rule with conditions: ('last_fico_range_high > 616.500000', 'last_fico_range_high > 631.500000', 'recoveries > 0.005000', 'term_num > 48.000000', 'verification_status > 1.500000')
#
# [INFO] Processing rule with conditions: ('acc_open_past_24mths <= 7.500000', 'dti <= 14.434999', 'last_fico_range_high <= 581.500000', 'last_fico_range_high <= 651.500000', 'recoveries <= 5.350000')
#
# [INFO] Processing rule with conditions: ('acc_open_past_24mths <= 7.500000', 'dti <= 14.434999', 'last_fico_range_high <= 581.500000', 'last_fico_range_high <= 651.500000', 'recoveries > 5.350000')
#
# [INFO] Processing rule with conditions: ('acc_open_past_24mths <= 7.500000', 'dti <= 14.434999', 'last_fico_range_high <= 651.500000', 'last_fico_range_high > 581.500000', 'recoveries <= 5.350000')
#
# [INFO] Processing rule with conditions: ('acc_open_past_24mths <= 7.500000', 'dti <= 14.434999', 'last_fico_range_high <= 651.500000', 'last_fico_range_high > 581.500000', 'recoveries > 5.350000')
#
# [INFO] Processing rule with conditions: ('acc_open_past_24mths <= 7.500000', 'dti > 14.434999', 'last_fico_range_high <= 651.500000', 'last_fico_range_high > 581.500000', 'recoveries <= 5.350000')
#
# [INFO] Processing rule with conditions: ('acc_open_past_24mths <= 7.500000', 'dti > 14.434999', 'last_fico_range_high <= 651.500000', 'last_fico_range_high > 581.500000', 'recoveries > 5.350000')
#
# [INFO] Processing rule with conditions: ('acc_open_past_24mths <= 7.500000', 'dti <= 14.434999', 'last_fico_range_high <= 581.500000', 'last_fico_range_high > 651.500000', 'recoveries <= 5.350000')
#
# [INFO] Processing rule with conditions: ('acc_open_past_24mths <= 7.500000', 'dti <= 14.434999', 'last_fico_range_high <= 581.500000', 'last_fico_range_high > 651.500000', 'recoveries > 5.350000')
#
# [INFO] Processing rule with conditions: ('acc_open_past_24mths <= 7.500000', 'dti <= 14.434999', 'last_fico_range_high > 581.500000', 'last_fico_range_high > 651.500000', 'recoveries <= 5.350000')
#
# [INFO] Processing rule with conditions: ('acc_open_past_24mths <= 7.500000', 'dti <= 14.434999', 'last_fico_range_high > 581.500000', 'last_fico_range_high > 651.500000', 'recoveries > 5.350000')
#
# [INFO] Processing rule with conditions: ('acc_open_past_24mths <= 7.500000', 'dti > 14.434999', 'last_fico_range_high > 581.500000', 'last_fico_range_high > 651.500000', 'recoveries <= 5.350000')
#
# [INFO] Processing rule with conditions: ('acc_open_past_24mths <= 7.500000', 'dti > 14.434999', 'last_fico_range_high > 581.500000', 'last_fico_range_high > 651.500000', 'recoveries > 5.350000')
#
# [INFO] Processing rule with conditions: ('acc_open_past_24mths > 7.500000', 'dti <= 14.434999', 'last_fico_range_high <= 581.500000', 'last_fico_range_high <= 651.500000', 'recoveries <= 5.350000')
#
# [INFO] Processing rule with conditions: ('acc_open_past_24mths > 7.500000', 'dti <= 14.434999', 'last_fico_range_high <= 581.500000', 'last_fico_range_high <= 651.500000', 'recoveries > 5.350000')
#
# [INFO] Processing rule with conditions: ('acc_open_past_24mths > 7.500000', 'dti <= 14.434999', 'last_fico_range_high <= 651.500000', 'last_fico_range_high > 581.500000', 'recoveries <= 5.350000')
#
# [INFO] Processing rule with conditions: ('acc_open_past_24mths > 7.500000', 'dti <= 14.434999', 'last_fico_range_high <= 651.500000', 'last_fico_range_high > 581.500000', 'recoveries > 5.350000')
#
# [INFO] Processing rule with conditions: ('acc_open_past_24mths > 7.500000', 'dti > 14.434999', 'last_fico_range_high <= 651.500000', 'last_fico_range_high > 581.500000', 'recoveries <= 5.350000')
#
# [INFO] Processing rule with conditions: ('acc_open_past_24mths > 7.500000', 'dti > 14.434999', 'last_fico_range_high <= 651.500000', 'last_fico_range_high > 581.500000', 'recoveries > 5.350000')
#
# [INFO] Processing rule with conditions: ('acc_open_past_24mths > 7.500000', 'dti <= 14.434999', 'last_fico_range_high <= 581.500000', 'last_fico_range_high > 651.500000', 'recoveries <= 5.350000')
#
# [INFO] Processing rule with conditions: ('acc_open_past_24mths > 7.500000', 'dti <= 14.434999', 'last_fico_range_high <= 581.500000', 'last_fico_range_high > 651.500000', 'recoveries > 5.350000')
#
# [INFO] Processing rule with conditions: ('acc_open_past_24mths > 7.500000', 'dti <= 14.434999', 'last_fico_range_high > 581.500000', 'last_fico_range_high > 651.500000', 'recoveries <= 5.350000')
#
# [INFO] Processing rule with conditions: ('acc_open_past_24mths > 7.500000', 'dti <= 14.434999', 'last_fico_range_high > 581.500000', 'last_fico_range_high > 651.500000', 'recoveries > 5.350000')
#
# [INFO] Processing rule with conditions: ('acc_open_past_24mths > 7.500000', 'dti > 14.434999', 'last_fico_range_high > 581.500000', 'last_fico_range_high > 651.500000', 'recoveries <= 5.350000')
#
# [INFO] Processing rule with conditions: ('acc_open_past_24mths > 7.500000', 'dti > 14.434999', 'last_fico_range_high > 581.500000', 'last_fico_range_high > 651.500000', 'recoveries > 5.350000')
#
# [INFO] Processing rule with conditions: ('dti <= 25.305000', 'grade <= 0.500000', 'last_fico_range_high <= 556.500000', 'last_fico_range_high <= 631.500000', 'recoveries <= 98.959999')
#
# [INFO] Processing rule with conditions: ('dti > 25.305000', 'grade <= 0.500000', 'last_fico_range_high <= 556.500000', 'last_fico_range_high <= 631.500000', 'recoveries <= 98.959999')
#
# [INFO] Processing rule with conditions: ('dti > 25.305000', 'grade > 0.500000', 'last_fico_range_high <= 556.500000', 'last_fico_range_high <= 631.500000', 'recoveries <= 98.959999')
#
# [INFO] Processing rule with conditions: ('dti <= 25.305000', 'grade <= 0.500000', 'last_fico_range_high <= 556.500000', 'last_fico_range_high <= 631.500000', 'recoveries > 98.959999')
#
# [INFO] Processing rule with conditions: ('dti > 25.305000', 'grade <= 0.500000', 'last_fico_range_high <= 556.500000', 'last_fico_range_high <= 631.500000', 'recoveries > 98.959999')
#
# [INFO] Processing rule with conditions: ('dti > 25.305000', 'grade > 0.500000', 'last_fico_range_high <= 556.500000', 'last_fico_range_high <= 631.500000', 'recoveries > 98.959999')
#
# [INFO] Processing rule with conditions: ('dti <= 25.305000', 'grade <= 0.500000', 'last_fico_range_high <= 556.500000', 'last_fico_range_high > 631.500000', 'recoveries <= 98.959999')
#
# [INFO] Processing rule with conditions: ('dti > 25.305000', 'grade <= 0.500000', 'last_fico_range_high <= 556.500000', 'last_fico_range_high > 631.500000', 'recoveries <= 98.959999')
#
# [INFO] Processing rule with conditions: ('dti > 25.305000', 'grade > 0.500000', 'last_fico_range_high <= 556.500000', 'last_fico_range_high > 631.500000', 'recoveries <= 98.959999')
#
# [INFO] Processing rule with conditions: ('dti <= 25.305000', 'grade <= 0.500000', 'last_fico_range_high <= 556.500000', 'last_fico_range_high > 631.500000', 'recoveries > 98.959999')
#
# [INFO] Processing rule with conditions: ('dti > 25.305000', 'grade <= 0.500000', 'last_fico_range_high <= 556.500000', 'last_fico_range_high > 631.500000', 'recoveries > 98.959999')
#
# [INFO] Processing rule with conditions: ('dti > 25.305000', 'grade > 0.500000', 'last_fico_range_high <= 556.500000', 'last_fico_range_high > 631.500000', 'recoveries > 98.959999')
#
# [INFO] Processing rule with conditions: ('dti <= 25.305000', 'grade <= 0.500000', 'last_fico_range_high <= 631.500000', 'last_fico_range_high > 556.500000', 'recoveries <= 98.959999')
#
# [INFO] Processing rule with conditions: ('dti > 25.305000', 'grade <= 0.500000', 'last_fico_range_high <= 631.500000', 'last_fico_range_high > 556.500000', 'recoveries <= 98.959999')
#
# [INFO] Processing rule with conditions: ('dti > 25.305000', 'grade > 0.500000', 'last_fico_range_high <= 631.500000', 'last_fico_range_high > 556.500000', 'recoveries <= 98.959999')
#
# [INFO] Processing rule with conditions: ('dti <= 25.305000', 'grade <= 0.500000', 'last_fico_range_high <= 631.500000', 'last_fico_range_high > 556.500000', 'recoveries > 98.959999')
#
# [INFO] Processing rule with conditions: ('dti > 25.305000', 'grade <= 0.500000', 'last_fico_range_high <= 631.500000', 'last_fico_range_high > 556.500000', 'recoveries > 98.959999')
#
# [INFO] Processing rule with conditions: ('dti > 25.305000', 'grade > 0.500000', 'last_fico_range_high <= 631.500000', 'last_fico_range_high > 556.500000', 'recoveries > 98.959999')
#
# [INFO] Processing rule with conditions: ('dti <= 25.305000', 'grade <= 0.500000', 'last_fico_range_high > 556.500000', 'last_fico_range_high > 631.500000', 'recoveries <= 98.959999')
#
# [INFO] Processing rule with conditions: ('dti > 25.305000', 'grade <= 0.500000', 'last_fico_range_high > 556.500000', 'last_fico_range_high > 631.500000', 'recoveries <= 98.959999')
#
# [INFO] Processing rule with conditions: ('dti > 25.305000', 'grade > 0.500000', 'last_fico_range_high > 556.500000', 'last_fico_range_high > 631.500000', 'recoveries <= 98.959999')
#
# [INFO] Processing rule with conditions: ('dti <= 25.305000', 'grade <= 0.500000', 'last_fico_range_high > 556.500000', 'last_fico_range_high > 631.500000', 'recoveries > 98.959999')
#
# [INFO] Processing rule with conditions: ('dti > 25.305000', 'grade <= 0.500000', 'last_fico_range_high > 556.500000', 'last_fico_range_high > 631.500000', 'recoveries > 98.959999')
#
# [INFO] Processing rule with conditions: ('dti > 25.305000', 'grade > 0.500000', 'last_fico_range_high > 556.500000', 'last_fico_range_high > 631.500000', 'recoveries > 98.959999')
#
# [INFO] Processing rule with conditions: ('fico_range_low <= 762.500000', 'grade <= 2.500000', 'last_fico_range_high <= 721.500000', 'loan_amnt <= 8987.500000', 'term_num <= 48.000000')
#
# [INFO] Processing rule with conditions: ('fico_range_low <= 762.500000', 'grade <= 2.500000', 'last_fico_range_high <= 721.500000', 'loan_amnt > 8987.500000', 'term_num <= 48.000000')
#
# [INFO] Processing rule with conditions: ('fico_range_low <= 762.500000', 'grade > 2.500000', 'last_fico_range_high <= 721.500000', 'loan_amnt <= 8987.500000', 'term_num <= 48.000000')
#
# [INFO] Processing rule with conditions: ('fico_range_low <= 762.500000', 'grade > 2.500000', 'last_fico_range_high <= 721.500000', 'loan_amnt > 8987.500000', 'term_num <= 48.000000')
#
# [INFO] Processing rule with conditions: ('fico_range_low <= 762.500000', 'grade <= 2.500000', 'last_fico_range_high <= 721.500000', 'loan_amnt <= 8987.500000', 'term_num > 48.000000')
#
# [INFO] Processing rule with conditions: ('fico_range_low <= 762.500000', 'grade <= 2.500000', 'last_fico_range_high <= 721.500000', 'loan_amnt > 8987.500000', 'term_num > 48.000000')
#
# [INFO] Processing rule with conditions: ('fico_range_low <= 762.500000', 'grade > 2.500000', 'last_fico_range_high <= 721.500000', 'loan_amnt <= 8987.500000', 'term_num > 48.000000')
#
# [INFO] Processing rule with conditions: ('fico_range_low <= 762.500000', 'grade > 2.500000', 'last_fico_range_high <= 721.500000', 'loan_amnt > 8987.500000', 'term_num > 48.000000')
#
# [INFO] Processing rule with conditions: ('fico_range_low <= 762.500000', 'grade <= 2.500000', 'last_fico_range_high > 721.500000', 'loan_amnt <= 8987.500000', 'term_num <= 48.000000')
#
# [INFO] Processing rule with conditions: ('fico_range_low <= 762.500000', 'grade <= 2.500000', 'last_fico_range_high > 721.500000', 'loan_amnt > 8987.500000', 'term_num <= 48.000000')
#
# [INFO] Processing rule with conditions: ('fico_range_low <= 762.500000', 'grade > 2.500000', 'last_fico_range_high > 721.500000', 'loan_amnt <= 8987.500000', 'term_num <= 48.000000')
#
# [INFO] Processing rule with conditions: ('fico_range_low <= 762.500000', 'grade > 2.500000', 'last_fico_range_high > 721.500000', 'loan_amnt > 8987.500000', 'term_num <= 48.000000')
#
# [INFO] Processing rule with conditions: ('fico_range_low <= 762.500000', 'grade <= 2.500000', 'last_fico_range_high > 721.500000', 'loan_amnt <= 8987.500000', 'term_num > 48.000000')
#
# [INFO] Processing rule with conditions: ('fico_range_low <= 762.500000', 'grade <= 2.500000', 'last_fico_range_high > 721.500000', 'loan_amnt > 8987.500000', 'term_num > 48.000000')
#
# [INFO] Processing rule with conditions: ('fico_range_low <= 762.500000', 'grade > 2.500000', 'last_fico_range_high > 721.500000', 'loan_amnt <= 8987.500000', 'term_num > 48.000000')
#
# [INFO] Processing rule with conditions: ('fico_range_low <= 762.500000', 'grade > 2.500000', 'last_fico_range_high > 721.500000', 'loan_amnt > 8987.500000', 'term_num > 48.000000')
#
# [INFO] Processing rule with conditions: ('fico_range_low > 762.500000', 'grade <= 2.500000', 'last_fico_range_high <= 721.500000', 'loan_amnt <= 8987.500000', 'term_num <= 48.000000')
#
# [INFO] Processing rule with conditions: ('fico_range_low > 762.500000', 'grade <= 2.500000', 'last_fico_range_high <= 721.500000', 'loan_amnt > 8987.500000', 'term_num <= 48.000000')
#
# [INFO] Processing rule with conditions: ('fico_range_low > 762.500000', 'grade > 2.500000', 'last_fico_range_high <= 721.500000', 'loan_amnt <= 8987.500000', 'term_num <= 48.000000')
#
# [INFO] Processing rule with conditions: ('fico_range_low > 762.500000', 'grade > 2.500000', 'last_fico_range_high <= 721.500000', 'loan_amnt > 8987.500000', 'term_num <= 48.000000')
#
# [INFO] Processing rule with conditions: ('fico_range_low > 762.500000', 'grade <= 2.500000', 'last_fico_range_high <= 721.500000', 'loan_amnt <= 8987.500000', 'term_num > 48.000000')
#
# [INFO] Processing rule with conditions: ('fico_range_low > 762.500000', 'grade <= 2.500000', 'last_fico_range_high <= 721.500000', 'loan_amnt > 8987.500000', 'term_num > 48.000000')
#
# [INFO] Processing rule with conditions: ('fico_range_low > 762.500000', 'grade > 2.500000', 'last_fico_range_high <= 721.500000', 'loan_amnt <= 8987.500000', 'term_num > 48.000000')
#
# [INFO] Processing rule with conditions: ('fico_range_low > 762.500000', 'grade > 2.500000', 'last_fico_range_high <= 721.500000', 'loan_amnt > 8987.500000', 'term_num > 48.000000')
#
# [INFO] Processing rule with conditions: ('fico_range_low > 762.500000', 'grade <= 2.500000', 'last_fico_range_high > 721.500000', 'loan_amnt <= 8987.500000', 'term_num <= 48.000000')
#
# [INFO] Processing rule with conditions: ('fico_range_low > 762.500000', 'grade <= 2.500000', 'last_fico_range_high > 721.500000', 'loan_amnt > 8987.500000', 'term_num <= 48.000000')
#
# [INFO] Processing rule with conditions: ('fico_range_low > 762.500000', 'grade > 2.500000', 'last_fico_range_high > 721.500000', 'loan_amnt <= 8987.500000', 'term_num <= 48.000000')
#
# [INFO] Processing rule with conditions: ('fico_range_low > 762.500000', 'grade > 2.500000', 'last_fico_range_high > 721.500000', 'loan_amnt > 8987.500000', 'term_num <= 48.000000')
#
# [INFO] Processing rule with conditions: ('fico_range_low > 762.500000', 'grade <= 2.500000', 'last_fico_range_high > 721.500000', 'loan_amnt <= 8987.500000', 'term_num > 48.000000')
#
# [INFO] Processing rule with conditions: ('fico_range_low > 762.500000', 'grade <= 2.500000', 'last_fico_range_high > 721.500000', 'loan_amnt > 8987.500000', 'term_num > 48.000000')
#
# [INFO] Processing rule with conditions: ('fico_range_low > 762.500000', 'grade > 2.500000', 'last_fico_range_high > 721.500000', 'loan_amnt <= 8987.500000', 'term_num > 48.000000')
#
# [INFO] Processing rule with conditions: ('fico_range_low > 762.500000', 'grade > 2.500000', 'last_fico_range_high > 721.500000', 'loan_amnt > 8987.500000', 'term_num > 48.000000')
#
# [INFO] Processing rule with conditions: ('last_fico_range_high <= 631.500000', 'last_fico_range_high <= 641.500000', 'last_fico_range_high <= 676.500000', 'loan_amnt <= 3712.500000', 'recoveries <= 1.280000')
#
# [INFO] Processing rule with conditions: ('last_fico_range_high <= 631.500000', 'last_fico_range_high <= 641.500000', 'last_fico_range_high <= 676.500000', 'loan_amnt <= 3712.500000', 'recoveries > 1.280000')
#
# [INFO] Processing rule with conditions: ('last_fico_range_high <= 631.500000', 'last_fico_range_high <= 641.500000', 'last_fico_range_high > 676.500000', 'loan_amnt <= 3712.500000', 'recoveries <= 1.280000')
#
# [INFO] Processing rule with conditions: ('last_fico_range_high <= 631.500000', 'last_fico_range_high <= 641.500000', 'last_fico_range_high > 676.500000', 'loan_amnt <= 3712.500000', 'recoveries > 1.280000')
#
# [INFO] Processing rule with conditions: ('last_fico_range_high <= 631.500000', 'last_fico_range_high > 641.500000', 'last_fico_range_high > 676.500000', 'loan_amnt <= 3712.500000', 'recoveries <= 1.280000')
#
# [INFO] Processing rule with conditions: ('last_fico_range_high <= 631.500000', 'last_fico_range_high > 641.500000', 'last_fico_range_high > 676.500000', 'loan_amnt <= 3712.500000', 'recoveries > 1.280000')
#
# [INFO] Processing rule with conditions: ('last_fico_range_high > 631.500000', 'last_fico_range_high > 641.500000', 'last_fico_range_high > 676.500000', 'loan_amnt <= 3712.500000', 'recoveries <= 1.280000')
#
# [INFO] Processing rule with conditions: ('last_fico_range_high > 631.500000', 'last_fico_range_high > 641.500000', 'last_fico_range_high > 676.500000', 'loan_amnt <= 3712.500000', 'recoveries > 1.280000')
#
# [INFO] Processing rule with conditions: ('last_fico_range_high <= 631.500000', 'last_fico_range_high <= 641.500000', 'last_fico_range_high <= 676.500000', 'loan_amnt > 3712.500000', 'recoveries <= 1.280000')
#
# [INFO] Processing rule with conditions: ('last_fico_range_high <= 631.500000', 'last_fico_range_high <= 641.500000', 'last_fico_range_high <= 676.500000', 'loan_amnt > 3712.500000', 'recoveries > 1.280000')
#
# [INFO] Processing rule with conditions: ('last_fico_range_high <= 631.500000', 'last_fico_range_high <= 641.500000', 'last_fico_range_high > 676.500000', 'loan_amnt > 3712.500000', 'recoveries <= 1.280000')
#
# [INFO] Processing rule with conditions: ('last_fico_range_high <= 631.500000', 'last_fico_range_high <= 641.500000', 'last_fico_range_high > 676.500000', 'loan_amnt > 3712.500000', 'recoveries > 1.280000')
#
# [INFO] Processing rule with conditions: ('last_fico_range_high <= 631.500000', 'last_fico_range_high > 641.500000', 'last_fico_range_high > 676.500000', 'loan_amnt > 3712.500000', 'recoveries <= 1.280000')
#
# [INFO] Processing rule with conditions: ('last_fico_range_high <= 631.500000', 'last_fico_range_high > 641.500000', 'last_fico_range_high > 676.500000', 'loan_amnt > 3712.500000', 'recoveries > 1.280000')
#
# ...
#   'confidence': 4.440315,
#   'support': np.float64(1e-06),
#   'precision': np.float64(1.0),
#   'purity': np.float64(1.0),
#   'quality_score': np.float64(1.0),
#   'samples_covered': 1,
#   'class_0_count': 0,
#   'class_1_count': 1,
#   'features_involved': ['fico_range_low',
#    'grade',
#    'last_fico_range_high',
#    'loan_amnt',
#    'total_rec_late_fee'],
#   'feature_count': 5,
#   'condition_count': 5,
#   'tp': 1,
#   'fp': 0},
#  {'tree_idx': 40,
#   'leaf_idx': 24,
#   'rule_conditions': ['total_rec_late_fee > 453.289978',
#    'grade > 5.500000',
#    'fico_range_low <= 807.500000',
#    'loan_amnt <= 32512.500000',
#    'last_fico_range_high <= 641.500000'],
#   'logit_score': -0.004244072022428296,
#   'predicted_class': 0,
#   'confidence': 0.004244,
#   'support': np.float64(0.040186),
#   'precision': np.float64(0.9557),
#   'purity': np.float64(0.9557),
#   'quality_score': np.float64(0.9557),
#   'samples_covered': 52421,
#   'class_0_count': 50099,
#   'class_1_count': 2322,
#   'features_involved': ['fico_range_low',
#    'grade',
#    'last_fico_range_high',
#    'loan_amnt',
#    'total_rec_late_fee'],
#   'feature_count': 5,
#   'condition_count': 5,
#   'tp': 50099,
#   'fp': 2322},
#  {'tree_idx': 40,
#   'leaf_idx': 25,
#   'rule_conditions': ['total_rec_late_fee > 453.289978',
#    'grade > 5.500000',
#    'fico_range_low <= 807.500000',
#    'loan_amnt <= 32512.500000',
#    'last_fico_range_high > 641.500000'],
#   'logit_score': -2.515667004947165,
#   'predicted_class': 0,
#   'confidence': 2.515667,
#   'support': np.float64(2.8e-05),
#   'precision': np.float64(0.9722),
#   'purity': np.float64(0.9722),
#   'quality_score': np.float64(0.9722),
#   'samples_covered': 36,
#   'class_0_count': 35,
#   'class_1_count': 1,
#   'features_involved': ['fico_range_low',
#    'grade',
#    'last_fico_range_high',
#    'loan_amnt',
#    'total_rec_late_fee'],
#   'feature_count': 5,
#   'condition_count': 5,
#   'tp': 35,
#   'fp': 1},
#  {'tree_idx': 40,
#   'leaf_idx': 26,
#   'rule_conditions': ['total_rec_late_fee > 453.289978',
#    'grade > 5.500000',
#    'fico_range_low <= 807.500000',
#    'loan_amnt > 32512.500000',
#    'last_fico_range_high <= 641.500000'],
#   'logit_score': 0.3037799969512308,
#   'predicted_class': 1,
#   'confidence': 0.30378,
#   'support': np.float64(0.000357),
#   'precision': np.float64(0.1245),
#   'purity': np.float64(0.1245),
#   'quality_score': np.float64(0.1245),
#   'samples_covered': 466,
#   'class_0_count': 408,
#   'class_1_count': 58,
#   'features_involved': ['fico_range_low',
#    'grade',
#    'last_fico_range_high',
#    'loan_amnt',
#    'total_rec_late_fee'],
#   'feature_count': 5,
#   'condition_count': 5,
#   'tp': 58,
#   'fp': 408},
#  {'tree_idx': 40,
#   'leaf_idx': 28,
#   'rule_conditions': ['total_rec_late_fee > 453.289978',
#    'grade > 5.500000',
#    'fico_range_low > 807.500000',
#    'loan_amnt <= 32512.500000',
#    'last_fico_range_high <= 641.500000'],
#   'logit_score': -0.6196091684163394,
#   'predicted_class': 0,
#   'confidence': 0.619609,
#   'support': np.float64(0.000602),
#   'precision': np.float64(0.9465),
#   'purity': np.float64(0.9465),
#   'quality_score': np.float64(0.9465),
#   'samples_covered': 785,
#   'class_0_count': 743,
#   'class_1_count': 42,
#   'features_involved': ['fico_range_low',
#    'grade',
#    'last_fico_range_high',
#    'loan_amnt',
#    'total_rec_late_fee'],
#   'feature_count': 5,
#   'condition_count': 5,
#   'tp': 743,
#   'fp': 42},
#  {'tree_idx': 41,
#   'leaf_idx': 0,
#   'rule_conditions': ['dti <= 35.665001',
#    'last_fico_range_high <= 601.500000',
#    'recoveries <= 0.005000',
#    'last_fico_range_high <= 536.500000',
#    'acc_open_past_24mths <= 14.500000'],
#   'logit_score': -0.00782182702033898,
#   'predicted_class': 0,
#   'confidence': 0.007822,
#   'support': np.float64(0.031937),
#   'precision': np.float64(0.4562),
#   'purity': np.float64(0.4562),
#   'quality_score': np.float64(0.4562),
#   'samples_covered': 41661,
#   'class_0_count': 19004,
#   'class_1_count': 22657,
#   'features_involved': ['acc_open_past_24mths',
#    'dti',
#    'last_fico_range_high',
#    'recoveries'],
#   'feature_count': 4,
#   'condition_count': 5,
#   'tp': 19004,
#   'fp': 22657},
#  {'tree_idx': 41,
#   'leaf_idx': 1,
#   'rule_conditions': ['dti <= 35.665001',
#    'last_fico_range_high <= 601.500000',
#    'recoveries <= 0.005000',
#    'last_fico_range_high <= 536.500000',
#    'acc_open_past_24mths > 14.500000'],
#   'logit_score': -0.016316925881084753,
#   'predicted_class': 0,
#   'confidence': 0.016317,
#   'support': np.float64(0.001071),
#   'precision': np.float64(0.2105),
#   'purity': np.float64(0.2105),
#   'quality_score': np.float64(0.2105),
#   'samples_covered': 1397,
#   'class_0_count': 294,
#   'class_1_count': 1103,
#   'features_involved': ['acc_open_past_24mths',
#    'dti',
#    'last_fico_range_high',
#    'recoveries'],
#   'feature_count': 4,
#   'condition_count': 5,
#   'tp': 294,
#   'fp': 1103},
#  {'tree_idx': 41,
#   'leaf_idx': 4,
#   'rule_conditions': ['dti <= 35.665001',
#    'last_fico_range_high <= 601.500000',
#    'recoveries > 0.005000',
#    'last_fico_range_high <= 536.500000',
#    'acc_open_past_24mths <= 14.500000'],
#   'logit_score': 0.0371640105924492,
#   'predicted_class': 1,
#   'confidence': 0.037164,
#   'support': np.float64(0.041154),
#   'precision': np.float64(1.0),
#   'purity': np.float64(1.0),
#   'quality_score': np.float64(1.0),
#   'samples_covered': 53684,
#   'class_0_count': 0,
#   'class_1_count': 53684,
#   'features_involved': ['acc_open_past_24mths',
#    'dti',
#    'last_fico_range_high',
#    'recoveries'],
#   'feature_count': 4,
#   'condition_count': 5,
#   'tp': 53684,
#   'fp': 0},
#  {'tree_idx': 41,
#   'leaf_idx': 5,
#   'rule_conditions': ['dti <= 35.665001',
#    'last_fico_range_high <= 601.500000',
#    'recoveries > 0.005000',
#    'last_fico_range_high <= 536.500000',
#    'acc_open_past_24mths > 14.500000'],
#   'logit_score': 0.001744037234252657,
#   'predicted_class': 1,
#   'confidence': 0.001744,
#   'support': np.float64(0.001255),
#   'precision': np.float64(1.0),
#   'purity': np.float64(1.0),
#   'quality_score': np.float64(1.0),
#   'samples_covered': 1637,
#   'class_0_count': 0,
#   'class_1_count': 1637,
#   'features_involved': ['acc_open_past_24mths',
#    'dti',
#    'last_fico_range_high',
#    'recoveries'],
#   'feature_count': 4,
#   'condition_count': 5,
#   'tp': 1637,
#   'fp': 0},
#  {'tree_idx': 41,
#   'leaf_idx': 8,
#   'rule_conditions': ['dti <= 35.665001',
#    'last_fico_range_high > 601.500000',
#    'recoveries <= 0.005000',
#    'last_fico_range_high <= 536.500000',
#    'acc_open_past_24mths <= 14.500000'],
#   'logit_score': 0.010318824125719614,
#   'predicted_class': 1,
#   'confidence': 0.010319,
#   'support': np.float64(0.06022),
#   'precision': np.float64(0.2959),
#   'purity': np.float64(0.2959),
#   'quality_score': np.float64(0.2959),
#   'samples_covered': 78555,
#   'class_0_count': 55307,
#   'class_1_count': 23248,
#   'features_involved': ['acc_open_past_24mths',
#    'dti',
#    'last_fico_range_high',
#    'recoveries'],
#   'feature_count': 4,
#   'condition_count': 5,
#   'tp': 23248,
#   'fp': 55307},
#  {'tree_idx': 41,
#   'leaf_idx': 9,
#   'rule_conditions': ['dti <= 35.665001',
#    'last_fico_range_high > 601.500000',
#    'recoveries <= 0.005000',
#    'last_fico_range_high <= 536.500000',
#    'acc_open_past_24mths > 14.500000'],
#   'logit_score': -0.1682484626080076,
#   'predicted_class': 0,
#   'confidence': 0.168248,
#   'support': np.float64(0.00187),
#   'precision': np.float64(0.428),
#   'purity': np.float64(0.428),
#   'quality_score': np.float64(0.428),
#   'samples_covered': 2439,
#   'class_0_count': 1044,
#   'class_1_count': 1395,
#   'features_involved': ['acc_open_past_24mths',
#    'dti',
#    'last_fico_range_high',
#    'recoveries'],
#   'feature_count': 4,
#   'condition_count': 5,
#   'tp': 1044,
#   'fp': 1395},
#  {'tree_idx': 41,
#   'leaf_idx': 10,
#   'rule_conditions': ['dti <= 35.665001',
#    'last_fico_range_high > 601.500000',
#    'recoveries <= 0.005000',
#    'last_fico_range_high > 536.500000',
#    'acc_open_past_24mths <= 14.500000'],
#   'logit_score': -0.0004995252592900798,
#   'predicted_class': 0,
#   'confidence': 0.0005,
#   'support': np.float64(0.734975),
#   'precision': np.float64(0.9809),
#   'purity': np.float64(0.9809),
#   'quality_score': np.float64(0.9809),
#   'samples_covered': 958745,
#   'class_0_count': 940432,
#   'class_1_count': 18313,
#   'features_involved': ['acc_open_past_24mths',
#    'dti',
#    'last_fico_range_high',
#    'recoveries'],
#   'feature_count': 4,
#   'condition_count': 5,
#   'tp': 940432,
#   'fp': 18313},
#  {'tree_idx': 41,
#   'leaf_idx': 11,
#   'rule_conditions': ['dti <= 35.665001',
#    'last_fico_range_high > 601.500000',
#    'recoveries <= 0.005000',
#    'last_fico_range_high > 536.500000',
#    'acc_open_past_24mths > 14.500000'],
#   'logit_score': -0.008720035777823501,
#   'predicted_class': 0,
#   'confidence': 0.00872,
#   'support': np.float64(0.018878),
#   'precision': np.float64(0.9603),
#   'purity': np.float64(0.9603),
#   'quality_score': np.float64(0.9603),
#   'samples_covered': 24625,
#   'class_0_count': 23648,
#   'class_1_count': 977,
#   'features_involved': ['acc_open_past_24mths',
#    'dti',
#    'last_fico_range_high',
#    'recoveries'],
#   'feature_count': 4,
#   'condition_count': 5,
#   'tp': 23648,
#   'fp': 977},
#  {'tree_idx': 41,
#   'leaf_idx': 12,
#   'rule_conditions': ['dti <= 35.665001',
#    'last_fico_range_high > 601.500000',
#    'recoveries > 0.005000',
#    'last_fico_range_high <= 536.500000',
#    'acc_open_past_24mths <= 14.500000'],
#   'logit_score': 0.030000817463165113,
#   'predicted_class': 1,
#   'confidence': 0.030001,
#   'support': np.float64(0.058248),
#   'precision': np.float64(1.0),
#   'purity': np.float64(1.0),
#   'quality_score': np.float64(1.0),
#   'samples_covered': 75982,
#   'class_0_count': 0,
#   'class_1_count': 75982,
#   'features_involved': ['acc_open_past_24mths',
#    'dti',
#    'last_fico_range_high',
#    'recoveries'],
#   'feature_count': 4,
#   'condition_count': 5,
#   'tp': 75982,
#   'fp': 0},
#  {'tree_idx': 41,
#   'leaf_idx': 13,
#   'rule_conditions': ['dti <= 35.665001',
#    'last_fico_range_high > 601.500000',
#    'recoveries > 0.005000',
#    'last_fico_range_high <= 536.500000',
#    'acc_open_past_24mths > 14.500000'],
#   'logit_score': 0.0014796523346683249,
#   'predicted_class': 1,
#   'confidence': 0.00148,
#   'support': np.float64(0.00251),
#   'precision': np.float64(1.0),
#   'purity': np.float64(1.0),
#   'quality_score': np.float64(1.0),
#   'samples_covered': 3274,
#   'class_0_count': 0,
#   'class_1_count': 3274,
#   'features_involved': ['acc_open_past_24mths',
#    'dti',
#    'last_fico_range_high',
#    'recoveries'],
#   'feature_count': 4,
#   'condition_count': 5,
#   'tp': 3274,
#   'fp': 0},
#  {'tree_idx': 41,
#   'leaf_idx': 14,
#   'rule_conditions': ['dti <= 35.665001',
#    'last_fico_range_high > 601.500000',
#    'recoveries > 0.005000',
#    'last_fico_range_high > 536.500000',
#    'acc_open_past_24mths <= 14.500000'],
#   'logit_score': 0.06850883654702801,
#   'predicted_class': 1,
#   'confidence': 0.068509,
#   'support': np.float64(0.035481),
#   'precision': np.float64(1.0),
#   'purity': np.float64(1.0),
#   'quality_score': np.float64(1.0),
#   'samples_covered': 46284,
#   'class_0_count': 0,
#   'class_1_count': 46284,
#   'features_involved': ['acc_open_past_24mths',
#    'dti',
#    'last_fico_range_high',
#    'recoveries'],
#   'feature_count': 4,
#   'condition_count': 5,
#   'tp': 46284,
#   'fp': 0},
#  {'tree_idx': 41,
#   'leaf_idx': 15,
#   'rule_conditions': ['dti <= 35.665001',
#    'last_fico_range_high > 601.500000',
#    'recoveries > 0.005000',
#    'last_fico_range_high > 536.500000',
#    'acc_open_past_24mths > 14.500000'],
#   'logit_score': 0.002212614165421033,
#   'predicted_class': 1,
#   'confidence': 0.002213,
#   'support': np.float64(0.001542),
#   'precision': np.float64(1.0),
#   'purity': np.float64(1.0),
#   'quality_score': np.float64(1.0),
#   'samples_covered': 2011,
#   'class_0_count': 0,
#   'class_1_count': 2011,
#   'features_involved': ['acc_open_past_24mths',
#    'dti',
#    'last_fico_range_high',
#    'recoveries'],
#   'feature_count': 4,
#   'condition_count': 5,
#   'tp': 2011,
#   'fp': 0},
#  {'tree_idx': 41,
#   'leaf_idx': 16,
#   'rule_conditions': ['dti > 35.665001',
#    'last_fico_range_high <= 601.500000',
#    'recoveries <= 0.005000',
#    'last_fico_range_high <= 536.500000',
#    'acc_open_past_24mths <= 14.500000'],
#   'logit_score': 0.11565223974327131,
#   'predicted_class': 1,
#   'confidence': 0.115652,
#   'support': np.float64(0.000494),
#   'precision': np.float64(0.6351),
#   'purity': np.float64(0.6351),
#   'quality_score': np.float64(0.6351),
#   'samples_covered': 644,
#   'class_0_count': 235,
#   'class_1_count': 409,
#   'features_involved': ['acc_open_past_24mths',
#    'dti',
#    'last_fico_range_high',
#    'recoveries'],
#   'feature_count': 4,
#   'condition_count': 5,
#   'tp': 409,
#   'fp': 235},
#  {'tree_idx': 41,
#   'leaf_idx': 17,
#   'rule_conditions': ['dti > 35.665001',
#    'last_fico_range_high <= 601.500000',
#    'recoveries <= 0.005000',
#    'last_fico_range_high <= 536.500000',
#    'acc_open_past_24mths > 14.500000'],
#   'logit_score': -1.2675942178252457,
#   'predicted_class': 0,
#   'confidence': 1.267594,
#   'support': np.float64(1.4e-05),
#   'precision': np.float64(0.2778),
#   'purity': np.float64(0.2778),
#   'quality_score': np.float64(0.2778),
#   'samples_covered': 18,
#   'class_0_count': 5,
#   'class_1_count': 13,
#   'features_involved': ['acc_open_past_24mths',
#    'dti',
#    'last_fico_range_high',
#    'recoveries'],
#   'feature_count': 4,
#   'condition_count': 5,
#   'tp': 5,
#   'fp': 13},
#  {'tree_idx': 41,
#   'leaf_idx': 20,
#   'rule_conditions': ['dti > 35.665001',
#    'last_fico_range_high <= 601.500000',
#    'recoveries > 0.005000',
#    'last_fico_range_high <= 536.500000',
#    'acc_open_past_24mths <= 14.500000'],
#   'logit_score': 0.000491054490604669,
#   'predicted_class': 1,
#   'confidence': 0.000491,
#   'support': np.float64(0.000693),
#   'precision': np.float64(1.0),
#   'purity': np.float64(1.0),
#   'quality_score': np.float64(1.0),
#   'samples_covered': 904,
#   'class_0_count': 0,
#   'class_1_count': 904,
#   'features_involved': ['acc_open_past_24mths',
#    'dti',
#    'last_fico_range_high',
#    'recoveries'],
#   'feature_count': 4,
#   'condition_count': 5,
#   'tp': 904,
#   'fp': 0},
#  {'tree_idx': 41,
#   'leaf_idx': 21,
#   'rule_conditions': ['dti > 35.665001',
#    'last_fico_range_high <= 601.500000',
#    'recoveries > 0.005000',
#    'last_fico_range_high <= 536.500000',
#    'acc_open_past_24mths > 14.500000'],
#   'logit_score': 4.2781535323804825e-05,
#   'predicted_class': 1,
#   'confidence': 4.3e-05,
#   'support': np.float64(3.3e-05),
#   'precision': np.float64(1.0),
#   'purity': np.float64(1.0),
#   'quality_score': np.float64(1.0),
#   'samples_covered': 43,
#   'class_0_count': 0,
#   'class_1_count': 43,
#   'features_involved': ['acc_open_past_24mths',
#    'dti',
#    'last_fico_range_high',
#    'recoveries'],
#   'feature_count': 4,
#   'condition_count': 5,
#   'tp': 43,
#   'fp': 0},
#  {'tree_idx': 41,
#   'leaf_idx': 24,
#   'rule_conditions': ['dti > 35.665001',
#    'last_fico_range_high > 601.500000',
#    'recoveries <= 0.005000',
#    'last_fico_range_high <= 536.500000',
#    'acc_open_past_24mths <= 14.500000'],
#   'logit_score': -0.025839344787514786,
#   'predicted_class': 0,
#   'confidence': 0.025839,
#   'support': np.float64(0.00099),
#   'precision': np.float64(0.646),
#   'purity': np.float64(0.646),
#   'quality_score': np.float64(0.646),
#   'samples_covered': 1291,
#   'class_0_count': 834,
#   'class_1_count': 457,
#   'features_involved': ['acc_open_past_24mths',
#    'dti',
#    'last_fico_range_high',
#    'recoveries'],
#   'feature_count': 4,
#   'condition_count': 5,
#   'tp': 834,
#   'fp': 457},
#  {'tree_idx': 41,
#   'leaf_idx': 25,
#   'rule_conditions': ['dti > 35.665001',
#    'last_fico_range_high > 601.500000',
#    'recoveries <= 0.005000',
#    'last_fico_range_high <= 536.500000',
#    'acc_open_past_24mths > 14.500000'],
#   'logit_score': 0.3090686118151298,
#   'predicted_class': 1,
#   'confidence': 0.309069,
#   'support': np.float64(3.1e-05),
#   'precision': np.float64(0.561),
#   'purity': np.float64(0.561),
#   'quality_score': np.float64(0.561),
#   'samples_covered': 41,
#   'class_0_count': 18,
#   'class_1_count': 23,
#   'features_involved': ['acc_open_past_24mths',
#    'dti',
#    'last_fico_range_high',
#    'recoveries'],
#   'feature_count': 4,
#   'condition_count': 5,
#   'tp': 23,
#   'fp': 18},
#  ...]

# %%
# Analyze the distribution of predicted classes in the extracted rules
total_rules = len(unique_rules)
count_predicted_class_1 = sum(
    1 for rule in unique_rules if rule.get("predicted_class") == 1
)
count_predicted_class_0 = sum(
    1 for rule in unique_rules if rule.get("predicted_class") == 0
)

print(f"\n[INFO] Total rules : {total_rules}")
print(f"[INFO] Rules class 1: {count_predicted_class_1} ({count_predicted_class_1/total_rules:.2%})")
print(f"[INFO] Rules class 0: {count_predicted_class_0} ({count_predicted_class_0/total_rules:.2%})")
# Out:
# [INFO] Total rules : 1681
# [INFO] Rules class 1: 1110 (66.03%)
# [INFO] Rules class 0: 571 (33.97%)

# %%
structured_rules = cr.convert_rules_to_simple_format(unique_rules)
structured_rules
# Out:
# [{'tree_id': 0,
#   'conditions': ['recoveries <= 0.005000',
#    'last_fico_range_high <= 581.500000',
#    'term_num <= 48.000000',
#    'recoveries <= 1730.060059',
#    'last_fico_range_high <= 631.500000'],
#   'predicted_class': 0,
#   'logit_score': -0.5791074310451048,
#   'confidence': 0.579107,
#   'support': np.float64(0.055417),
#   'precision': np.float64(0.6408)},
#  {'tree_id': 0,
#   'conditions': ['recoveries <= 0.005000',
#    'last_fico_range_high <= 581.500000',
#    'term_num <= 48.000000',
#    'recoveries <= 1730.060059',
#    'last_fico_range_high > 631.500000'],
#   'predicted_class': 1,
#   'logit_score': 10.61425670868059,
#   'confidence': 10.614257,
#   'support': np.float64(0.04363),
#   'precision': np.float64(1.0)},
#  {'tree_id': 0,
#   'conditions': ['recoveries <= 0.005000',
#    'last_fico_range_high <= 581.500000',
#    'term_num <= 48.000000',
#    'recoveries > 1730.060059',
#    'last_fico_range_high <= 631.500000'],
#   'predicted_class': 0,
#   'logit_score': -1.900557595696344,
#   'confidence': 1.900558,
#   'support': np.float64(0.048246),
#   'precision': np.float64(0.8695)},
#  {'tree_id': 0,
#   'conditions': ['recoveries <= 0.005000',
#    'last_fico_range_high <= 581.500000',
#    'term_num <= 48.000000',
#    'recoveries > 1730.060059',
#    'last_fico_range_high > 631.500000'],
#   'predicted_class': 1,
#   'logit_score': 10.065391245803456,
#   'confidence': 10.065391,
#   'support': np.float64(0.01392),
#   'precision': np.float64(1.0)},
#  {'tree_id': 0,
#   'conditions': ['recoveries <= 0.005000',
#    'last_fico_range_high <= 581.500000',
#    'term_num > 48.000000',
#    'recoveries <= 1730.060059',
#    'last_fico_range_high <= 631.500000'],
#   'predicted_class': 1,
#   'logit_score': 0.6534571155043267,
#   'confidence': 0.653457,
#   'support': np.float64(0.01958),
#   'precision': np.float64(0.656)},
#  {'tree_id': 0,
#   'conditions': ['recoveries <= 0.005000',
#    'last_fico_range_high <= 581.500000',
#    'term_num > 48.000000',
#    'recoveries <= 1730.060059',
#    'last_fico_range_high > 631.500000'],
#   'predicted_class': 1,
#   'logit_score': 10.105604111069336,
#   'confidence': 10.105604,
#   'support': np.float64(0.015136),
#   'precision': np.float64(1.0)},
#  {'tree_id': 0,
#   'conditions': ['recoveries <= 0.005000',
#    'last_fico_range_high <= 581.500000',
#    'term_num > 48.000000',
#    'recoveries > 1730.060059',
#    'last_fico_range_high <= 631.500000'],
#   'predicted_class': 0,
#   'logit_score': -0.6854460289592921,
#   'confidence': 0.685446,
#   'support': np.float64(0.01374),
#   'precision': np.float64(0.6636)},
#  {'tree_id': 0,
#   'conditions': ['recoveries <= 0.005000',
#    'last_fico_range_high <= 581.500000',
#    'term_num > 48.000000',
#    'recoveries > 1730.060059',
#    'last_fico_range_high > 631.500000'],
#   'predicted_class': 1,
#   'logit_score': 9.514712488699487,
#   'confidence': 9.514712,
#   'support': np.float64(0.005731),
#   'precision': np.float64(1.0)},
#  {'tree_id': 0,
#   'conditions': ['recoveries <= 0.005000',
#    'last_fico_range_high > 581.500000',
#    'term_num <= 48.000000',
#    'recoveries <= 1730.060059',
#    'last_fico_range_high > 631.500000'],
#   'predicted_class': 1,
#   'logit_score': 9.902305241349517,
#   'confidence': 9.902305,
#   'support': np.float64(0.010516),
#   'precision': np.float64(1.0)},
#  {'tree_id': 0,
#   'conditions': ['recoveries <= 0.005000',
#    'last_fico_range_high > 581.500000',
#    'term_num <= 48.000000',
#    'recoveries > 1730.060059',
#    'last_fico_range_high > 631.500000'],
#   'predicted_class': 1,
#   'logit_score': 9.553986303818576,
#   'confidence': 9.553986,
#   'support': np.float64(0.006011),
#   'precision': np.float64(1.0)},
#  {'tree_id': 0,
#   'conditions': ['recoveries <= 0.005000',
#    'last_fico_range_high > 581.500000',
#    'term_num > 48.000000',
#    'recoveries <= 1730.060059',
#    'last_fico_range_high > 631.500000'],
#   'predicted_class': 1,
#   'logit_score': 10.24692714962559,
#   'confidence': 10.246927,
#   'support': np.float64(0.019436),
#   'precision': np.float64(1.0)},
#  {'tree_id': 0,
#   'conditions': ['recoveries <= 0.005000',
#    'last_fico_range_high > 581.500000',
#    'term_num > 48.000000',
#    'recoveries > 1730.060059',
#    'last_fico_range_high > 631.500000'],
#   'predicted_class': 1,
#   'logit_score': 9.800078692403941,
#   'confidence': 9.800079,
#   'support': np.float64(0.008936),
#   'precision': np.float64(1.0)},
#  {'tree_id': 0,
#   'conditions': ['recoveries > 0.005000',
#    'last_fico_range_high <= 581.500000',
#    'term_num <= 48.000000',
#    'recoveries > 1730.060059',
#    'last_fico_range_high <= 631.500000'],
#   'predicted_class': 0,
#   'logit_score': -4.5658228269705345,
#   'confidence': 4.565823,
#   'support': np.float64(0.559752),
#   'precision': np.float64(0.9897)},
#  {'tree_id': 0,
#   'conditions': ['recoveries > 0.005000',
#    'last_fico_range_high <= 581.500000',
#    'term_num <= 48.000000',
#    'recoveries > 1730.060059',
#    'last_fico_range_high > 631.500000'],
#   'predicted_class': 1,
#   'logit_score': 9.668661096844986,
#   'confidence': 9.668661,
#   'support': np.float64(0.007211),
#   'precision': np.float64(1.0)},
#  {'tree_id': 0,
#   'conditions': ['recoveries > 0.005000',
#    'last_fico_range_high <= 581.500000',
#    'term_num > 48.000000',
#    'recoveries > 1730.060059',
#    'last_fico_range_high <= 631.500000'],
#   'predicted_class': 0,
#   'logit_score': -3.8344774123076095,
#   'confidence': 3.834477,
#   'support': np.float64(0.16069),
#   'precision': np.float64(0.9788)},
#  {'tree_id': 0,
#   'conditions': ['recoveries > 0.005000',
#    'last_fico_range_high <= 581.500000',
#    'term_num > 48.000000',
#    'recoveries > 1730.060059',
#    'last_fico_range_high > 631.500000'],
#   'predicted_class': 1,
#   'logit_score': 9.050622278899617,
#   'confidence': 9.050622,
#   'support': np.float64(0.002932),
#   'precision': np.float64(1.0)},
#  {'tree_id': 0,
#   'conditions': ['recoveries > 0.005000',
#    'last_fico_range_high > 581.500000',
#    'term_num <= 48.000000',
#    'recoveries > 1730.060059',
#    'last_fico_range_high > 631.500000'],
#   'predicted_class': 1,
#   'logit_score': 9.295988544669537,
#   'confidence': 9.295989,
#   'support': np.float64(0.004141),
#   'precision': np.float64(1.0)},
#  {'tree_id': 0,
#   'conditions': ['recoveries > 0.005000',
#    'last_fico_range_high > 581.500000',
#    'term_num > 48.000000',
#    'recoveries > 1730.060059',
#    'last_fico_range_high > 631.500000'],
#   'predicted_class': 1,
#   'logit_score': 9.433459771344285,
#   'confidence': 9.43346,
#   'support': np.float64(0.004976),
#   'precision': np.float64(1.0)},
#  {'tree_id': 1,
#   'conditions': ['last_fico_range_high <= 506.500000',
#    'recoveries <= 1.280000',
#    'debt_settlement_flag <= 0.500000',
#    'last_fico_range_high <= 581.500000',
#    'dti <= 25.035000'],
#   'predicted_class': 1,
#   'logit_score': 0.7528976112680642,
#   'confidence': 0.752898,
#   'support': np.float64(0.01116),
#   'precision': np.float64(0.6178)},
#  {'tree_id': 1,
#   'conditions': ['last_fico_range_high <= 506.500000',
#    'recoveries <= 1.280000',
#    'debt_settlement_flag <= 0.500000',
#    'last_fico_range_high <= 581.500000',
#    'dti > 25.035000'],
#   'predicted_class': 0,
#   'logit_score': -0.392397673538152,
#   'confidence': 0.392398,
#   'support': np.float64(0.045005),
#   'precision': np.float64(0.6519)},
#  {'tree_id': 1,
#   'conditions': ['last_fico_range_high <= 506.500000',
#    'recoveries <= 1.280000',
#    'debt_settlement_flag <= 0.500000',
#    'last_fico_range_high > 581.500000',
#    'dti <= 25.035000'],
#   'predicted_class': 1,
#   'logit_score': 0.913549690707729,
#   'confidence': 0.91355,
#   'support': np.float64(0.013015),
#   'precision': np.float64(1.0)},
#  {'tree_id': 1,
#   'conditions': ['last_fico_range_high <= 506.500000',
#    'recoveries <= 1.280000',
#    'debt_settlement_flag <= 0.500000',
#    'last_fico_range_high > 581.500000',
#    'dti > 25.035000'],
#   'predicted_class': 1,
#   'logit_score': 1.6778102622384112,
#   'confidence': 1.67781,
#   'support': np.float64(0.043707),
#   'precision': np.float64(1.0)},
#  {'tree_id': 1,
#   'conditions': ['last_fico_range_high <= 506.500000',
#    'recoveries <= 1.280000',
#    'debt_settlement_flag > 0.500000',
#    'last_fico_range_high <= 581.500000',
#    'dti <= 25.035000'],
#   'predicted_class': 1,
#   'logit_score': 4.885094206703894,
#   'confidence': 4.885094,
#   'support': np.float64(8e-05),
#   'precision': np.float64(1.0)},
#  {'tree_id': 1,
#   'conditions': ['last_fico_range_high <= 506.500000',
#    'recoveries <= 1.280000',
#    'debt_settlement_flag > 0.500000',
#    'last_fico_range_high <= 581.500000',
#    'dti > 25.035000'],
#   'predicted_class': 1,
#   'logit_score': 5.222538372205704,
#   'confidence': 5.222538,
#   'support': np.float64(0.000475),
#   'precision': np.float64(0.9984)},
#  {'tree_id': 1,
#   'conditions': ['last_fico_range_high <= 506.500000',
#    'recoveries <= 1.280000',
#    'debt_settlement_flag > 0.500000',
#    'last_fico_range_high > 581.500000',
#    'dti <= 25.035000'],
#   'predicted_class': 1,
#   'logit_score': 0.09971073704041868,
#   'confidence': 0.099711,
#   'support': np.float64(0.000766),
#   'precision': np.float64(1.0)},
#  {'tree_id': 1,
#   'conditions': ['last_fico_range_high <= 506.500000',
#    'recoveries <= 1.280000',
#    'debt_settlement_flag > 0.500000',
#    'last_fico_range_high > 581.500000',
#    'dti > 25.035000'],
#   'predicted_class': 1,
#   'logit_score': 0.6374056604220306,
#   'confidence': 0.637406,
#   'support': np.float64(0.006682),
#   'precision': np.float64(1.0)},
#  {'tree_id': 1,
#   'conditions': ['last_fico_range_high <= 506.500000',
#    'recoveries > 1.280000',
#    'debt_settlement_flag <= 0.500000',
#    'last_fico_range_high <= 581.500000',
#    'dti > 25.035000'],
#   'predicted_class': 0,
#   'logit_score': -0.17062555140979535,
#   'confidence': 0.170626,
#   'support': np.float64(0.615793),
#   'precision': np.float64(0.9773)},
#  {'tree_id': 1,
#   'conditions': ['last_fico_range_high <= 506.500000',
#    'recoveries > 1.280000',
#    'debt_settlement_flag <= 0.500000',
#    'last_fico_range_high > 581.500000',
#    'dti > 25.035000'],
#   'predicted_class': 1,
#   'logit_score': 1.7918686566570703,
#   'confidence': 1.791869,
#   'support': np.float64(0.026752),
#   'precision': np.float64(1.0)},
#  {'tree_id': 1,
#   'conditions': ['last_fico_range_high <= 506.500000',
#    'recoveries > 1.280000',
#    'debt_settlement_flag > 0.500000',
#    'last_fico_range_high <= 581.500000',
#    'dti > 25.035000'],
#   'predicted_class': 1,
#   'logit_score': 9.12571350856445,
#   'confidence': 9.125714,
#   'support': np.float64(0.000515),
#   'precision': np.float64(0.994)},
#  {'tree_id': 1,
#   'conditions': ['last_fico_range_high <= 506.500000',
#    'recoveries > 1.280000',
#    'debt_settlement_flag > 0.500000',
#    'last_fico_range_high > 581.500000',
#    'dti > 25.035000'],
#   'predicted_class': 1,
#   'logit_score': 1.2042168816122367,
#   'confidence': 1.204217,
#   'support': np.float64(0.009967),
#   'precision': np.float64(1.0)},
#  {'tree_id': 1,
#   'conditions': ['last_fico_range_high > 506.500000',
#    'recoveries <= 1.280000',
#    'debt_settlement_flag <= 0.500000',
#    'last_fico_range_high <= 581.500000',
#    'dti <= 25.035000'],
#   'predicted_class': 1,
#   'logit_score': 1.3972383370033485,
#   'confidence': 1.397238,
#   'support': np.float64(0.0035),
#   'precision': np.float64(0.7569)},
#  {'tree_id': 1,
#   'conditions': ['last_fico_range_high > 506.500000',
#    'recoveries <= 1.280000',
#    'debt_settlement_flag <= 0.500000',
#    'last_fico_range_high <= 581.500000',
#    'dti > 25.035000'],
#   'predicted_class': 1,
#   'logit_score': 0.13939129267863903,
#   'confidence': 0.139391,
#   'support': np.float64(0.014972),
#   'precision': np.float64(0.4797)},
#  {'tree_id': 1,
#   'conditions': ['last_fico_range_high > 506.500000',
#    'recoveries <= 1.280000',
#    'debt_settlement_flag <= 0.500000',
#    'last_fico_range_high > 581.500000',
#    'dti <= 25.035000'],
#   'predicted_class': 1,
#   'logit_score': 0.3697199900385954,
#   'confidence': 0.36972,
#   'support': np.float64(0.003487),
#   'precision': np.float64(1.0)},
#  {'tree_id': 1,
#   'conditions': ['last_fico_range_high > 506.500000',
#    'recoveries <= 1.280000',
#    'debt_settlement_flag <= 0.500000',
#    'last_fico_range_high > 581.500000',
#    'dti > 25.035000'],
#   'predicted_class': 1,
#   'logit_score': 1.114132719082386,
#   'confidence': 1.114133,
#   'support': np.float64(0.017538),
#   'precision': np.float64(1.0)},
#  {'tree_id': 1,
#   'conditions': ['last_fico_range_high > 506.500000',
#    'recoveries <= 1.280000',
#    'debt_settlement_flag > 0.500000',
#    'last_fico_range_high <= 581.500000',
#    'dti <= 25.035000'],
#   'predicted_class': 1,
#   'logit_score': 4.374310062978864,
#   'confidence': 4.37431,
#   'support': np.float64(2.8e-05),
#   'precision': np.float64(1.0)},
#  {'tree_id': 1,
#   'conditions': ['last_fico_range_high > 506.500000',
#    'recoveries <= 1.280000',
#    'debt_settlement_flag > 0.500000',
#    'last_fico_range_high <= 581.500000',
#    'dti > 25.035000'],
#   'predicted_class': 1,
#   'logit_score': 5.18103042530641,
#   'confidence': 5.18103,
#   'support': np.float64(0.000208),
#   'precision': np.float64(1.0)},
#  {'tree_id': 1,
#   'conditions': ['last_fico_range_high > 506.500000',
#    'recoveries <= 1.280000',
#    'debt_settlement_flag > 0.500000',
#    'last_fico_range_high > 581.500000',
#    'dti <= 25.035000'],
#   'predicted_class': 1,
#   'logit_score': 0.03484299517182088,
#   'confidence': 0.034843,
#   'support': np.float64(0.000251),
#   'precision': np.float64(1.0)},
#  {'tree_id': 1,
#   'conditions': ['last_fico_range_high > 506.500000',
#    'recoveries <= 1.280000',
#    'debt_settlement_flag > 0.500000',
#    'last_fico_range_high > 581.500000',
#    'dti > 25.035000'],
#   'predicted_class': 1,
#   'logit_score': 0.3402687970803207,
#   'confidence': 0.340269,
#   'support': np.float64(0.002842),
#   'precision': np.float64(1.0)},
#  {'tree_id': 1,
#   'conditions': ['last_fico_range_high > 506.500000',
#    'recoveries > 1.280000',
#    'debt_settlement_flag <= 0.500000',
#    'last_fico_range_high <= 581.500000',
#    'dti > 25.035000'],
#   'predicted_class': 1,
#   'logit_score': 0.33146001268070124,
#   'confidence': 0.33146,
#   'support': np.float64(0.166993),
#   'precision': np.float64(0.0387)},
#  {'tree_id': 1,
#   'conditions': ['last_fico_range_high > 506.500000',
#    'recoveries > 1.280000',
#    'debt_settlement_flag <= 0.500000',
#    'last_fico_range_high > 581.500000',
#    'dti > 25.035000'],
#   'predicted_class': 1,
#   'logit_score': 1.2120043415978592,
#   'confidence': 1.212004,
#   'support': np.float64(0.010688),
#   'precision': np.float64(1.0)},
#  {'tree_id': 1,
#   'conditions': ['last_fico_range_high > 506.500000',
#    'recoveries > 1.280000',
#    'debt_settlement_flag > 0.500000',
#    'last_fico_range_high <= 581.500000',
#    'dti > 25.035000'],
#   'predicted_class': 1,
#   'logit_score': 8.22355636136326,
#   'confidence': 8.223556,
#   'support': np.float64(0.000238),
#   'precision': np.float64(0.9936)},
#  {'tree_id': 1,
#   'conditions': ['last_fico_range_high > 506.500000',
#    'recoveries > 1.280000',
#    'debt_settlement_flag > 0.500000',
#    'last_fico_range_high > 581.500000',
#    'dti > 25.035000'],
#   'predicted_class': 1,
#   'logit_score': 0.8593844883473815,
#   'confidence': 0.859384,
#   'support': np.float64(0.005339),
#   'precision': np.float64(1.0)},
#  {'tree_id': 2,
#   'conditions': ['last_fico_range_high <= 676.500000',
#    'loan_amnt <= 9812.500000',
#    'fico_range_low <= 702.500000',
#    'recoveries <= 7.880000',
#    'last_fico_range_high <= 631.500000'],
#   'predicted_class': 0,
#   'logit_score': -0.35751617884804304,
#   'confidence': 0.357516,
#   'support': np.float64(0.04432),
#   'precision': np.float64(0.7872)},
#  {'tree_id': 2,
#   'conditions': ['last_fico_range_high <= 676.500000',
#    'loan_amnt <= 9812.500000',
#    'fico_range_low <= 702.500000',
#    'recoveries > 7.880000',
#    'last_fico_range_high <= 631.500000'],
#   'predicted_class': 1,
#   'logit_score': 0.02603690002220497,
#   'confidence': 0.026037,
#   'support': np.float64(0.062487),
#   'precision': np.float64(0.368)},
#  {'tree_id': 2,
#   'conditions': ['last_fico_range_high <= 676.500000',
#    'loan_amnt <= 9812.500000',
#    'fico_range_low > 702.500000',
#    'recoveries <= 7.880000',
#    'last_fico_range_high <= 631.500000'],
#   'predicted_class': 1,
#   'logit_score': 0.03532865087253384,
#   'confidence': 0.035329,
#   'support': np.float64(0.010923),
#   'precision': np.float64(0.2837)},
#  {'tree_id': 2,
#   'conditions': ['last_fico_range_high <= 676.500000',
#    'loan_amnt <= 9812.500000',
#    'fico_range_low > 702.500000',
#    'recoveries > 7.880000',
#    'last_fico_range_high <= 631.500000'],
#   'predicted_class': 1,
#   'logit_score': 0.4749613921919602,
#   'confidence': 0.474961,
#   'support': np.float64(0.021148),
#   'precision': np.float64(0.4748)},
#  {'tree_id': 2,
#   'conditions': ['last_fico_range_high <= 676.500000',
#    'loan_amnt > 9812.500000',
#    'fico_range_low <= 702.500000',
#    'recoveries <= 7.880000',
#    'last_fico_range_high <= 631.500000'],
#   'predicted_class': 1,
#   'logit_score': 0.468111535140064,
#   'confidence': 0.468112,
#   'support': np.float64(0.026514),
#   'precision': np.float64(1.0)},
#  {'tree_id': 2,
#   'conditions': ['last_fico_range_high <= 676.500000',
#    'loan_amnt > 9812.500000',
#    'fico_range_low <= 702.500000',
#    'recoveries > 7.880000',
#    'last_fico_range_high <= 631.500000'],
#   'predicted_class': 1,
#   'logit_score': 0.9818424925499751,
#   'confidence': 0.981842,
#   'support': np.float64(0.068533),
#   'precision': np.float64(1.0)},
#  {'tree_id': 2,
#   'conditions': ['last_fico_range_high <= 676.500000',
#    'loan_amnt > 9812.500000',
#    'fico_range_low > 702.500000',
#    'recoveries <= 7.880000',
#    'last_fico_range_high <= 631.500000'],
#   'predicted_class': 1,
#   'logit_score': 0.13776033370479585,
#   'confidence': 0.13776,
#   'support': np.float64(0.005864),
#   'precision': np.float64(1.0)},
#  {'tree_id': 2,
#   'conditions': ['last_fico_range_high <= 676.500000',
#    'loan_amnt > 9812.500000',
#    'fico_range_low > 702.500000',
#    'recoveries > 7.880000',
#    'last_fico_range_high <= 631.500000'],
#   'predicted_class': 1,
#   'logit_score': 0.48043202303463667,
#   'confidence': 0.480432,
#   'support': np.float64(0.020508),
#   'precision': np.float64(1.0)},
#  {'tree_id': 2,
#   'conditions': ['last_fico_range_high > 676.500000',
#    'loan_amnt <= 9812.500000',
#    'fico_range_low <= 702.500000',
#    'recoveries <= 7.880000',
#    'last_fico_range_high <= 631.500000'],
#   'predicted_class': 1,
#   'logit_score': 0.7551394102994762,
#   'confidence': 0.755139,
#   'support': np.float64(0.0429),
#   'precision': np.float64(0.0279)},
#  {'tree_id': 2,
#   'conditions': ['last_fico_range_high > 676.500000',
#    'loan_amnt <= 9812.500000',
#    'fico_range_low <= 702.500000',
#    'recoveries <= 7.880000',
#    'last_fico_range_high > 631.500000'],
#   'predicted_class': 0,
#   'logit_score': -0.5960562824452659,
#   'confidence': 0.596056,
#   'support': np.float64(0.111626),
#   'precision': np.float64(0.9932)},
#  {'tree_id': 2,
#   'conditions': ['last_fico_range_high > 676.500000',
#    'loan_amnt <= 9812.500000',
#    'fico_range_low <= 702.500000',
#    'recoveries > 7.880000',
#    'last_fico_range_high <= 631.500000'],
#   'predicted_class': 1,
#   'logit_score': 1.1348387855173592,
#   'confidence': 1.134839,
#   'support': np.float64(0.062161),
#   'precision': np.float64(0.0502)},
#  {'tree_id': 2,
#   'conditions': ['last_fico_range_high > 676.500000',
#    'loan_amnt <= 9812.500000',
#    'fico_range_low <= 702.500000',
#    'recoveries > 7.880000',
#    'last_fico_range_high > 631.500000'],
#   'predicted_class': 0,
#   'logit_score': -0.785875870580687,
#   'confidence': 0.785876,
#   'support': np.float64(0.214615),
#   'precision': np.float64(0.9925)},
#  {'tree_id': 2,
#   'conditions': ['last_fico_range_high > 676.500000',
#    'loan_amnt <= 9812.500000',
#    'fico_range_low > 702.500000',
#    'recoveries <= 7.880000',
#    'last_fico_range_high <= 631.500000'],
#   'predicted_class': 1,
#   'logit_score': 1.2795498988130234,
#   'confidence': 1.27955,
#   'support': np.float64(0.009612),
#   'precision': np.float64(0.0484)},
#  {'tree_id': 2,
#   'conditions': ['last_fico_range_high > 676.500000',
#    'loan_amnt <= 9812.500000',
#    'fico_range_low > 702.500000',
#    'recoveries <= 7.880000',
#    'last_fico_range_high > 631.500000'],
#   'predicted_class': 0,
#   'logit_score': -0.38642983393537805,
#   'confidence': 0.38643,
#   'support': np.float64(0.078631),
#   'precision': np.float64(0.9919)},
#  {'tree_id': 2,
#   'conditions': ['last_fico_range_high > 676.500000',
#    'loan_amnt <= 9812.500000',
#    'fico_range_low > 702.500000',
#    'recoveries > 7.880000',
#    'last_fico_range_high <= 631.500000'],
#   'predicted_class': 1,
#   'logit_score': 1.7512686065145249,
#   'confidence': 1.751269,
#   'support': np.float64(0.017567),
#   'precision': np.float64(0.0865)},
#  {'tree_id': 2,
#   'conditions': ['last_fico_range_high > 676.500000',
#    'loan_amnt <= 9812.500000',
#    'fico_range_low > 702.500000',
#    'recoveries > 7.880000',
#    'last_fico_range_high > 631.500000'],
#   'predicted_class': 0,
#   'logit_score': -0.5780995459859809,
#   'confidence': 0.5781,
#   'support': np.float64(0.185048),
#   'precision': np.float64(0.9914)},
#  {'tree_id': 2,
#   'conditions': ['last_fico_range_high > 676.500000',
#    'loan_amnt > 9812.500000',
#    'fico_range_low <= 702.500000',
#    'recoveries <= 7.880000',
#    'last_fico_range_high <= 631.500000'],
#   'predicted_class': 1,
#   'logit_score': 0.09491328366043829,
#   'confidence': 0.094913,
#   'support': np.float64(0.002137),
#   'precision': np.float64(1.0)},
#  {'tree_id': 2,
#   'conditions': ['last_fico_range_high > 676.500000',
#    'loan_amnt > 9812.500000',
#    'fico_range_low <= 702.500000',
#    'recoveries <= 7.880000',
#    'last_fico_range_high > 631.500000'],
#   'predicted_class': 1,
#   'logit_score': 0.01969106515951163,
#   'confidence': 0.019691,
#   'support': np.float64(0.000463),
#   'precision': np.float64(1.0)},
#  {'tree_id': 2,
#   'conditions': ['last_fico_range_high > 676.500000',
#    'loan_amnt > 9812.500000',
#    'fico_range_low <= 702.500000',
#    'recoveries > 7.880000',
#    'last_fico_range_high <= 631.500000'],
#   'predicted_class': 1,
#   'logit_score': 0.3447944153230583,
#   'confidence': 0.344794,
#   'support': np.float64(0.007572),
#   'precision': np.float64(1.0)},
#  {'tree_id': 2,
#   'conditions': ['last_fico_range_high > 676.500000',
#    'loan_amnt > 9812.500000',
#    'fico_range_low <= 702.500000',
#    'recoveries > 7.880000',
#    'last_fico_range_high > 631.500000'],
#   'predicted_class': 1,
#   'logit_score': 0.09061270607035787,
#   'confidence': 0.090613,
#   'support': np.float64(0.001703),
#   'precision': np.float64(1.0)},
#  {'tree_id': 2,
#   'conditions': ['last_fico_range_high > 676.500000',
#    'loan_amnt > 9812.500000',
#    'fico_range_low > 702.500000',
#    'recoveries <= 7.880000',
#    'last_fico_range_high <= 631.500000'],
#   'predicted_class': 1,
#   'logit_score': 0.03412029037938797,
#   'confidence': 0.03412,
#   'support': np.float64(0.000769),
#   'precision': np.float64(1.0)},
#  {'tree_id': 2,
#   'conditions': ['last_fico_range_high > 676.500000',
#    'loan_amnt > 9812.500000',
#    'fico_range_low > 702.500000',
#    'recoveries <= 7.880000',
#    'last_fico_range_high > 631.500000'],
#   'predicted_class': 1,
#   'logit_score': 0.014443736208036006,
#   'confidence': 0.014444,
#   'support': np.float64(0.000327),
#   'precision': np.float64(1.0)},
#  {'tree_id': 2,
#   'conditions': ['last_fico_range_high > 676.500000',
#    'loan_amnt > 9812.500000',
#    'fico_range_low > 702.500000',
#    'recoveries > 7.880000',
#    'last_fico_range_high <= 631.500000'],
#   'predicted_class': 1,
#   'logit_score': 0.17526534869279473,
#   'confidence': 0.175265,
#   'support': np.float64(0.003313),
#   'precision': np.float64(1.0)},
#  {'tree_id': 2,
#   'conditions': ['last_fico_range_high > 676.500000',
#    'loan_amnt > 9812.500000',
#    'fico_range_low > 702.500000',
#    'recoveries > 7.880000',
#    'last_fico_range_high > 631.500000'],
#   'predicted_class': 1,
#   'logit_score': 0.06936055769243124,
#   'confidence': 0.069361,
#   'support': np.float64(0.001259),
#   'precision': np.float64(1.0)},
#  {'tree_id': 3,
#   'conditions': ['last_fico_range_high <= 536.500000',
#    'recoveries <= 23.610001',
#    'last_fico_range_high <= 581.500000',
#    'mort_acc <= 0.500000',
#    'loan_amnt <= 36012.500000'],
#   'predicted_class': 1,
#   'logit_score': 0.4111438621147543,
#   'confidence': 0.411144,
#   'support': np.float64(0.01877),
#   'precision': np.float64(0.5804)},
#  {'tree_id': 3,
#   'conditions': ['last_fico_range_high <= 536.500000',
#    'recoveries <= 23.610001',
#    'last_fico_range_high <= 581.500000',
#    'mort_acc <= 0.500000',
#    'loan_amnt > 36012.500000'],
#   'predicted_class': 0,
#   'logit_score': -0.03855153615712501,
#   'confidence': 0.038552,
#   'support': np.float64(0.019325),
#   'precision': np.float64(0.6418)},
#  {'tree_id': 3,
#   'conditions': ['last_fico_range_high <= 536.500000',
#    'recoveries <= 23.610001',
#    'last_fico_range_high <= 581.500000',
#    'mort_acc > 0.500000',
#    'loan_amnt <= 36012.500000'],
#   'predicted_class': 1,
#   'logit_score': 0.5518537263571085,
#   'confidence': 0.551854,
#   'support': np.float64(0.024096),
#   'precision': np.float64(1.0)},
#  {'tree_id': 3,
#   'conditions': ['last_fico_range_high <= 536.500000',
#    'recoveries <= 23.610001',
#    'last_fico_range_high <= 581.500000',
#    'mort_acc > 0.500000',
#    'loan_amnt > 36012.500000'],
#   'predicted_class': 1,
#   'logit_score': 0.4233599467010625,
#   'confidence': 0.42336,
#   'support': np.float64(0.020405),
#   'precision': np.float64(1.0)},
#  {'tree_id': 3,
#   'conditions': ['last_fico_range_high <= 536.500000',
#    'recoveries <= 23.610001',
#    'last_fico_range_high > 581.500000',
#    'mort_acc <= 0.500000',
#    'loan_amnt > 36012.500000'],
#   'predicted_class': 1,
#   'logit_score': 0.09391514229713409,
#   'confidence': 0.093915,
#   'support': np.float64(0.297127),
#   'precision': np.float64(0.032)},
#  {'tree_id': 3,
#   'conditions': ['last_fico_range_high <= 536.500000',
#    'recoveries <= 23.610001',
#    'last_fico_range_high > 581.500000',
#    'mort_acc > 0.500000',
#    'loan_amnt > 36012.500000'],
#   'predicted_class': 1,
#   'logit_score': 0.7107126395624719,
#   'confidence': 0.710713,
#   'support': np.float64(0.019833),
#   'precision': np.float64(1.0)},
#  {'tree_id': 3,
#   'conditions': ['last_fico_range_high <= 536.500000',
#    'recoveries > 23.610001',
#    'last_fico_range_high <= 581.500000',
#    'mort_acc <= 0.500000',
#    'loan_amnt <= 36012.500000'],
#   'predicted_class': 1,
#   'logit_score': 0.05397595115841171,
#   'confidence': 0.053976,
#   'support': np.float64(0.015102),
#   'precision': np.float64(0.5313)},
#  {'tree_id': 3,
#   'conditions': ['last_fico_range_high <= 536.500000',
#    'recoveries > 23.610001',
#    'last_fico_range_high <= 581.500000',
#    'mort_acc <= 0.500000',
#    'loan_amnt > 36012.500000'],
#   'predicted_class': 0,
#   'logit_score': -0.3720890370681152,
#   'confidence': 0.372089,
#   'support': np.float64(0.022323),
#   'precision': np.float64(0.6637)},
#  {'tree_id': 3,
#   'conditions': ['last_fico_range_high <= 536.500000',
#    'recoveries > 23.610001',
#    'last_fico_range_high <= 581.500000',
#    'mort_acc > 0.500000',
#    'loan_amnt <= 36012.500000'],
#   'predicted_class': 1,
#   'logit_score': 0.41935106039689046,
#   'confidence': 0.419351,
#   'support': np.float64(0.018027),
#   'precision': np.float64(1.0)},
#  {'tree_id': 3,
#   'conditions': ['last_fico_range_high <= 536.500000',
#    'recoveries > 23.610001',
#    'last_fico_range_high <= 581.500000',
#    'mort_acc > 0.500000',
#    'loan_amnt > 36012.500000'],
#   'predicted_class': 1,
#   'logit_score': 0.47275470867024383,
#   'confidence': 0.472755,
#   'support': np.float64(0.024146),
#   'precision': np.float64(1.0)},
#  {'tree_id': 3,
#   'conditions': ['last_fico_range_high <= 536.500000',
#    'recoveries > 23.610001',
#    'last_fico_range_high > 581.500000',
#    'mort_acc <= 0.500000',
#    'loan_amnt > 36012.500000'],
#   'predicted_class': 0,
#   'logit_score': -0.11384695590375478,
#   'confidence': 0.113847,
#   'support': np.float64(0.479537),
#   'precision': np.float64(0.9717)},
#  {'tree_id': 3,
#   'conditions': ['last_fico_range_high <= 536.500000',
#    'recoveries > 23.610001',
#    'last_fico_range_high > 581.500000',
#    'mort_acc > 0.500000',
#    'loan_amnt > 36012.500000'],
#   'predicted_class': 1,
#   'logit_score': 0.9434588364036035,
#   'confidence': 0.943459,
#   'support': np.float64(0.029884),
#   'precision': np.float64(1.0)},
#  {'tree_id': 3,
#   'conditions': ['last_fico_range_high > 536.500000',
#    'recoveries <= 23.610001',
#    'last_fico_range_high <= 581.500000',
#    'mort_acc <= 0.500000',
#    'loan_amnt <= 36012.500000'],
#   'predicted_class': 1,
#   'logit_score': 2.2427707163741575,
#   'confidence': 2.242771,
#   'support': np.float64(0.000147),
#   'precision': np.float64(0.9479)},
#  {'tree_id': 3,
#   'conditions': ['last_fico_range_high > 536.500000',
#    'recoveries <= 23.610001',
#    'last_fico_range_high <= 581.500000',
#    'mort_acc <= 0.500000',
#    'loan_amnt > 36012.500000'],
#   'predicted_class': 1,
#   'logit_score': 2.2293360084420675,
#   'confidence': 2.229336,
#   'support': np.float64(0.000107),
#   'precision': np.float64(0.8857)},
#  {'tree_id': 3,
#   'conditions': ['last_fico_range_high > 536.500000',
#    'recoveries <= 23.610001',
#    'last_fico_range_high <= 581.500000',
#    'mort_acc > 0.500000',
#    'loan_amnt <= 36012.500000'],
#   'predicted_class': 1,
#   'logit_score': 0.005170584747870398,
#   'confidence': 0.005171,
#   'support': np.float64(0.000138),
#   'precision': np.float64(1.0)},
#  {'tree_id': 3,
#   'conditions': ['last_fico_range_high > 536.500000',
#    'recoveries <= 23.610001',
#    'last_fico_range_high <= 581.500000',
#    'mort_acc > 0.500000',
#    'loan_amnt > 36012.500000'],
#   'predicted_class': 1,
#   'logit_score': 0.004252261054249091,
#   'confidence': 0.004252,
#   'support': np.float64(0.00013),
#   'precision': np.float64(1.0)},
#  {'tree_id': 3,
#   'conditions': ['last_fico_range_high > 536.500000',
#    'recoveries <= 23.610001',
#    'last_fico_range_high > 581.500000',
#    'mort_acc <= 0.500000',
#    'loan_amnt > 36012.500000'],
#   'predicted_class': 1,
#   'logit_score': 1.5400646137816996,
#   'confidence': 1.540065,
#   'support': np.float64(0.001652),
#   'precision': np.float64(0.0896)},
#  {'tree_id': 3,
#   'conditions': ['last_fico_range_high > 536.500000',
#    'recoveries <= 23.610001',
#    'last_fico_range_high > 581.500000',
#    'mort_acc > 0.500000',
#    'loan_amnt > 36012.500000'],
#   'predicted_class': 1,
#   'logit_score': 0.009479906081689278,
#   'confidence': 0.00948,
#   'support': np.float64(0.000153),
#   'precision': np.float64(1.0)},
#  {'tree_id': 3,
#   'conditions': ['last_fico_range_high > 536.500000',
#    'recoveries > 23.610001',
#    'last_fico_range_high <= 581.500000',
#    'mort_acc <= 0.500000',
#    'loan_amnt <= 36012.500000'],
#   'predicted_class': 1,
#   'logit_score': 2.3199207354496205,
#   'confidence': 2.319921,
#   'support': np.float64(0.000182),
#   'precision': np.float64(0.916)},
#  {'tree_id': 3,
#   'conditions': ['last_fico_range_high > 536.500000',
#    'recoveries > 23.610001',
#    'last_fico_range_high <= 581.500000',
#    'mort_acc <= 0.500000',
#    'loan_amnt > 36012.500000'],
#   'predicted_class': 1,
#   'logit_score': 1.83309626639391,
#   'confidence': 1.833096,
#   'support': np.float64(0.00028),
#   'precision': np.float64(0.8575)},
#  {'tree_id': 3,
#   'conditions': ['last_fico_range_high > 536.500000',
#    'recoveries > 23.610001',
#    'last_fico_range_high <= 581.500000',
#    'mort_acc > 0.500000',
#    'loan_amnt <= 36012.500000'],
#   'predicted_class': 1,
#   'logit_score': 0.006960618627828772,
#   'confidence': 0.006961,
#   'support': np.float64(0.000189),
#   'precision': np.float64(1.0)},
#  {'tree_id': 3,
#   'conditions': ['last_fico_range_high > 536.500000',
#    'recoveries > 23.610001',
#    'last_fico_range_high <= 581.500000',
#    'mort_acc > 0.500000',
#    'loan_amnt > 36012.500000'],
#   'predicted_class': 1,
#   'logit_score': 0.01106932472913604,
#   'confidence': 0.011069,
#   'support': np.float64(0.000347),
#   'precision': np.float64(1.0)},
#  {'tree_id': 3,
#   'conditions': ['last_fico_range_high > 536.500000',
#    'recoveries > 23.610001',
#    'last_fico_range_high > 581.500000',
#    'mort_acc <= 0.500000',
#    'loan_amnt > 36012.500000'],
#   'predicted_class': 1,
#   'logit_score': 0.8362538068962149,
#   'confidence': 0.836254,
#   'support': np.float64(0.007576),
#   'precision': np.float64(0.0425)},
#  {'tree_id': 3,
#   'conditions': ['last_fico_range_high > 536.500000',
#    'recoveries > 23.610001',
#    'last_fico_range_high > 581.500000',
#    'mort_acc > 0.500000',
#    'loan_amnt > 36012.500000'],
#   'predicted_class': 1,
#   'logit_score': 0.0329213037370538,
#   'confidence': 0.032921,
#   'support': np.float64(0.000524),
#   'precision': np.float64(1.0)},
#  {'tree_id': 4,
#   'conditions': ['last_fico_range_high <= 249.500000',
#    'total_rec_late_fee <= 15.395000',
#    'recoveries <= 396.714996',
#    'last_fico_range_high <= 601.500000',
#    'dti <= 35.665001'],
#   'predicted_class': 0,
#   'logit_score': -5.346861239201131,
#   'confidence': 5.346861,
#   'support': np.float64(9.5e-05),
#   'precision': np.float64(0.9355)},
#  {'tree_id': 4,
#   'conditions': ['last_fico_range_high <= 249.500000',
#    'total_rec_late_fee <= 15.395000',
#    'recoveries <= 396.714996',
#    'last_fico_range_high <= 601.500000',
#    'dti > 35.665001'],
#   'predicted_class': 1,
#   'logit_score': 0.013760235065797405,
#   'confidence': 0.01376,
#   'support': np.float64(0.104078),
#   'precision': np.float64(0.4733)},
#  {'tree_id': 4,
#   'conditions': ['last_fico_range_high <= 249.500000',
#    'total_rec_late_fee <= 15.395000',
#    'recoveries <= 396.714996',
#    'last_fico_range_high > 601.500000',
#    'dti <= 35.665001'],
#   'predicted_class': 0,
#   'logit_score': -1.6495254528405503,
#   'confidence': 1.649525,
#   'support': np.float64(1e-06),
#   'precision': np.float64(1.0)},
#  {'tree_id': 4,
#   'conditions': ['last_fico_range_high <= 249.500000',
#    'total_rec_late_fee <= 15.395000',
#    'recoveries <= 396.714996',
#    'last_fico_range_high > 601.500000',
#    'dti > 35.665001'],
#   'predicted_class': 1,
#   'logit_score': 0.499650116073102,
#   'confidence': 0.49965,
#   'support': np.float64(0.007526),
#   'precision': np.float64(0.6173)},
#  {'tree_id': 4,
#   'conditions': ['last_fico_range_high <= 249.500000',
#    'total_rec_late_fee <= 15.395000',
#    'recoveries > 396.714996',
#    'last_fico_range_high <= 601.500000',
#    'dti <= 35.665001'],
#   'predicted_class': 1,
#   'logit_score': 0.0002522371850955141,
#   'confidence': 0.000252,
#   'support': np.float64(8e-06),
#   'precision': np.float64(1.0)},
#  {'tree_id': 4,
#   'conditions': ['last_fico_range_high <= 249.500000',
#    'total_rec_late_fee <= 15.395000',
#    'recoveries > 396.714996',
#    'last_fico_range_high <= 601.500000',
#    'dti > 35.665001'],
#   'predicted_class': 1,
#   'logit_score': 0.7685101948804638,
#   'confidence': 0.76851,
#   'support': np.float64(0.072479),
#   'precision': np.float64(1.0)},
#  {'tree_id': 4,
#   'conditions': ['last_fico_range_high <= 249.500000',
#    'total_rec_late_fee <= 15.395000',
#    'recoveries > 396.714996',
#    'last_fico_range_high > 601.500000',
#    'dti <= 35.665001'],
#   'predicted_class': 1,
#   'logit_score': 1.3346420469561423e-05,
#   'confidence': 1.3e-05,
#   'support': np.float64(1e-06),
#   'precision': np.float64(1.0)},
#  {'tree_id': 4,
#   'conditions': ['last_fico_range_high <= 249.500000',
#    'total_rec_late_fee <= 15.395000',
#    'recoveries > 396.714996',
#    'last_fico_range_high > 601.500000',
#    'dti > 35.665001'],
#   'predicted_class': 1,
#   'logit_score': 0.17794593138782722,
#   'confidence': 0.177946,
#   'support': np.float64(0.010596),
#   'precision': np.float64(1.0)},
#  {'tree_id': 4,
#   'conditions': ['last_fico_range_high <= 249.500000',
#    'total_rec_late_fee > 15.395000',
#    'recoveries <= 396.714996',
#    'last_fico_range_high <= 601.500000',
#    'dti > 35.665001'],
#   'predicted_class': 0,
#   'logit_score': -0.12050416979343337,
#   'confidence': 0.120504,
#   'support': np.float64(0.734686),
#   'precision': np.float64(0.9733)},
#  {'tree_id': 4,
#   'conditions': ['last_fico_range_high <= 249.500000',
#    'total_rec_late_fee > 15.395000',
#    'recoveries <= 396.714996',
#    'last_fico_range_high > 601.500000',
#    'dti > 35.665001'],
#   'predicted_class': 1,
#   'logit_score': 0.3158338202295995,
#   'confidence': 0.315834,
#   'support': np.float64(0.014001),
#   'precision': np.float64(0.1167)},
#  {'tree_id': 4,
#   'conditions': ['last_fico_range_high <= 249.500000',
#    'total_rec_late_fee > 15.395000',
#    'recoveries > 396.714996',
#    'last_fico_range_high <= 601.500000',
#    'dti > 35.665001'],
#   'predicted_class': 1,
#   'logit_score': 0.5154227780180968,
#   'confidence': 0.515423,
#   'support': np.float64(0.024333),
#   'precision': np.float64(1.0)},
#  {'tree_id': 4,
#   'conditions': ['last_fico_range_high <= 249.500000',
#    'total_rec_late_fee > 15.395000',
#    'recoveries > 396.714996',
#    'last_fico_range_high > 601.500000',
#    'dti > 35.665001'],
#   'predicted_class': 1,
#   'logit_score': 0.12479538070582888,
#   'confidence': 0.124795,
#   'support': np.float64(0.004716),
#   'precision': np.float64(1.0)},
#  {'tree_id': 4,
#   'conditions': ['last_fico_range_high > 249.500000',
#    'total_rec_late_fee <= 15.395000',
#    'recoveries <= 396.714996',
#    'last_fico_range_high <= 601.500000',
#    'dti > 35.665001'],
#   'predicted_class': 1,
#   'logit_score': 0.770152391939498,
#   'confidence': 0.770152,
#   'support': np.float64(0.003278),
#   'precision': np.float64(0.7)},
#  {'tree_id': 4,
#   'conditions': ['last_fico_range_high > 249.500000',
#    'total_rec_late_fee <= 15.395000',
#    'recoveries <= 396.714996',
#    'last_fico_range_high > 601.500000',
#    'dti > 35.665001'],
#   'predicted_class': 1,
#   'logit_score': 0.9794412698945933,
#   'confidence': 0.979441,
#   'support': np.float64(0.000254),
#   'precision': np.float64(0.7644)},
#  {'tree_id': 4,
#   'conditions': ['last_fico_range_high > 249.500000',
#    'total_rec_late_fee <= 15.395000',
#    'recoveries > 396.714996',
#    'last_fico_range_high <= 601.500000',
#    'dti > 35.665001'],
#   'predicted_class': 1,
#   'logit_score': 0.06867376796199279,
#   'confidence': 0.068674,
#   'support': np.float64(0.00293),
#   'precision': np.float64(1.0)},
#  {'tree_id': 4,
#   'conditions': ['last_fico_range_high > 249.500000',
#    'total_rec_late_fee <= 15.395000',
#    'recoveries > 396.714996',
#    'last_fico_range_high > 601.500000',
#    'dti > 35.665001'],
#   'predicted_class': 1,
#   'logit_score': 0.009783841154987318,
#   'confidence': 0.009784,
#   'support': np.float64(0.000373),
#   'precision': np.float64(1.0)},
#  {'tree_id': 4,
#   'conditions': ['last_fico_range_high > 249.500000',
#    'total_rec_late_fee > 15.395000',
#    'recoveries <= 396.714996',
#    'last_fico_range_high <= 601.500000',
#    'dti > 35.665001'],
#   'predicted_class': 1,
#   'logit_score': 0.17775615813859158,
#   'confidence': 0.177756,
#   'support': np.float64(0.018733),
#   'precision': np.float64(0.0448)},
#  {'tree_id': 4,
#   'conditions': ['last_fico_range_high > 249.500000',
#    'total_rec_late_fee > 15.395000',
#    'recoveries <= 396.714996',
#    'last_fico_range_high > 601.500000',
#    'dti > 35.665001'],
#   'predicted_class': 1,
#   'logit_score': 0.3911467805073179,
#   'confidence': 0.391147,
#   'support': np.float64(0.000507),
#   'precision': np.float64(0.1785)},
#  {'tree_id': 4,
#   'conditions': ['last_fico_range_high > 249.500000',
#    'total_rec_late_fee > 15.395000',
#    'recoveries > 396.714996',
#    'last_fico_range_high <= 601.500000',
#    'dti > 35.665001'],
#   'predicted_class': 1,
#   'logit_score': 0.04767746944634897,
#   'confidence': 0.047677,
#   'support': np.float64(0.001164),
#   'precision': np.float64(1.0)},
#  {'tree_id': 4,
#   'conditions': ['last_fico_range_high > 249.500000',
#    'total_rec_late_fee > 15.395000',
#    'recoveries > 396.714996',
#    'last_fico_range_high > 601.500000',
#    'dti > 35.665001'],
#   'predicted_class': 1,
#   'logit_score': 0.010614031812949976,
#   'confidence': 0.010614,
#   'support': np.float64(0.00024),
#   'precision': np.float64(1.0)},
#  {'tree_id': 5,
#   'conditions': ['last_fico_range_high <= 506.500000',
#    'recoveries <= 1.280000',
#    'last_fico_range_high <= 516.500000',
#    'loan_amnt <= 18987.500000',
#    'last_fico_range_high <= 656.500000'],
#   'predicted_class': 0,
#   'logit_score': -0.28729613983400704,
#   'confidence': 0.287296,
#   'support': np.float64(0.011449),
#   'precision': np.float64(0.382)},
#  {'tree_id': 5,
#   'conditions': ['last_fico_range_high <= 506.500000',
#    'recoveries <= 1.280000',
#    'last_fico_range_high <= 516.500000',
#    'loan_amnt <= 18987.500000',
#    'last_fico_range_high > 656.500000'],
#   'predicted_class': 1,
#   'logit_score': 0.2401237143632446,
#   'confidence': 0.240124,
#   'support': np.float64(0.004202),
#   'precision': np.float64(0.4775)},
#  {'tree_id': 5,
#   'conditions': ['last_fico_range_high <= 506.500000',
#    'recoveries <= 1.280000',
#    'last_fico_range_high <= 516.500000',
#    'loan_amnt > 18987.500000',
#    'last_fico_range_high <= 656.500000'],
#   'predicted_class': 1,
#   'logit_score': 0.189176843646699,
#   'confidence': 0.189177,
#   'support': np.float64(0.013223),
#   'precision': np.float64(1.0)},
#  {'tree_id': 5,
#   'conditions': ['last_fico_range_high <= 506.500000',
#    'recoveries <= 1.280000',
#    'last_fico_range_high <= 516.500000',
#    'loan_amnt > 18987.500000',
#    'last_fico_range_high > 656.500000'],
#   'predicted_class': 1,
#   'logit_score': 0.03579199979983592,
#   'confidence': 0.035792,
#   'support': np.float64(0.005304),
#   'precision': np.float64(1.0)},
#  {'tree_id': 5,
#   'conditions': ['last_fico_range_high <= 506.500000',
#    'recoveries <= 1.280000',
#    'last_fico_range_high > 516.500000',
#    'loan_amnt <= 18987.500000',
#    'last_fico_range_high > 656.500000'],
#   'predicted_class': 0,
#   'logit_score': -0.026180168120443575,
#   'confidence': 0.02618,
#   'support': np.float64(0.132938),
#   'precision': np.float64(0.8231)},
#  {'tree_id': 5,
#   'conditions': ['last_fico_range_high <= 506.500000',
#    'recoveries <= 1.280000',
#    'last_fico_range_high > 516.500000',
#    'loan_amnt > 18987.500000',
#    'last_fico_range_high > 656.500000'],
#   'predicted_class': 1,
#   'logit_score': 0.5122118985143687,
#   'confidence': 0.512212,
#   'support': np.float64(0.06882),
#   'precision': np.float64(1.0)},
#  {'tree_id': 5,
#   'conditions': ['last_fico_range_high <= 506.500000',
#    'recoveries > 1.280000',
#    'last_fico_range_high <= 516.500000',
#    'loan_amnt <= 18987.500000',
#    'last_fico_range_high <= 656.500000'],
#   'predicted_class': 0,
#   'logit_score': -0.11785239666836665,
#   'confidence': 0.117852,
#   'support': np.float64(0.003319),
#   'precision': np.float64(0.2238)},
#  {'tree_id': 5,
#   'conditions': ['last_fico_range_high <= 506.500000',
#    'recoveries > 1.280000',
#    'last_fico_range_high <= 516.500000',
#    'loan_amnt <= 18987.500000',
#    'last_fico_range_high > 656.500000'],
#   'predicted_class': 1,
#   'logit_score': 0.5483030602728798,
#   'confidence': 0.548303,
#   'support': np.float64(0.001289),
#   'precision': np.float64(0.699)},
#  {'tree_id': 5,
#   'conditions': ['last_fico_range_high <= 506.500000',
#    'recoveries > 1.280000',
#    'last_fico_range_high <= 516.500000',
#    'loan_amnt > 18987.500000',
#    'last_fico_range_high <= 656.500000'],
#   'predicted_class': 1,
#   'logit_score': 0.05430861430220657,
#   'confidence': 0.054309,
#   'support': np.float64(0.004296),
#   'precision': np.float64(1.0)},
#  {'tree_id': 5,
#   'conditions': ['last_fico_range_high <= 506.500000',
#    'recoveries > 1.280000',
#    'last_fico_range_high <= 516.500000',
#    'loan_amnt > 18987.500000',
#    'last_fico_range_high > 656.500000'],
#   'predicted_class': 1,
#   'logit_score': 0.0140064239296154,
#   'confidence': 0.014006,
#   'support': np.float64(0.002115),
#   'precision': np.float64(1.0)},
#  {'tree_id': 5,
#   'conditions': ['last_fico_range_high <= 506.500000',
#    'recoveries > 1.280000',
#    'last_fico_range_high > 516.500000',
#    'loan_amnt <= 18987.500000',
#    'last_fico_range_high > 656.500000'],
#   'predicted_class': 1,
#   'logit_score': 0.22488342161469063,
#   'confidence': 0.224883,
#   'support': np.float64(0.039899),
#   'precision': np.float64(0.3053)},
#  {'tree_id': 5,
#   'conditions': ['last_fico_range_high <= 506.500000',
#    'recoveries > 1.280000',
#    'last_fico_range_high > 516.500000',
#    'loan_amnt > 18987.500000',
#    'last_fico_range_high > 656.500000'],
#   'predicted_class': 1,
#   'logit_score': 0.3180216791198453,
#   'confidence': 0.318022,
#   'support': np.float64(0.038641),
#   'precision': np.float64(1.0)},
#  {'tree_id': 5,
#   'conditions': ['last_fico_range_high > 506.500000',
#    'recoveries <= 1.280000',
#    'last_fico_range_high > 516.500000',
#    'loan_amnt <= 18987.500000',
#    'last_fico_range_high > 656.500000'],
#   'predicted_class': 0,
#   'logit_score': -0.09747119754852372,
#   'confidence': 0.097471,
#   'support': np.float64(0.468861),
#   'precision': np.float64(0.9913)},
#  {'tree_id': 5,
#   'conditions': ['last_fico_range_high > 506.500000',
#    'recoveries <= 1.280000',
#    'last_fico_range_high > 516.500000',
#    'loan_amnt > 18987.500000',
#    'last_fico_range_high > 656.500000'],
#   'predicted_class': 1,
#   'logit_score': 0.15286560037351946,
#   'confidence': 0.152866,
#   'support': np.float64(0.005014),
#   'precision': np.float64(1.0)},
#  {'tree_id': 5,
#   'conditions': ['last_fico_range_high > 506.500000',
#    'recoveries > 1.280000',
#    'last_fico_range_high > 516.500000',
#    'loan_amnt <= 18987.500000',
#    'last_fico_range_high > 656.500000'],
#   'predicted_class': 0,
#   'logit_score': -0.10329819570060707,
#   'confidence': 0.103298,
#   'support': np.float64(0.19701),
#   'precision': np.float64(0.9895)},
#  {'tree_id': 5,
#   'conditions': ['last_fico_range_high > 506.500000',
#    'recoveries > 1.280000',
#    'last_fico_range_high > 516.500000',
#    'loan_amnt > 18987.500000',
#    'last_fico_range_high > 656.500000'],
#   'predicted_class': 1,
#   'logit_score': 0.11088202829722929,
#   'confidence': 0.110882,
#   'support': np.float64(0.003619),
#   'precision': np.float64(1.0)},
#  {'tree_id': 6,
#   'conditions': ['verification_status <= 1.500000',
#    'last_fico_range_high <= 631.500000',
#    'last_fico_range_high <= 616.500000',
#    'recoveries <= 0.005000',
#    'term_num <= 48.000000'],
#   'predicted_class': 1,
#   'logit_score': 0.09550749706057376,
#   'confidence': 0.095507,
#   'support': np.float64(0.060785),
#   'precision': np.float64(0.2899)},
#  {'tree_id': 6,
#   'conditions': ['verification_status <= 1.500000',
#    'last_fico_range_high <= 631.500000',
#    'last_fico_range_high <= 616.500000',
#    'recoveries <= 0.005000',
#    'term_num > 48.000000'],
#   'predicted_class': 0,
#   'logit_score': -0.07941191236649799,
#   'confidence': 0.079412,
#   'support': np.float64(0.025679),
#   'precision': np.float64(0.7253)},
#  {'tree_id': 6,
#   'conditions': ['verification_status <= 1.500000',
#    'last_fico_range_high <= 631.500000',
#    'last_fico_range_high > 616.500000',
#    'recoveries <= 0.005000',
#    'term_num <= 48.000000'],
#   'predicted_class': 0,
#   'logit_score': -0.2831746669427223,
#   'confidence': 0.283175,
#   'support': np.float64(0.012046),
#   'precision': np.float64(0.9117)},
#  {'tree_id': 6,
#   'conditions': ['verification_status <= 1.500000',
#    'last_fico_range_high <= 631.500000',
#    'last_fico_range_high > 616.500000',
#    'recoveries <= 0.005000',
#    'term_num > 48.000000'],
#   'predicted_class': 0,
#   'logit_score': -0.397487834133168,
#   'confidence': 0.397488,
#   'support': np.float64(0.005153),
#   'precision': np.float64(0.9103)},
#  {'tree_id': 6,
#   'conditions': ['verification_status <= 1.500000',
#    'last_fico_range_high <= 631.500000',
#    'last_fico_range_high > 616.500000',
#    'recoveries > 0.005000',
#    'term_num <= 48.000000'],
#   'predicted_class': 1,
#   'logit_score': 0.13331092302280628,
#   'confidence': 0.133311,
#   'support': np.float64(0.418695),
#   'precision': np.float64(0.0094)},
#  {'tree_id': 6,
#   'conditions': ['verification_status <= 1.500000',
#    'last_fico_range_high <= 631.500000',
#    'last_fico_range_high > 616.500000',
#    'recoveries > 0.005000',
#    'term_num > 48.000000'],
#   'predicted_class': 1,
#   'logit_score': 0.3018622152043178,
#   'confidence': 0.301862,
#   'support': np.float64(0.141057),
#   'precision': np.float64(0.013)},
#  {'tree_id': 6,
#   'conditions': ['verification_status <= 1.500000',
#    'last_fico_range_high > 631.500000',
#    'last_fico_range_high <= 616.500000',
#    'recoveries <= 0.005000',
#    'term_num <= 48.000000'],
#   'predicted_class': 1,
#   'logit_score': 0.3048788915848838,
#   'confidence': 0.304879,
#   'support': np.float64(0.046333),
#   'precision': np.float64(1.0)},
#  {'tree_id': 6,
#   'conditions': ['verification_status <= 1.500000',
#    'last_fico_range_high > 631.500000',
#    'last_fico_range_high <= 616.500000',
# ...
#   'confidence': 0.002435,
#   'support': np.float64(0.003569),
#   'precision': np.float64(1.0)},
#  {'tree_id': 39,
#   'conditions': ['total_rec_late_fee > 248.934998',
#    'acc_open_past_24mths > 2.500000',
#    'last_fico_range_high <= 581.500000',
#    'recoveries > 0.005000',
#    'last_fico_range_high > 576.500000'],
#   'predicted_class': 1,
#   'logit_score': 1.837397553359631e-06,
#   'confidence': 2e-06,
#   'support': np.float64(4e-06),
#   'precision': np.float64(1.0)},
#  {'tree_id': 39,
#   'conditions': ['total_rec_late_fee > 248.934998',
#    'acc_open_past_24mths > 2.500000',
#    'last_fico_range_high > 581.500000',
#    'recoveries <= 0.005000',
#    'last_fico_range_high <= 576.500000'],
#   'predicted_class': 1,
#   'logit_score': 0.02059076424272283,
#   'confidence': 0.020591,
#   'support': np.float64(0.0104),
#   'precision': np.float64(1.0)},
#  {'tree_id': 39,
#   'conditions': ['total_rec_late_fee > 248.934998',
#    'acc_open_past_24mths > 2.500000',
#    'last_fico_range_high > 581.500000',
#    'recoveries <= 0.005000',
#    'last_fico_range_high > 576.500000'],
#   'predicted_class': 1,
#   'logit_score': 1.7894680064397237e-05,
#   'confidence': 1.8e-05,
#   'support': np.float64(1.4e-05),
#   'precision': np.float64(1.0)},
#  {'tree_id': 39,
#   'conditions': ['total_rec_late_fee > 248.934998',
#    'acc_open_past_24mths > 2.500000',
#    'last_fico_range_high > 581.500000',
#    'recoveries > 0.005000',
#    'last_fico_range_high <= 576.500000'],
#   'predicted_class': 1,
#   'logit_score': 0.07771445124061656,
#   'confidence': 0.077714,
#   'support': np.float64(0.043399),
#   'precision': np.float64(1.0)},
#  {'tree_id': 39,
#   'conditions': ['total_rec_late_fee > 248.934998',
#    'acc_open_past_24mths > 2.500000',
#    'last_fico_range_high > 581.500000',
#    'recoveries > 0.005000',
#    'last_fico_range_high > 576.500000'],
#   'predicted_class': 1,
#   'logit_score': 4.543418890831545e-05,
#   'confidence': 4.5e-05,
#   'support': np.float64(4.5e-05),
#   'precision': np.float64(1.0)},
#  {'tree_id': 40,
#   'conditions': ['total_rec_late_fee <= 453.289978',
#    'grade <= 5.500000',
#    'fico_range_low <= 807.500000',
#    'loan_amnt <= 32512.500000',
#    'last_fico_range_high <= 641.500000'],
#   'predicted_class': 1,
#   'logit_score': 0.003549713230533686,
#   'confidence': 0.00355,
#   'support': np.float64(0.265138),
#   'precision': np.float64(0.6013)},
#  {'tree_id': 40,
#   'conditions': ['total_rec_late_fee <= 453.289978',
#    'grade <= 5.500000',
#    'fico_range_low <= 807.500000',
#    'loan_amnt <= 32512.500000',
#    'last_fico_range_high > 641.500000'],
#   'predicted_class': 0,
#   'logit_score': -0.5372504382416035,
#   'confidence': 0.53725,
#   'support': np.float64(1.4e-05),
#   'precision': np.float64(0.6111)},
#  {'tree_id': 40,
#   'conditions': ['total_rec_late_fee <= 453.289978',
#    'grade <= 5.500000',
#    'fico_range_low <= 807.500000',
#    'loan_amnt > 32512.500000',
#    'last_fico_range_high <= 641.500000'],
#   'predicted_class': 1,
#   'logit_score': 0.0043990884528350305,
#   'confidence': 0.004399,
#   'support': np.float64(0.002996),
#   'precision': np.float64(0.7623)},
#  {'tree_id': 40,
#   'conditions': ['total_rec_late_fee <= 453.289978',
#    'grade <= 5.500000',
#    'fico_range_low > 807.500000',
#    'loan_amnt <= 32512.500000',
#    'last_fico_range_high <= 641.500000'],
#   'predicted_class': 0,
#   'logit_score': -0.24576666403271058,
#   'confidence': 0.245767,
#   'support': np.float64(0.000258),
#   'precision': np.float64(0.2768)},
#  {'tree_id': 40,
#   'conditions': ['total_rec_late_fee <= 453.289978',
#    'grade <= 5.500000',
#    'fico_range_low > 807.500000',
#    'loan_amnt > 32512.500000',
#    'last_fico_range_high <= 641.500000'],
#   'predicted_class': 1,
#   'logit_score': 2.1827514054405963,
#   'confidence': 2.182751,
#   'support': np.float64(1e-06),
#   'precision': np.float64(1.0)},
#  {'tree_id': 40,
#   'conditions': ['total_rec_late_fee <= 453.289978',
#    'grade > 5.500000',
#    'fico_range_low <= 807.500000',
#    'loan_amnt <= 32512.500000',
#    'last_fico_range_high <= 641.500000'],
#   'predicted_class': 0,
#   'logit_score': -0.07039460558239902,
#   'confidence': 0.070395,
#   'support': np.float64(0.01428),
#   'precision': np.float64(0.2327)},
#  {'tree_id': 40,
#   'conditions': ['total_rec_late_fee <= 453.289978',
#    'grade > 5.500000',
#    'fico_range_low <= 807.500000',
#    'loan_amnt <= 32512.500000',
#    'last_fico_range_high > 641.500000'],
#   'predicted_class': 0,
#   'logit_score': -1.3001304946699674,
#   'confidence': 1.30013,
#   'support': np.float64(2.5e-05),
#   'precision': np.float64(0.375)},
#  {'tree_id': 40,
#   'conditions': ['total_rec_late_fee <= 453.289978',
#    'grade > 5.500000',
#    'fico_range_low <= 807.500000',
#    'loan_amnt > 32512.500000',
#    'last_fico_range_high <= 641.500000'],
#   'predicted_class': 0,
#   'logit_score': -0.15030451921852434,
#   'confidence': 0.150305,
#   'support': np.float64(0.000415),
#   'precision': np.float64(0.2251)},
#  {'tree_id': 40,
#   'conditions': ['total_rec_late_fee <= 453.289978',
#    'grade > 5.500000',
#    'fico_range_low <= 807.500000',
#    'loan_amnt > 32512.500000',
#    'last_fico_range_high > 641.500000'],
#   'predicted_class': 1,
#   'logit_score': 3.459463814677065,
#   'confidence': 3.459464,
#   'support': np.float64(2e-06),
#   'precision': np.float64(1.0)},
#  {'tree_id': 40,
#   'conditions': ['total_rec_late_fee <= 453.289978',
#    'grade > 5.500000',
#    'fico_range_low > 807.500000',
#    'loan_amnt <= 32512.500000',
#    'last_fico_range_high <= 641.500000'],
#   'predicted_class': 1,
#   'logit_score': 1.1889775349211045,
#   'confidence': 1.188978,
#   'support': np.float64(6.4e-05),
#   'precision': np.float64(0.9524)},
#  {'tree_id': 40,
#   'conditions': ['total_rec_late_fee <= 453.289978',
#    'grade > 5.500000',
#    'fico_range_low > 807.500000',
#    'loan_amnt > 32512.500000',
#    'last_fico_range_high <= 641.500000'],
#   'predicted_class': 1,
#   'logit_score': 6.989198643705089e-06,
#   'confidence': 7e-06,
#   'support': np.float64(2e-06),
#   'precision': np.float64(1.0)},
#  {'tree_id': 40,
#   'conditions': ['total_rec_late_fee > 453.289978',
#    'grade <= 5.500000',
#    'fico_range_low <= 807.500000',
#    'loan_amnt <= 32512.500000',
#    'last_fico_range_high <= 641.500000'],
#   'predicted_class': 1,
#   'logit_score': 0.0040440053288649126,
#   'confidence': 0.004044,
#   'support': np.float64(0.667494),
#   'precision': np.float64(0.0297)},
#  {'tree_id': 40,
#   'conditions': ['total_rec_late_fee > 453.289978',
#    'grade <= 5.500000',
#    'fico_range_low <= 807.500000',
#    'loan_amnt <= 32512.500000',
#    'last_fico_range_high > 641.500000'],
#   'predicted_class': 0,
#   'logit_score': -2.6644567145453584,
#   'confidence': 2.664457,
#   'support': np.float64(2.6e-05),
#   'precision': np.float64(0.9706)},
#  {'tree_id': 40,
#   'conditions': ['total_rec_late_fee > 453.289978',
#    'grade <= 5.500000',
#    'fico_range_low <= 807.500000',
#    'loan_amnt > 32512.500000',
#    'last_fico_range_high <= 641.500000'],
#   'predicted_class': 0,
#   'logit_score': -0.24662957573518524,
#   'confidence': 0.24663,
#   'support': np.float64(0.00214),
#   'precision': np.float64(0.8904)},
#  {'tree_id': 40,
#   'conditions': ['total_rec_late_fee > 453.289978',
#    'grade <= 5.500000',
#    'fico_range_low <= 807.500000',
#    'loan_amnt > 32512.500000',
#    'last_fico_range_high > 641.500000'],
#   'predicted_class': 0,
#   'logit_score': -0.25742212725977315,
#   'confidence': 0.257422,
#   'support': np.float64(2e-06),
#   'precision': np.float64(1.0)},
#  {'tree_id': 40,
#   'conditions': ['total_rec_late_fee > 453.289978',
#    'grade <= 5.500000',
#    'fico_range_low > 807.500000',
#    'loan_amnt <= 32512.500000',
#    'last_fico_range_high <= 641.500000'],
#   'predicted_class': 0,
#   'logit_score': -0.05542226960974469,
#   'confidence': 0.055422,
#   'support': np.float64(0.005971),
#   'precision': np.float64(0.9653)},
#  {'tree_id': 40,
#   'conditions': ['total_rec_late_fee > 453.289978',
#    'grade <= 5.500000',
#    'fico_range_low > 807.500000',
#    'loan_amnt > 32512.500000',
#    'last_fico_range_high <= 641.500000'],
#   'predicted_class': 1,
#   'logit_score': 4.440314891066954,
#   'confidence': 4.440315,
#   'support': np.float64(1e-06),
#   'precision': np.float64(1.0)},
#  {'tree_id': 40,
#   'conditions': ['total_rec_late_fee > 453.289978',
#    'grade > 5.500000',
#    'fico_range_low <= 807.500000',
#    'loan_amnt <= 32512.500000',
#    'last_fico_range_high <= 641.500000'],
#   'predicted_class': 0,
#   'logit_score': -0.004244072022428296,
#   'confidence': 0.004244,
#   'support': np.float64(0.040186),
#   'precision': np.float64(0.9557)},
#  {'tree_id': 40,
#   'conditions': ['total_rec_late_fee > 453.289978',
#    'grade > 5.500000',
#    'fico_range_low <= 807.500000',
#    'loan_amnt <= 32512.500000',
#    'last_fico_range_high > 641.500000'],
#   'predicted_class': 0,
#   'logit_score': -2.515667004947165,
#   'confidence': 2.515667,
#   'support': np.float64(2.8e-05),
#   'precision': np.float64(0.9722)},
#  {'tree_id': 40,
#   'conditions': ['total_rec_late_fee > 453.289978',
#    'grade > 5.500000',
#    'fico_range_low <= 807.500000',
#    'loan_amnt > 32512.500000',
#    'last_fico_range_high <= 641.500000'],
#   'predicted_class': 1,
#   'logit_score': 0.3037799969512308,
#   'confidence': 0.30378,
#   'support': np.float64(0.000357),
#   'precision': np.float64(0.1245)},
#  {'tree_id': 40,
#   'conditions': ['total_rec_late_fee > 453.289978',
#    'grade > 5.500000',
#    'fico_range_low > 807.500000',
#    'loan_amnt <= 32512.500000',
#    'last_fico_range_high <= 641.500000'],
#   'predicted_class': 0,
#   'logit_score': -0.6196091684163394,
#   'confidence': 0.619609,
#   'support': np.float64(0.000602),
#   'precision': np.float64(0.9465)},
#  {'tree_id': 41,
#   'conditions': ['dti <= 35.665001',
#    'last_fico_range_high <= 601.500000',
#    'recoveries <= 0.005000',
#    'last_fico_range_high <= 536.500000',
#    'acc_open_past_24mths <= 14.500000'],
#   'predicted_class': 0,
#   'logit_score': -0.00782182702033898,
#   'confidence': 0.007822,
#   'support': np.float64(0.031937),
#   'precision': np.float64(0.4562)},
#  {'tree_id': 41,
#   'conditions': ['dti <= 35.665001',
#    'last_fico_range_high <= 601.500000',
#    'recoveries <= 0.005000',
#    'last_fico_range_high <= 536.500000',
#    'acc_open_past_24mths > 14.500000'],
#   'predicted_class': 0,
#   'logit_score': -0.016316925881084753,
#   'confidence': 0.016317,
#   'support': np.float64(0.001071),
#   'precision': np.float64(0.2105)},
#  {'tree_id': 41,
#   'conditions': ['dti <= 35.665001',
#    'last_fico_range_high <= 601.500000',
#    'recoveries > 0.005000',
#    'last_fico_range_high <= 536.500000',
#    'acc_open_past_24mths <= 14.500000'],
#   'predicted_class': 1,
#   'logit_score': 0.0371640105924492,
#   'confidence': 0.037164,
#   'support': np.float64(0.041154),
#   'precision': np.float64(1.0)},
#  {'tree_id': 41,
#   'conditions': ['dti <= 35.665001',
#    'last_fico_range_high <= 601.500000',
#    'recoveries > 0.005000',
#    'last_fico_range_high <= 536.500000',
#    'acc_open_past_24mths > 14.500000'],
#   'predicted_class': 1,
#   'logit_score': 0.001744037234252657,
#   'confidence': 0.001744,
#   'support': np.float64(0.001255),
#   'precision': np.float64(1.0)},
#  {'tree_id': 41,
#   'conditions': ['dti <= 35.665001',
#    'last_fico_range_high > 601.500000',
#    'recoveries <= 0.005000',
#    'last_fico_range_high <= 536.500000',
#    'acc_open_past_24mths <= 14.500000'],
#   'predicted_class': 1,
#   'logit_score': 0.010318824125719614,
#   'confidence': 0.010319,
#   'support': np.float64(0.06022),
#   'precision': np.float64(0.2959)},
#  {'tree_id': 41,
#   'conditions': ['dti <= 35.665001',
#    'last_fico_range_high > 601.500000',
#    'recoveries <= 0.005000',
#    'last_fico_range_high <= 536.500000',
#    'acc_open_past_24mths > 14.500000'],
#   'predicted_class': 0,
#   'logit_score': -0.1682484626080076,
#   'confidence': 0.168248,
#   'support': np.float64(0.00187),
#   'precision': np.float64(0.428)},
#  {'tree_id': 41,
#   'conditions': ['dti <= 35.665001',
#    'last_fico_range_high > 601.500000',
#    'recoveries <= 0.005000',
#    'last_fico_range_high > 536.500000',
#    'acc_open_past_24mths <= 14.500000'],
#   'predicted_class': 0,
#   'logit_score': -0.0004995252592900798,
#   'confidence': 0.0005,
#   'support': np.float64(0.734975),
#   'precision': np.float64(0.9809)},
#  {'tree_id': 41,
#   'conditions': ['dti <= 35.665001',
#    'last_fico_range_high > 601.500000',
#    'recoveries <= 0.005000',
#    'last_fico_range_high > 536.500000',
#    'acc_open_past_24mths > 14.500000'],
#   'predicted_class': 0,
#   'logit_score': -0.008720035777823501,
#   'confidence': 0.00872,
#   'support': np.float64(0.018878),
#   'precision': np.float64(0.9603)},
#  {'tree_id': 41,
#   'conditions': ['dti <= 35.665001',
#    'last_fico_range_high > 601.500000',
#    'recoveries > 0.005000',
#    'last_fico_range_high <= 536.500000',
#    'acc_open_past_24mths <= 14.500000'],
#   'predicted_class': 1,
#   'logit_score': 0.030000817463165113,
#   'confidence': 0.030001,
#   'support': np.float64(0.058248),
#   'precision': np.float64(1.0)},
#  {'tree_id': 41,
#   'conditions': ['dti <= 35.665001',
#    'last_fico_range_high > 601.500000',
#    'recoveries > 0.005000',
#    'last_fico_range_high <= 536.500000',
#    'acc_open_past_24mths > 14.500000'],
#   'predicted_class': 1,
#   'logit_score': 0.0014796523346683249,
#   'confidence': 0.00148,
#   'support': np.float64(0.00251),
#   'precision': np.float64(1.0)},
#  {'tree_id': 41,
#   'conditions': ['dti <= 35.665001',
#    'last_fico_range_high > 601.500000',
#    'recoveries > 0.005000',
#    'last_fico_range_high > 536.500000',
#    'acc_open_past_24mths <= 14.500000'],
#   'predicted_class': 1,
#   'logit_score': 0.06850883654702801,
#   'confidence': 0.068509,
#   'support': np.float64(0.035481),
#   'precision': np.float64(1.0)},
#  {'tree_id': 41,
#   'conditions': ['dti <= 35.665001',
#    'last_fico_range_high > 601.500000',
#    'recoveries > 0.005000',
#    'last_fico_range_high > 536.500000',
#    'acc_open_past_24mths > 14.500000'],
#   'predicted_class': 1,
#   'logit_score': 0.002212614165421033,
#   'confidence': 0.002213,
#   'support': np.float64(0.001542),
#   'precision': np.float64(1.0)},
#  {'tree_id': 41,
#   'conditions': ['dti > 35.665001',
#    'last_fico_range_high <= 601.500000',
#    'recoveries <= 0.005000',
#    'last_fico_range_high <= 536.500000',
#    'acc_open_past_24mths <= 14.500000'],
#   'predicted_class': 1,
#   'logit_score': 0.11565223974327131,
#   'confidence': 0.115652,
#   'support': np.float64(0.000494),
#   'precision': np.float64(0.6351)},
#  {'tree_id': 41,
#   'conditions': ['dti > 35.665001',
#    'last_fico_range_high <= 601.500000',
#    'recoveries <= 0.005000',
#    'last_fico_range_high <= 536.500000',
#    'acc_open_past_24mths > 14.500000'],
#   'predicted_class': 0,
#   'logit_score': -1.2675942178252457,
#   'confidence': 1.267594,
#   'support': np.float64(1.4e-05),
#   'precision': np.float64(0.2778)},
#  {'tree_id': 41,
#   'conditions': ['dti > 35.665001',
#    'last_fico_range_high <= 601.500000',
#    'recoveries > 0.005000',
#    'last_fico_range_high <= 536.500000',
#    'acc_open_past_24mths <= 14.500000'],
#   'predicted_class': 1,
#   'logit_score': 0.000491054490604669,
#   'confidence': 0.000491,
#   'support': np.float64(0.000693),
#   'precision': np.float64(1.0)},
#  {'tree_id': 41,
#   'conditions': ['dti > 35.665001',
#    'last_fico_range_high <= 601.500000',
#    'recoveries > 0.005000',
#    'last_fico_range_high <= 536.500000',
#    'acc_open_past_24mths > 14.500000'],
#   'predicted_class': 1,
#   'logit_score': 4.2781535323804825e-05,
#   'confidence': 4.3e-05,
#   'support': np.float64(3.3e-05),
#   'precision': np.float64(1.0)},
#  {'tree_id': 41,
#   'conditions': ['dti > 35.665001',
#    'last_fico_range_high > 601.500000',
#    'recoveries <= 0.005000',
#    'last_fico_range_high <= 536.500000',
#    'acc_open_past_24mths <= 14.500000'],
#   'predicted_class': 0,
#   'logit_score': -0.025839344787514786,
#   'confidence': 0.025839,
#   'support': np.float64(0.00099),
#   'precision': np.float64(0.646)},
#  {'tree_id': 41,
#   'conditions': ['dti > 35.665001',
#    'last_fico_range_high > 601.500000',
#    'recoveries <= 0.005000',
#    'last_fico_range_high <= 536.500000',
#    'acc_open_past_24mths > 14.500000'],
#   'predicted_class': 1,
#   'logit_score': 0.3090686118151298,
#   'confidence': 0.309069,
#   'support': np.float64(3.1e-05),
#   'precision': np.float64(0.561)},
#  ...]

# %%
cat_mappings_fixed = {
    var: {code: cat for cat, code in mapping.items()}
    for var, mapping in cat_mappings.items()
}

print("[INFO] CREATING FUZZY SYSTEM (ONE-TIME SETUP)")

#Comparing the performance of different tree-based strategies for rule extraction, use logits as the output type for the fuzzy inference system to capture the confidence of predictions, which can enhance the interpretability and performance of the system.
results = cr.compare_tree_strategies(structured_rules, [5,10, 15, 20, 25, 30, 35, 40, 45 ,50,55,60,65])
# Out:
# [INFO] CREATING FUZZY SYSTEM (ONE-TIME SETUP)
#
# [INFO] -------------------- Comparing Tree Strategies --------------------
# [INFO] Total trees available: 68
#
# [INFO] 5 trees:
#   Rules: 159 (C0:45, C1:114)
#   Sum C0: -12.3
#   Sum C1: 11.5
#   Net:    -0.8
#
# [INFO] 10 trees:
#   Rules: 319 (C0:84, C1:235)
#   Sum C0: -17.3
#   Sum C1: 20.0
#   Net:    +2.7
#
# [INFO] 15 trees:
#   Rules: 463 (C0:120, C1:343)
#   Sum C0: -29.0
#   Sum C1: 77.6
#   Net:    +48.6
#
# [INFO] 20 trees:
#   Rules: 589 (C0:159, C1:430)
#   Sum C0: -49.3
#   Sum C1: 113.3
#   Net:    +64.1
#
# [INFO] 25 trees:
#   Rules: 717 (C0:204, C1:513)
#   Sum C0: -65.4
#   Sum C1: 124.5
#   Net:    +59.1
#
# [INFO] 30 trees:
#   Rules: 836 (C0:232, C1:604)
#   Sum C0: -70.4
#   Sum C1: 138.0
#   Net:    +67.6
#
# [INFO] 35 trees:
#   Rules: 956 (C0:261, C1:695)
#   Sum C0: -76.6
#   Sum C1: 144.5
#   Net:    +67.9
#
# [INFO] 40 trees:
#   Rules: 1068 (C0:284, C1:784)
#   Sum C0: -93.2
#   Sum C1: 280.2
#   Net:    +187.0
#
# [INFO] 45 trees:
#   Rules: 1175 (C0:317, C1:858)
#   Sum C0: -107.5
#   Sum C1: 292.2
#   Net:    +184.6
#
# [INFO] 50 trees:
#   Rules: 1299 (C0:381, C1:918)
#   Sum C0: -147.7
#   Sum C1: 333.4
#   Net:    +185.6
#
# [INFO] 55 trees:
#   Rules: 1410 (C0:442, C1:968)
#   Sum C0: -173.4
#   Sum C1: 359.5
#   Net:    +186.1
#
# [INFO] 60 trees:
#   Rules: 1513 (C0:488, C1:1025)
#   Sum C0: -199.4
#   Sum C1: 377.7
#   Net:    +178.3
#
# [INFO] 65 trees:
#   Rules: 1617 (C0:539, C1:1078)
#   Sum C0: -210.7
#   Sum C1: 387.4
#   Net:    +176.7
#
# [INFO] ----------------------------------------------------------------
# [INFO] BEST BALANCE: 5 trees
#   Net sum: -0.8 (closest to 0)
#   Rules: 159
# [INFO] ----------------------------------------------------------------

# %%
import time
setup_start = time.time()

X_test_encoded = mod.encode_data_like_training(X_test, cat_mappings)
n_trees = 25

filtered_rules = cr.select_best_trees(structured_rules, n_trees=n_trees)
threshold = catboost_metrics['optimal_threshold']

cutpoints, linguistic_terms, fuzzy_rules, _ = fi.evaluate_fuzzy_system(
    catboost_rules=filtered_rules,
    catboost_predictions=catboost_model.predict(X_test_encoded[:100]),
    X_train=X_train_encoded,
    X_test=X_test_encoded[:100],
    y_test=y_test.values[:100],
    category_mappings=cat_mappings_fixed,
    classification_threshold=0.5,
    t_norm_operator='min',
    evaluation_sample_size=100,
    parallel_jobs=1,
    apply_purpose_grouping=True
)

setup_time = time.time() - setup_start

print(f"\n[INFO] Fuzzy system created in {setup_time:.1f}s:")
print(f"  Variables: {len(linguistic_terms)}")
print(f"  Fuzzy rules: {len(fuzzy_rules):,}")
print(f"  Categorical decoded: {sum(1 for r in fuzzy_rules for a in r['antecedents'] if a.get('is_categorical', False)):,}")
# Out:
# [INFO] -------------------- Selecting 25 Best Trees --------------------
#
# [INFO] Selected 717 rules from 25 trees
#   Class 0: 204 rules, sum=-65.4
#   Class 1: 513 rules, sum=124.5
#   Net sum: +59.1
#   Imbalanced
# [INFO] ----------------------------------------------------------------
#
# [INFO] -------------------- Fuzzy CatBoost System Evaluation --------------------
# Classification threshold: 0.5
# T-norm operator: min
# Purpose grouping: True
# All features treated as numeric (categorical pre-encoded)
# [INFO] -------------------------------------------------------------------------
#
# [INFO] Step 1: Extracting variable conditions from rules
# [INFO] Rules processed: 717
# [INFO] Variables identified: 12
#
# [INFO] Step 2: Optimizing cutpoints with auto-strategy selection
# [INFO] last_fico_range_high: numeric -> adaptive, 13 cutpoints, 7 terms
# [INFO] recoveries: numeric -> adaptive, 4 cutpoints, 3 terms
# [INFO] debt_settlement_flag: categorical [CATEGORICAL] -> density_, 4 cutpoints, 3 terms
# [INFO] dti: numeric -> adaptive, 5 cutpoints, 4 terms
# [INFO] mort_acc: numeric -> linear_p, 8 cutpoints, 6 terms
# [INFO] loan_amnt: numeric -> adaptive, 22 cutpoints, 7 terms
# [INFO] acc_open_past_24mths: numeric -> linear_p, 9 cutpoints, 7 terms
# [INFO] fico_range_low: numeric -> linear_p, 12 cutpoints, 7 terms
# [INFO] term_num: numeric -> density_, 4 cutpoints, 3 terms
# [INFO] grade: categorical [CATEGORICAL] -> linear_p, 7 cutpoints, 5 terms
# [INFO] total_rec_late_fee: numeric -> adaptive, 5 cutpoints, 4 terms
# [INFO] verification_status: categorical [CATEGORICAL] -> density_, 6 cutpoints, 4 terms
#
# [INFO] Total variables processed: 12
#
# [INFO] -------------------- Cutpoint Optimization Summary --------------------
#
# Method                                        Variables    Percentage
# ----------------------------------------------------------------------
# Adaptive Percentile Alignment                 5              41.7%
# Constrained Mathematical Programming          4              33.3%
# Density-Weighted K-Means Clustering           3              25.0%
# ----------------------------------------------------------------------
# TOTAL                                         12            100.0%
#
# [INFO] -------------------- Variables by Optimization Method --------------------
#
# Adaptive Percentile Alignment (5 variables):
# ----------------------------------------------------------------------
#   dti                        last_fico_range_high       loan_amnt
#   recoveries                 total_rec_late_fee
#
# Constrained Mathematical Programming (4 variables):
# ----------------------------------------------------------------------
#   acc_open_past_24mths       fico_range_low             grade
#   mort_acc
#
# Density-Weighted K-Means Clustering (3 variables):
# ----------------------------------------------------------------------
#   debt_settlement_flag       term_num                   verification_status
#
# [INFO] -------------------- Cutpoint and Linguistic Term Statistics --------------------
#
# Cutpoints per variable:
#   Min:     4
#   Max:     22
#   Mean:    8.2
#   Median:  6.5
#
# Linguistic terms per variable:
#   Min:     3
#   Max:     7
#   Mean:    5.0
#   Median:  4.5
#
# Linguistic term distribution:
# # Terms      # Variables     Percentage
# ---------------------------------------------
# 3            3                 25.0%
# 4            3                 25.0%
# 5            1                  8.3%
# 6            1                  8.3%
# 7            4                 33.3%
# [INFO] -------------------------------------------------------------------------
#
# [INFO] Step 3: Transforming rules to fuzzy format
# [INFO] Fuzzy rules created: 717
# [INFO] Categorical conditions decoded: 352
#
# [INFO] Step 5: Executing fuzzy inference (parallel_jobs=1)
#
# [INFO] Preparing optimized inference
# [INFO] Total trees: 25
# [INFO] Total rules: 717
# [INFO] Samples: 100
# [INFO] Batch size: 100
# [INFO] Using ALL trees (pre-selected by select_best_trees)
# [INFO] Batches: 1
# [INFO] Parallel jobs: 1
#
# [INFO] Starting inference
#
# [INFO] Inference completed in 0.1s
# [INFO] Throughput: 692.9 samples/sec
#
# [INFO] Step 6: Calculating performance metrics
#
# [INFO] -------------------- Evaluation Results --------------------
#
# Metric          Fuzzy      CatBoost   Difference   % Change
# ------------------------------------------------------------
# Accuracy        0.1200     0.9600          -0.8400     -87.5%
# Sensitivity     1.0000     0.7273          +0.2727     +37.5%
# Precision       0.1111     0.8889          -0.7778     -87.5%
# F1_score        0.2000     0.8000          -0.6000     -75.0%
#
# [INFO] ----------------------------------------------------------------
#
# [INFO] Fuzzy system created in 30.9s:
#   Variables: 12
#   Fuzzy rules: 717
#   Categorical decoded: 352
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s finished

# %%
print("\n[INFO] -------------------- Grid Search: Threshold --------------------")

top_k_values = [n_trees]
threshold_values = [0.20, 0.25, 0.30, 0.35, 0.40, 0.45, 0.50, 0.55, 0.60, 0.65, 0.7, 0.75, 0.80]

best_f1 = 0.0
best_config = None
results_grid = []

sample_size = 50000 #Use a larger sample size for more reliable evaluation, but be mindful of execution time.

sss = StratifiedShuffleSplit(
    n_splits=1, 
    test_size=sample_size, 
    random_state=42
)

y_test_array = y_test.values if isinstance(y_test, pd.Series) else y_test

sample_idx = next(sss.split(X_test_encoded, y_test_array))[1]

y_test_array = y_test.values if isinstance(y_test, pd.Series) else y_test

X_test_sample = X_test_encoded.iloc[sample_idx].reset_index(drop=True)
y_test_sample = y_test_array[sample_idx]

print(f"\n[INFO] Test sample: {len(X_test_sample):,} samples")
print(f"[INFO] Configurations to test: {len(top_k_values) * len(threshold_values)}")

for i, (top_k, threshold) in enumerate([(k, t) for k in top_k_values for t in threshold_values]):
    print(f"\n[INFO] ----------------------------------------------------------------")
    print(f"[INFO] Config {i+1}/{len(top_k_values)*len(threshold_values)}: top_k={top_k}, threshold={threshold}")
    print(f"[INFO] ----------------------------------------------------------------")
    
    try:
        config_start = time.time()
        
        fuzzy_predictions = fi.execute_fuzzy_inference(
            X_test_sample,
            fuzzy_rules,
            linguistic_terms,
            cat_mappings_fixed,
            t_norm_operator='min',
            classification_threshold=threshold,
            parallel_jobs=-1
        )
        
        config_time = time.time() - config_start
        
        acc = accuracy_score(y_test_sample, fuzzy_predictions)
        sens = recall_score(y_test_sample, fuzzy_predictions, pos_label=1, zero_division=0)
        prec = precision_score(y_test_sample, fuzzy_predictions, pos_label=1, zero_division=0)
        f1 = f1_score(y_test_sample, fuzzy_predictions, pos_label=1, zero_division=0)
        
        cm = confusion_matrix(y_test_sample, fuzzy_predictions)
        tn, fp, fn, tp = cm.ravel()
        
        results_grid.append({
            'top_k': top_k,
            'threshold': threshold,
            'accuracy': acc,
            'sensitivity': sens,
            'precision': prec,
            'f1_score': f1,
            'time_sec': config_time,
            'tp': int(tp),
            'fp': int(fp),
            'tn': int(tn),
            'fn': int(fn)
        })
        
        if f1 > best_f1:
            best_f1 = f1
            best_config = (top_k, threshold)
            best_predictions = fuzzy_predictions.copy()
        
        print(f"\n[INFO] Completed in {config_time:.1f}s")
        print(f"\n[INFO] Metrics:")
        print(f"    Accuracy:    {acc:.4f}")
        print(f"    Sensitivity: {sens:.4f}")
        print(f"    Precision:   {prec:.4f}")
        print(f"    F1:          {f1:.4f}")
        
        print(f"\n[INFO] Confusion Matrix:")
        print(f"    TP: {tp:,}  FP: {fp:,}")
        print(f"    FN: {fn:,}  TN: {tn:,}")
        
    except Exception as e:
        print(f"\n[ERROR] {e}")
        import traceback
        traceback.print_exc()
        continue

print("\n[INFO] -------------------- Grid Search Results --------------------")

if len(results_grid) > 0:
    print(f"\n{'Top-K':<8} {'Thresh':<8} {'Acc':<8} {'Sens':<8} {'Prec':<8} {'F1':<8} {'Time(s)':<10}")
    print("-" * 70)
    
    for result in sorted(results_grid, key=lambda x: x['f1_score'], reverse=True):
        marker = " <- BEST" if (result['top_k'], result['threshold']) == best_config else ""
        print(f"{result['top_k']:<8} {result['threshold']:<8.2f} "
              f"{result['accuracy']:<8.4f} {result['sensitivity']:<8.4f} "
              f"{result['precision']:<8.4f} {result['f1_score']:<8.4f} "
              f"{result['time_sec']:<10.1f}{marker}")
    
    if best_config:
        print(f"\n[INFO] -------------------- Best Configuration --------------------")
        
        best_result = [r for r in results_grid if (r['top_k'], r['threshold']) == best_config][0]
        
        print(f"\n[INFO] Configuration:")
        print(f"  Top-K trees: {best_config[0]}")
        print(f"  Threshold:   {best_config[1]}")
        
        print(f"\n[INFO] Performance:")
        print(f"  Accuracy:    {best_result['accuracy']:.4f}")
        print(f"  Sensitivity: {best_result['sensitivity']:.4f}")
        print(f"  Precision:   {best_result['precision']:.4f}")
        print(f"  F1-Score:    {best_result['f1_score']:.4f}")
        
        print(f"\n[INFO] Confusion Matrix:")
        print(f"                 Predicted")
        print(f"               Good (0)  Bad (1)")
        print(f"  Actual Good  {best_result['tn']:8,}  {best_result['fp']:8,}")
        print(f"         Bad   {best_result['fn']:8,}  {best_result['tp']:8,}")

else:
    print("\n[ERROR] No results obtained - check for errors")

print("\n[INFO] ----------------------------------------------------------------")
# Out:
# [INFO] -------------------- Grid Search: Threshold --------------------
#
# [INFO] Test sample: 50,000 samples
# [INFO] Configurations to test: 13
#
# [INFO] ----------------------------------------------------------------
# [INFO] Config 1/13: top_k=25, threshold=0.2
# [INFO] ----------------------------------------------------------------
#
# [INFO] Preparing optimized inference
# [INFO] Total trees: 25
# [INFO] Total rules: 717
# [INFO] Samples: 50,000
# [INFO] Batch size: 100
# [INFO] Using ALL trees (pre-selected by select_best_trees)
# [INFO] Batches: 500
# [INFO] Parallel jobs: -1
#
# [INFO] Starting inference
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  40 tasks      | elapsed:    3.8s
# [Parallel(n_jobs=-1)]: Done 130 tasks      | elapsed:    6.0s
# [Parallel(n_jobs=-1)]: Done 256 tasks      | elapsed:    9.2s
# [Parallel(n_jobs=-1)]: Done 418 tasks      | elapsed:   13.3s
# [Parallel(n_jobs=-1)]: Done 500 out of 500 | elapsed:   15.3s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [INFO] Inference completed in 15.5s
# [INFO] Throughput: 3217.6 samples/sec
#
# [INFO] Completed in 15.5s
#
# [INFO] Metrics:
#     Accuracy:    0.1947
#     Sensitivity: 1.0000
#     Precision:   0.1947
#     F1:          0.3259
#
# [INFO] Confusion Matrix:
#     TP: 9,734  FP: 40,265
#     FN: 0  TN: 1
#
# [INFO] ----------------------------------------------------------------
# [INFO] Config 2/13: top_k=25, threshold=0.25
# [INFO] ----------------------------------------------------------------
#
# [INFO] Preparing optimized inference
# [INFO] Total trees: 25
# [INFO] Total rules: 717
# [INFO] Samples: 50,000
# [INFO] Batch size: 100
# [INFO] Using ALL trees (pre-selected by select_best_trees)
# [INFO] Batches: 500
# [INFO] Parallel jobs: -1
#
# [INFO] Starting inference
# [Parallel(n_jobs=-1)]: Done  40 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=-1)]: Done 130 tasks      | elapsed:    3.5s
# [Parallel(n_jobs=-1)]: Done 256 tasks      | elapsed:    6.8s
# [Parallel(n_jobs=-1)]: Done 418 tasks      | elapsed:   11.0s
# [Parallel(n_jobs=-1)]: Done 500 out of 500 | elapsed:   13.2s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [INFO] Inference completed in 13.4s
# [INFO] Throughput: 3723.1 samples/sec
#
# [INFO] Completed in 13.4s
#
# [INFO] Metrics:
#     Accuracy:    0.1947
#     Sensitivity: 1.0000
#     Precision:   0.1947
#     F1:          0.3259
#
# [INFO] Confusion Matrix:
#     TP: 9,734  FP: 40,265
#     FN: 0  TN: 1
#
# [INFO] ----------------------------------------------------------------
# [INFO] Config 3/13: top_k=25, threshold=0.3
# [INFO] ----------------------------------------------------------------
#
# [INFO] Preparing optimized inference
# [INFO] Total trees: 25
# [INFO] Total rules: 717
# [INFO] Samples: 50,000
# [INFO] Batch size: 100
# [INFO] Using ALL trees (pre-selected by select_best_trees)
# [INFO] Batches: 500
# [INFO] Parallel jobs: -1
#
# [INFO] Starting inference
# [Parallel(n_jobs=-1)]: Done  40 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=-1)]: Done 130 tasks      | elapsed:    3.5s
# [Parallel(n_jobs=-1)]: Done 256 tasks      | elapsed:    6.8s
# [Parallel(n_jobs=-1)]: Done 418 tasks      | elapsed:   11.0s
# [Parallel(n_jobs=-1)]: Done 500 out of 500 | elapsed:   13.1s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [INFO] Inference completed in 13.4s
# [INFO] Throughput: 3742.4 samples/sec
#
# [INFO] Completed in 13.4s
#
# [INFO] Metrics:
#     Accuracy:    0.1947
#     Sensitivity: 1.0000
#     Precision:   0.1947
#     F1:          0.3259
#
# [INFO] Confusion Matrix:
#     TP: 9,734  FP: 40,264
#     FN: 0  TN: 2
#
# [INFO] ----------------------------------------------------------------
# [INFO] Config 4/13: top_k=25, threshold=0.35
# [INFO] ----------------------------------------------------------------
#
# [INFO] Preparing optimized inference
# [INFO] Total trees: 25
# [INFO] Total rules: 717
# [INFO] Samples: 50,000
# [INFO] Batch size: 100
# [INFO] Using ALL trees (pre-selected by select_best_trees)
# [INFO] Batches: 500
# [INFO] Parallel jobs: -1
#
# [INFO] Starting inference
# [Parallel(n_jobs=-1)]: Done  40 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=-1)]: Done 130 tasks      | elapsed:    3.6s
# [Parallel(n_jobs=-1)]: Done 256 tasks      | elapsed:    6.9s
# [Parallel(n_jobs=-1)]: Done 418 tasks      | elapsed:   11.2s
# [Parallel(n_jobs=-1)]: Done 500 out of 500 | elapsed:   13.1s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [INFO] Inference completed in 13.3s
# [INFO] Throughput: 3749.0 samples/sec
#
# [INFO] Completed in 13.3s
#
# [INFO] Metrics:
#     Accuracy:    0.1948
#     Sensitivity: 1.0000
#     Precision:   0.1947
#     F1:          0.3259
#
# [INFO] Confusion Matrix:
#     TP: 9,734  FP: 40,262
#     FN: 0  TN: 4
#
# [INFO] ----------------------------------------------------------------
# [INFO] Config 5/13: top_k=25, threshold=0.4
# [INFO] ----------------------------------------------------------------
#
# [INFO] Preparing optimized inference
# [INFO] Total trees: 25
# [INFO] Total rules: 717
# [INFO] Samples: 50,000
# [INFO] Batch size: 100
# [INFO] Using ALL trees (pre-selected by select_best_trees)
# [INFO] Batches: 500
# [INFO] Parallel jobs: -1
#
# [INFO] Starting inference
# [Parallel(n_jobs=-1)]: Done  40 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=-1)]: Done 130 tasks      | elapsed:    3.6s
# [Parallel(n_jobs=-1)]: Done 256 tasks      | elapsed:    6.9s
# [Parallel(n_jobs=-1)]: Done 418 tasks      | elapsed:   11.3s
# [Parallel(n_jobs=-1)]: Done 500 out of 500 | elapsed:   13.3s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [INFO] Inference completed in 13.5s
# [INFO] Throughput: 3702.7 samples/sec
#
# [INFO] Completed in 13.5s
#
# [INFO] Metrics:
#     Accuracy:    0.1948
#     Sensitivity: 0.9999
#     Precision:   0.1947
#     F1:          0.3259
#
# [INFO] Confusion Matrix:
#     TP: 9,733  FP: 40,259
#     FN: 1  TN: 7
#
# [INFO] ----------------------------------------------------------------
# [INFO] Config 6/13: top_k=25, threshold=0.45
# [INFO] ----------------------------------------------------------------
#
# [INFO] Preparing optimized inference
# [INFO] Total trees: 25
# [INFO] Total rules: 717
# [INFO] Samples: 50,000
# [INFO] Batch size: 100
# [INFO] Using ALL trees (pre-selected by select_best_trees)
# [INFO] Batches: 500
# [INFO] Parallel jobs: -1
#
# [INFO] Starting inference
# [Parallel(n_jobs=-1)]: Done  40 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=-1)]: Done 130 tasks      | elapsed:    3.5s
# [Parallel(n_jobs=-1)]: Done 256 tasks      | elapsed:    7.0s
# [Parallel(n_jobs=-1)]: Done 418 tasks      | elapsed:   11.2s
# [Parallel(n_jobs=-1)]: Done 500 out of 500 | elapsed:   13.3s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [INFO] Inference completed in 13.5s
# [INFO] Throughput: 3710.3 samples/sec
#
# [INFO] Completed in 13.5s
#
# [INFO] Metrics:
#     Accuracy:    0.1950
#     Sensitivity: 0.9993
#     Precision:   0.1947
#     F1:          0.3258
#
# [INFO] Confusion Matrix:
#     TP: 9,727  FP: 40,243
#     FN: 7  TN: 23
#
# [INFO] ----------------------------------------------------------------
# [INFO] Config 7/13: top_k=25, threshold=0.5
# [INFO] ----------------------------------------------------------------
#
# [INFO] Preparing optimized inference
# [INFO] Total trees: 25
# [INFO] Total rules: 717
# [INFO] Samples: 50,000
# [INFO] Batch size: 100
# [INFO] Using ALL trees (pre-selected by select_best_trees)
# [INFO] Batches: 500
# [INFO] Parallel jobs: -1
#
# [INFO] Starting inference
# [Parallel(n_jobs=-1)]: Done  40 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=-1)]: Done 130 tasks      | elapsed:    3.7s
# [Parallel(n_jobs=-1)]: Done 256 tasks      | elapsed:    7.1s
# [Parallel(n_jobs=-1)]: Done 418 tasks      | elapsed:   11.4s
# [Parallel(n_jobs=-1)]: Done 500 out of 500 | elapsed:   13.5s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [INFO] Inference completed in 13.7s
# [INFO] Throughput: 3639.2 samples/sec
#
# [INFO] Completed in 13.7s
#
# [INFO] Metrics:
#     Accuracy:    0.1957
#     Sensitivity: 0.9984
#     Precision:   0.1947
#     F1:          0.3258
#
# [INFO] Confusion Matrix:
#     TP: 9,718  FP: 40,198
#     FN: 16  TN: 68
#
# [INFO] ----------------------------------------------------------------
# [INFO] Config 8/13: top_k=25, threshold=0.55
# [INFO] ----------------------------------------------------------------
#
# [INFO] Preparing optimized inference
# [INFO] Total trees: 25
# [INFO] Total rules: 717
# [INFO] Samples: 50,000
# [INFO] Batch size: 100
# [INFO] Using ALL trees (pre-selected by select_best_trees)
# [INFO] Batches: 500
# [INFO] Parallel jobs: -1
#
# [INFO] Starting inference
# [Parallel(n_jobs=-1)]: Done  40 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=-1)]: Done 130 tasks      | elapsed:    3.6s
# [Parallel(n_jobs=-1)]: Done 256 tasks      | elapsed:    7.0s
# [Parallel(n_jobs=-1)]: Done 418 tasks      | elapsed:   11.3s
# [Parallel(n_jobs=-1)]: Done 500 out of 500 | elapsed:   13.4s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [INFO] Inference completed in 13.6s
# [INFO] Throughput: 3670.5 samples/sec
#
# [INFO] Completed in 13.6s
#
# [INFO] Metrics:
#     Accuracy:    0.1995
#     Sensitivity: 0.9955
#     Precision:   0.1951
#     F1:          0.3262
#
# [INFO] Confusion Matrix:
#     TP: 9,690  FP: 39,980
#     FN: 44  TN: 286
#
# [INFO] ----------------------------------------------------------------
# [INFO] Config 9/13: top_k=25, threshold=0.6
# [INFO] ----------------------------------------------------------------
#
# [INFO] Preparing optimized inference
# [INFO] Total trees: 25
# [INFO] Total rules: 717
# [INFO] Samples: 50,000
# [INFO] Batch size: 100
# [INFO] Using ALL trees (pre-selected by select_best_trees)
# [INFO] Batches: 500
# [INFO] Parallel jobs: -1
#
# [INFO] Starting inference
# [Parallel(n_jobs=-1)]: Done  40 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=-1)]: Done 130 tasks      | elapsed:    3.6s
# [Parallel(n_jobs=-1)]: Done 256 tasks      | elapsed:    6.9s
# [Parallel(n_jobs=-1)]: Done 418 tasks      | elapsed:   11.2s
# [Parallel(n_jobs=-1)]: Done 500 out of 500 | elapsed:   13.3s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [INFO] Inference completed in 13.5s
# [INFO] Throughput: 3704.7 samples/sec
#
# [INFO] Completed in 13.5s
#
# [INFO] Metrics:
#     Accuracy:    0.2169
#     Sensitivity: 0.9856
#     Precision:   0.1974
#     F1:          0.3289
#
# [INFO] Confusion Matrix:
#     TP: 9,594  FP: 39,016
#     FN: 140  TN: 1,250
#
# [INFO] ----------------------------------------------------------------
# [INFO] Config 10/13: top_k=25, threshold=0.65
# [INFO] ----------------------------------------------------------------
#
# [INFO] Preparing optimized inference
# [INFO] Total trees: 25
# [INFO] Total rules: 717
# [INFO] Samples: 50,000
# [INFO] Batch size: 100
# [INFO] Using ALL trees (pre-selected by select_best_trees)
# [INFO] Batches: 500
# [INFO] Parallel jobs: -1
#
# [INFO] Starting inference
# [Parallel(n_jobs=-1)]: Done  40 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=-1)]: Done 130 tasks      | elapsed:    3.7s
# [Parallel(n_jobs=-1)]: Done 256 tasks      | elapsed:    7.0s
# [Parallel(n_jobs=-1)]: Done 418 tasks      | elapsed:   11.3s
# [Parallel(n_jobs=-1)]: Done 500 out of 500 | elapsed:   13.4s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [INFO] Inference completed in 13.6s
# [INFO] Throughput: 3683.7 samples/sec
#
# [INFO] Completed in 13.6s
#
# [INFO] Metrics:
#     Accuracy:    0.2810
#     Sensitivity: 0.9584
#     Precision:   0.2079
#     F1:          0.3417
#
# [INFO] Confusion Matrix:
#     TP: 9,329  FP: 35,543
#     FN: 405  TN: 4,723
#
# [INFO] ----------------------------------------------------------------
# [INFO] Config 11/13: top_k=25, threshold=0.7
# [INFO] ----------------------------------------------------------------
#
# [INFO] Preparing optimized inference
# [INFO] Total trees: 25
# [INFO] Total rules: 717
# [INFO] Samples: 50,000
# [INFO] Batch size: 100
# [INFO] Using ALL trees (pre-selected by select_best_trees)
# [INFO] Batches: 500
# [INFO] Parallel jobs: -1
#
# [INFO] Starting inference
# [Parallel(n_jobs=-1)]: Done  40 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=-1)]: Done 130 tasks      | elapsed:    3.7s
# [Parallel(n_jobs=-1)]: Done 256 tasks      | elapsed:    7.0s
# [Parallel(n_jobs=-1)]: Done 418 tasks      | elapsed:   11.2s
# [Parallel(n_jobs=-1)]: Done 500 out of 500 | elapsed:   13.3s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [INFO] Inference completed in 13.5s
# [INFO] Throughput: 3695.1 samples/sec
#
# [INFO] Completed in 13.5s
#
# [INFO] Metrics:
#     Accuracy:    0.4338
#     Sensitivity: 0.9153
#     Precision:   0.2448
#     F1:          0.3863
#
# [INFO] Confusion Matrix:
#     TP: 8,910  FP: 27,486
#     FN: 824  TN: 12,780
#
# [INFO] ----------------------------------------------------------------
# [INFO] Config 12/13: top_k=25, threshold=0.75
# [INFO] ----------------------------------------------------------------
#
# [INFO] Preparing optimized inference
# [INFO] Total trees: 25
# [INFO] Total rules: 717
# [INFO] Samples: 50,000
# [INFO] Batch size: 100
# [INFO] Using ALL trees (pre-selected by select_best_trees)
# [INFO] Batches: 500
# [INFO] Parallel jobs: -1
#
# [INFO] Starting inference
# [Parallel(n_jobs=-1)]: Done  40 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=-1)]: Done 130 tasks      | elapsed:    3.7s
# [Parallel(n_jobs=-1)]: Done 256 tasks      | elapsed:    7.0s
# [Parallel(n_jobs=-1)]: Done 418 tasks      | elapsed:   11.3s
# [Parallel(n_jobs=-1)]: Done 500 out of 500 | elapsed:   13.3s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [INFO] Inference completed in 13.6s
# [INFO] Throughput: 3685.5 samples/sec
#
# [INFO] Completed in 13.6s
#
# [INFO] Metrics:
#     Accuracy:    0.6592
#     Sensitivity: 0.8728
#     Precision:   0.3496
#     F1:          0.4993
#
# [INFO] Confusion Matrix:
#     TP: 8,496  FP: 15,803
#     FN: 1,238  TN: 24,463
#
# [INFO] ----------------------------------------------------------------
# [INFO] Config 13/13: top_k=25, threshold=0.8
# [INFO] ----------------------------------------------------------------
#
# [INFO] Preparing optimized inference
# [INFO] Total trees: 25
# [INFO] Total rules: 717
# [INFO] Samples: 50,000
# [INFO] Batch size: 100
# [INFO] Using ALL trees (pre-selected by select_best_trees)
# [INFO] Batches: 500
# [INFO] Parallel jobs: -1
#
# [INFO] Starting inference
# [Parallel(n_jobs=-1)]: Done  40 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=-1)]: Done 130 tasks      | elapsed:    3.7s
# [Parallel(n_jobs=-1)]: Done 256 tasks      | elapsed:    7.0s
# [Parallel(n_jobs=-1)]: Done 418 tasks      | elapsed:   11.4s
# [INFO] Inference completed in 13.6s
# [INFO] Throughput: 3665.3 samples/sec
#
# [INFO] Completed in 13.6s
#
# [INFO] Metrics:
#     Accuracy:    0.8037
#     Sensitivity: 0.8202
#     Precision:   0.4975
#     F1:          0.6193
#
# [INFO] Confusion Matrix:
#     TP: 7,984  FP: 8,065
#     FN: 1,750  TN: 32,201
#
# [INFO] -------------------- Grid Search Results --------------------
#
# Top-K    Thresh   Acc      Sens     Prec     F1       Time(s)
# ----------------------------------------------------------------------
# 25       0.80     0.8037   0.8202   0.4975   0.6193   13.6       <- BEST
# 25       0.75     0.6592   0.8728   0.3496   0.4993   13.6
# 25       0.70     0.4338   0.9153   0.2448   0.3863   13.5
# 25       0.65     0.2810   0.9584   0.2079   0.3417   13.6
# 25       0.60     0.2169   0.9856   0.1974   0.3289   13.5
# 25       0.55     0.1995   0.9955   0.1951   0.3262   13.6
# 25       0.35     0.1948   1.0000   0.1947   0.3259   13.3
# 25       0.30     0.1947   1.0000   0.1947   0.3259   13.4
# 25       0.40     0.1948   0.9999   0.1947   0.3259   13.5
# 25       0.20     0.1947   1.0000   0.1947   0.3259   15.5
# 25       0.25     0.1947   1.0000   0.1947   0.3259   13.4
# 25       0.45     0.1950   0.9993   0.1947   0.3258   13.5
# 25       0.50     0.1957   0.9984   0.1947   0.3258   13.7
#
# [INFO] -------------------- Best Configuration --------------------
#
# [INFO] Configuration:
#   Top-K trees: 25
#   Threshold:   0.8
#
# [INFO] Performance:
#   Accuracy:    0.8037
#   Sensitivity: 0.8202
#   Precision:   0.4975
#   F1-Score:    0.6193
#
# [INFO] Confusion Matrix:
#                  Predicted
#                Good (0)  Bad (1)
#   Actual Good    32,201     8,065
#          Bad      1,750     7,984
#
# [INFO] ----------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done 500 out of 500 | elapsed:   13.4s finished

# %%
#Evaluate best configuration on full test set in fuzzy inference system

#The best_k and threshold values to test
top_k_values = [n_trees]
threshold_values = [0.75]


best_f1 = 0.0
best_config = None
results_grid = []

#use all test data for final evaluation
y_test_array = y_test.values if isinstance(y_test, pd.Series) else y_test


print(f"\nTest: {len(X_test_encoded):,} Total Rows")
print(f"Configurations to test: {len(top_k_values) * len(threshold_values)}")


print("\n[INFO] -------------------- Grid Search: Threshold --------------------")

top_k_values = [n_trees]
threshold_values = [0.75]

best_f1 = 0.0
best_config = None
results_grid = []



y_test_array = y_test.values if isinstance(y_test, pd.Series) else y_test

print(f"\n[INFO] Test sample: {len(X_test_encoded):,} samples")
print(f"[INFO] Configurations to test: {len(top_k_values) * len(threshold_values)}")

for i, (top_k, threshold) in enumerate([(k, t) for k in top_k_values for t in threshold_values]):
    print(f"\n[INFO] ----------------------------------------------------------------")
    print(f"[INFO] Config {i+1}/{len(top_k_values)*len(threshold_values)}: top_k={top_k}, threshold={threshold}")
    print(f"[INFO] ----------------------------------------------------------------")
    
    try:
        config_start = time.time()
        
        fuzzy_predictions = fi.execute_fuzzy_inference(
            X_test_encoded,
            fuzzy_rules,
            linguistic_terms,
            cat_mappings_fixed,
            t_norm_operator='min',
            classification_threshold=threshold,
            parallel_jobs=-1
        )
        
        config_time = time.time() - config_start
        
        acc = accuracy_score(y_test_array, fuzzy_predictions)
        sens = recall_score(y_test_array, fuzzy_predictions, pos_label=1, zero_division=0)
        prec = precision_score(y_test_array, fuzzy_predictions, pos_label=1, zero_division=0)
        f1 = f1_score(y_test_array, fuzzy_predictions, pos_label=1, zero_division=0)
        
        cm = confusion_matrix(y_test_array, fuzzy_predictions)
        tn, fp, fn, tp = cm.ravel()
        
        results_grid.append({
            'top_k': top_k,
            'threshold': threshold,
            'accuracy': acc,
            'sensitivity': sens,
            'precision': prec,
            'f1_score': f1,
            'time_sec': config_time,
            'tp': int(tp),
            'fp': int(fp),
            'tn': int(tn),
            'fn': int(fn)
        })
        
        if f1 > best_f1:
            best_f1 = f1
            best_config = (top_k, threshold)
            best_predictions = fuzzy_predictions.copy()
        
        print(f"\n[INFO] Completed in {config_time:.1f}s")
        print(f"\n[INFO] Metrics:")
        print(f"    Accuracy:    {acc:.4f}")
        print(f"    Sensitivity: {sens:.4f}")
        print(f"    Precision:   {prec:.4f}")
        print(f"    F1:          {f1:.4f}")
        
        print(f"\n[INFO] Confusion Matrix:")
        print(f"    TP: {tp:,}  FP: {fp:,}")
        print(f"    FN: {fn:,}  TN: {tn:,}")
        
    except Exception as e:
        print(f"\n[ERROR] {e}")
        import traceback
        traceback.print_exc()
        continue

print("\n[INFO] -------------------- Grid Search Results --------------------")

if len(results_grid) > 0:
    print(f"\n{'Top-K':<8} {'Thresh':<8} {'Acc':<8} {'Sens':<8} {'Prec':<8} {'F1':<8} {'Time(s)':<10}")
    print("-" * 70)
    
    for result in sorted(results_grid, key=lambda x: x['f1_score'], reverse=True):
        marker = " <- BEST" if (result['top_k'], result['threshold']) == best_config else ""
        print(f"{result['top_k']:<8} {result['threshold']:<8.2f} "
              f"{result['accuracy']:<8.4f} {result['sensitivity']:<8.4f} "
              f"{result['precision']:<8.4f} {result['f1_score']:<8.4f} "
              f"{result['time_sec']:<10.1f}{marker}")
    
    if best_config:
        print(f"\n[INFO] -------------------- Best Configuration --------------------")
        
        best_result = [r for r in results_grid if (r['top_k'], r['threshold']) == best_config][0]
        
        print(f"\n[INFO] Configuration:")
        print(f"  Top-K trees: {best_config[0]}")
        print(f"  Threshold:   {best_config[1]}")
        
        print(f"\n[INFO] Performance:")
        print(f"  Accuracy:    {best_result['accuracy']:.4f}")
        print(f"  Sensitivity: {best_result['sensitivity']:.4f}")
        print(f"  Precision:   {best_result['precision']:.4f}")
        print(f"  F1-Score:    {best_result['f1_score']:.4f}")
        
        print(f"\n[INFO] Confusion Matrix:")
        print(f"                 Predicted")
        print(f"               Good (0)  Bad (1)")
        print(f"  Actual Good  {best_result['tn']:8,}  {best_result['fp']:8,}")
        print(f"         Bad   {best_result['fn']:8,}  {best_result['tp']:8,}")
        

else:
    print("\n[ERROR] No results obtained - check for errors")

print("\n[INFO] ----------------------------------------------------------------")
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# Test: 559,054 Total Rows
# Configurations to test: 1
#
# [INFO] -------------------- Grid Search: Threshold --------------------
#
# [INFO] Test sample: 559,054 samples
# [INFO] Configurations to test: 1
#
# [INFO] ----------------------------------------------------------------
# [INFO] Config 1/1: top_k=25, threshold=0.75
# [INFO] ----------------------------------------------------------------
#
# [INFO] Preparing optimized inference
# [INFO] Total trees: 25
# [INFO] Total rules: 717
# [INFO] Samples: 559,054
# [INFO] Batch size: 100
# [INFO] Using ALL trees (pre-selected by select_best_trees)
# [INFO] Batches: 5591
# [INFO] Parallel jobs: -1
#
# [INFO] Starting inference
# [Parallel(n_jobs=-1)]: Done  40 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=-1)]: Done 130 tasks      | elapsed:    3.7s
# [Parallel(n_jobs=-1)]: Done 256 tasks      | elapsed:    7.4s
# [Parallel(n_jobs=-1)]: Done 418 tasks      | elapsed:   11.7s
# [Parallel(n_jobs=-1)]: Done 616 tasks      | elapsed:   17.0s
# [Parallel(n_jobs=-1)]: Done 850 tasks      | elapsed:   23.2s
# [Parallel(n_jobs=-1)]: Done 1120 tasks      | elapsed:   30.5s
# [Parallel(n_jobs=-1)]: Done 1426 tasks      | elapsed:   38.5s
# [Parallel(n_jobs=-1)]: Done 1768 tasks      | elapsed:   47.5s
# [Parallel(n_jobs=-1)]: Done 2146 tasks      | elapsed:   57.4s
# [Parallel(n_jobs=-1)]: Done 2560 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 3010 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 3496 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done 4018 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=-1)]: Done 4576 tasks      | elapsed:  2.0min
# [Parallel(n_jobs=-1)]: Done 5170 tasks      | elapsed:  2.3min
# [INFO] Inference completed in 147.3s
# [INFO] Throughput: 3795.9 samples/sec
#
# [INFO] Completed in 147.3s
#
# [INFO] Metrics:
#     Accuracy:    0.6576
#     Sensitivity: 0.8666
#     Precision:   0.3477
#     F1:          0.4963
#
# [INFO] Confusion Matrix:
#     TP: 94,314  FP: 176,902
#     FN: 14,518  TN: 273,320
#
# [INFO] -------------------- Grid Search Results --------------------
#
# Top-K    Thresh   Acc      Sens     Prec     F1       Time(s)
# ----------------------------------------------------------------------
# 25       0.75     0.6576   0.8666   0.3477   0.4963   147.3      <- BEST
#
# [INFO] -------------------- Best Configuration --------------------
#
# [INFO] Configuration:
#   Top-K trees: 25
#   Threshold:   0.75
#
# [INFO] Performance:
#   Accuracy:    0.6576
#   Sensitivity: 0.8666
#   Precision:   0.3477
#   F1-Score:    0.4963
#
# [INFO] Confusion Matrix:
#                  Predicted
#                Good (0)  Bad (1)
#   Actual Good   273,320   176,902
#          Bad     14,518    94,314
#
# [INFO] ----------------------------------------------------------------
# [Parallel(n_jobs=-1)]: Done 5591 out of 5591 | elapsed:  2.5min finished

# %%
print("\n[INFO] CatBoost model evaluating start.")

X_test_encoded = mod.encode_data_like_training(X_test, cat_mappings)
threshold = catboost_metrics['optimal_threshold']
em.evaluate_model(catboost_model, X_test_encoded, y_test, threshold=threshold)
print("\n[INFO] CatBoost model evaluating successfully.")
print(cat_mappings)
# Out:
# [INFO] CatBoost model evaluating start.
#
# [INFO] -------------------- Model Evaluation --------------------
# MODEL - TEST SET EVALUATION
# [INFO] ----------------------------------------------------------------
# [INFO] Using classification threshold: 0.430
#
# [INFO] -------------------- Performance Metrics --------------------
#
# Test samples: 559,054
# Positive class (bad loans): 108,832 (19.5%)
#
# Metric               Value
# ----------------------------------------
# Accuracy             0.9582
# Recall (Sensitivity) 0.8564
# Precision            0.9234
# F1-Score             0.8887
# Specificity          0.9828
# ROC-AUC              0.9811
# Log Loss             0.1090
#
# [INFO] -------------------- Confusion Matrix --------------------
#
#                  Predicted
#                Good (0)  Bad (1)
# Actual  Good    442,494     7,728
#         Bad      15,625    93,207
#
# Metric                    Count      Percentage
# --------------------------------------------------
# True Negatives (TN)        442,494    98.28% of predicted good
# False Positives (FP)         7,728     1.72% of predicted good
# False Negatives (FN)        15,625    14.36% of predicted bad
# True Positives (TP)         93,207    85.64% of predicted bad
#
# [INFO] -------------------- Classification Report --------------------
#               precision    recall  f1-score   support
#
#     Good (0)     0.9659    0.9828    0.9743    450222
#      Bad (1)     0.9234    0.8564    0.8887    108832
#
#     accuracy                         0.9582    559054
#    macro avg     0.9447    0.9196    0.9315    559054
# weighted avg     0.9576    0.9582    0.9576    559054
#
#
# [INFO] -------------------- Evaluation Complete --------------------
#
# [INFO] CatBoost model evaluating successfully.
# {'debt_settlement_flag': {'N': 0, 'Y': 1}, 'grade': {'A': 0, 'B': 1, 'C': 2, 'D': 3, 'E': 4, 'F': 5, 'G': 6}, 'verification_status': {'Not Verified': 0, 'Source Verified': 1, 'Verified': 2}}

# %%
ef.plot_membership_functions(
    linguistic_terms,
    save_path='membership_functions_all.png'
)

ef.plot_membership_functions(
    linguistic_terms,
    variables_to_plot=['last_fico_range_high', 'recoveries', 'term_num', 'fico_range_low'],
    save_path='membership_functions_key.png'
)

ef.plot_membership_functions_paper(
    linguistic_terms,
    variables=['last_fico_range_high', 'recoveries', 'term_num', 'fico_range_low'],
    output_path='membership_functions_paper.png'
)

summary_df = ef.summarize_fuzzy_rules(
    fuzzy_rules,
    linguistic_terms,
    top_n=15,
    sort_by='logit'
)

ef.export_rules_for_paper(
    fuzzy_rules,
    linguistic_terms,
    output_file='fuzzy_rules_paper.txt',
    max_rules=20
)
# Out:
# [INFO] Membership functions saved to: membership_functions_all.png
# [INFO] Membership functions saved to: membership_functions_key.png
# [INFO] Paper membership functions saved: membership_functions_paper.png
# [INFO] Variables plotted: last_fico_range_high, recoveries, term_num, fico_range_low
#
# [INFO] -------------------- Fuzzy Rule System Summary --------------------
#
# [INFO] General Statistics:
#   Total Rules:     717
#   Total Trees:     25
#   Class 0 Rules:   204 (28.5%)
#   Class 1 Rules:   513 (71.5%)
#
# [INFO] Variables:
#   Total Variables: 12
#   Variables: acc_open_past_24mths, debt_settlement_flag, dti, fico_range_low, grade, last_fico_range_high, loan_amnt, mort_acc, recoveries, term_num, total_rec_late_fee, verification_status
#
# [INFO] Linguistic Terms:
#   Total Terms:     60
#   Avg per Variable: 5.0
#
# [INFO] -------------------- Top 15 Rules (sorted by logit) --------------------
#
#  Rank  Tree  Class  Logit  Antecedents                                                                                Rule
#     1     1      1 +9.126            5 last_fico_range_high IS (VeryLow OR Low) AND recoveries IS (Low OR High) AND deb...
#     2     1      1 +8.224            5 last_fico_range_high IS (MediumLow OR Medium OR MediumHigh OR High OR VeryHigh) ...
#     3     1      1 +5.223            5 last_fico_range_high IS (VeryLow OR Low) AND recoveries IS VeryLow AND debt_sett...
#     4     1      1 +5.181            5 last_fico_range_high IS (MediumLow OR Medium OR MediumHigh OR High OR VeryHigh) ...
#     5     1      1 +4.885            5 last_fico_range_high IS (VeryLow OR Low) AND recoveries IS VeryLow AND debt_sett...
#     6    66      0 -4.674            5 last_fico_range_high IS (High OR VeryHigh) AND fico_range_low IS (MediumHigh OR ...
#     7     1      1 +4.374            5 last_fico_range_high IS (MediumLow OR Medium OR MediumHigh OR High OR VeryHigh) ...
#     8    45      0 -3.711            5 fico_range_low IS VeryLow AND last_fico_range_high IS (VeryLow OR Low OR MediumL...
#     9    53      1 +3.678            5 loan_amnt IS (MediumLow OR Medium OR MediumHigh OR High OR VeryHigh) AND total_r...
#    10    32      1 +3.566            5 last_fico_range_high IS (MediumLow OR Medium OR MediumHigh OR High OR VeryHigh) ...
#    11    45      0 -2.943            5 fico_range_low IS VeryLow AND last_fico_range_high IS (Medium OR MediumHigh OR H...
#    12     9      0 -2.851            5 fico_range_low IS (VeryLow OR Low OR MediumLow OR Medium OR MediumHigh) AND last...
#    13    53      1 +2.846            5 loan_amnt IS (VeryLow OR Low) AND total_rec_late_fee IS VeryLow AND fico_range_l...
#    14    53      0 -2.713            5 loan_amnt IS (VeryLow OR Low) AND total_rec_late_fee IS (Low OR Medium OR High) ...
#    15    32      1 +2.323            5 last_fico_range_high IS (VeryLow OR Low) AND loan_amnt IS VeryLow AND dti IS (Me...
#
# [INFO] Rules exported to: fuzzy_rules_paper.txt
